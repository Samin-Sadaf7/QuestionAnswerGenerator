# %% [markdown]
# <a href="https://colab.research.google.com/github/Samin-Sadaf7/QuestionAnswerGenerator/blob/main/Medibee_AI_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Set Up

# %% [markdown]
# ##Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Package Installation

# %%
# !pip uninstall typer -y
# !pip install --force-reinstall spacy weasel
# Out:
# Found existing installation: typer 0.12.5
# Uninstalling typer-0.12.5:
#   Successfully uninstalled typer-0.12.5
# Collecting spacy
#   Using cached spacy-3.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting weasel
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Using cached thinc-8.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting setuptools (from spacy)
#   Using cached setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting packaging>=20.0 (from spacy)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.0 MB/s eta 0:00:00
# Collecting confection<0.2.0,>=0.0.4 (from weasel)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel)
#   Using cached cloudpathlib-0.19.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel)
#   Using cached smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Collecting typing_extensions>4 (from cloudpathlib<1.0.0,>=0.7.0->weasel)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel)
#   Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Using cached blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached marisa_trie-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached spacy-3.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.0 MB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cloudpathlib-0.19.0-py3-none-any.whl (49 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
# Using cached langcodes-3.4.0-py3-none-any.whl (182 kB)
# Using cached murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached smart_open-7.0.4-py3-none-any.whl (61 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
# Using cached thinc-8.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached setuptools-75.1.0-py3-none-any.whl (1.2 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached rich-13.8.1-py3-none-any.whl (241 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 10.7 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Using cached marisa_trie-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing_extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, pygments, packaging, numpy, murmurhash, mdurl, MarkupSafe, idna, click, charset-normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, marisa-trie, jinja2, cloudpathlib, blis, rich, pydantic, language-data, typer, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.8
#     Uninstalling cymem-2.0.8:
#       Successfully uninstalled cymem-2.0.8
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: spacy-loggers
#     Found existing installation: spacy-loggers 1.0.5
#     Uninstalling spacy-loggers-1.0.5:
#       Successfully uninstalled spacy-loggers-1.0.5
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.12
#     Uninstalling spacy-legacy-3.0.12:
#       Successfully uninstalled spacy-legacy-3.0.12
#   Attempting uninstall: shellingham
#     Found existing installation: shellingham 1.5.4
#     Uninstalling shellingham-1.5.4:
#       Successfully uninstalled shellingham-1.5.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.0.4
#     Uninstalling setuptools-71.0.4:
#       Successfully uninstalled setuptools-71.0.4
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.10
#     Uninstalling murmurhash-1.0.10:
#       Successfully uninstalled murmurhash-1.0.10
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.8.30
#     Uninstalling certifi-2024.8.30:
#       Successfully uninstalled certifi-2024.8.30
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.10
#     Uninstalling catalogue-2.0.10:
#       Successfully uninstalled catalogue-2.0.10
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
#       Successfully uninstalled srsly-2.4.8
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.0.4
#     Uninstalling smart-open-7.0.4:
#       Successfully uninstalled smart-open-7.0.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.9
#     Uninstalling preshed-3.0.9:
#       Successfully uninstalled preshed-3.0.9
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: marisa-trie
#     Found existing installation: marisa-trie 1.2.0
#     Uninstalling marisa-trie-1.2.0:
#       Successfully uninstalled marisa-trie-1.2.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: cloudpathlib
#     Found existing installation: cloudpathlib 0.19.0
#     Uninstalling cloudpathlib-0.19.0:
#       Successfully uninstalled cloudpathlib-0.19.0
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.11
#     Uninstalling blis-0.7.11:
#       Successfully uninstalled blis-0.7.11
#   Attempting uninstall: rich
#     Found existing installation: rich 13.8.1
#     Uninstalling rich-13.8.1:
#       Successfully uninstalled rich-13.8.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
#   Attempting uninstall: language-data
#     Found existing installation: language_data 1.2.0
#     Uninstalling language_data-1.2.0:
#       Successfully uninstalled language_data-1.2.0
#   Attempting uninstall: langcodes
#     Found existing installation: langcodes 3.4.0
#     Uninstalling langcodes-3.4.0:
#       Successfully uninstalled langcodes-3.4.0
#   Attempting uninstall: confection
#     Found existing installation: confection 0.1.5
#     Uninstalling confection-0.1.5:
#       Successfully uninstalled confection-0.1.5
#   Attempting uninstall: weasel
#     Found existing installation: weasel 0.4.1
#     Uninstalling weasel-0.4.1:
#       Successfully uninstalled weasel-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.5
#     Uninstalling thinc-8.2.5:
#       Successfully uninstalled thinc-8.2.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.6
#     Uninstalling spacy-3.7.6:
#       Successfully uninstalled spacy-3.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2024.8.30 charset-normalizer-3.3.2 click-8.1.7 cloudpathlib-0.19.0 confection-0.1.5 cymem-2.0.8 idna-3.10 jinja2-3.1.4 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 numpy-1.26.4 packaging-24.1 preshed-3.0.9 pydantic-2.9.2 pydantic-core-2.23.4 pygments-2.18.0 requests-2.32.3 rich-13.8.1 setuptools-75.1.0 shellingham-1.5.4 smart-open-7.0.4 spacy-3.7.6 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 tqdm-4.66.5 typer-0.12.5 typing_extensions-4.12.2 urllib3-2.2.3 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0

# %%
# !pip install --force-reinstall --no-deps typer==0.9.0
# !pip install fastapi-cli
# !pip install langchain-community sentence-transformers pypdf2 pypdf chromadb
# !pip install google-generativeai
# Out:
# Collecting typer==0.9.0
#   Using cached typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.5
#     Uninstalling typer-0.12.5:
#       Successfully uninstalled typer-0.12.5
# Successfully installed typer-0.9.0
# Requirement already satisfied: fastapi-cli in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Collecting typer>=0.12.3 (from fastapi-cli)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: uvicorn>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (0.30.6)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (4.12.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (13.8.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.15.0->uvicorn[standard]>=0.15.0->fastapi-cli) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (6.0.2)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.15.0->fastapi-cli) (13.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli) (2.18.0)
# Requirement already satisfied: anyio>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from watchfiles>=0.13->uvicorn[standard]>=0.15.0->fastapi-cli) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]>=0.15.0->fastapi-cli) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]>=0.15.0->fastapi-cli) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]>=0.15.0->fastapi-cli) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli) (0.1.2)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed typer-0.12.5
# Collecting langchain-community
#   Using cached langchain_community-0.3.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-3.1.1-py3-none-any.whl.metadata (10 kB)
# Collecting pypdf2
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pypdf
#   Using cached pypdf-5.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting chromadb
#   Using cached chromadb-0.5.7-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.4.0,>=0.3.0 (from langchain-community)
#   Using cached langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain-community)
#   Using cached langchain_core-0.3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting langsmith<0.2.0,>=0.1.112 (from langchain-community)
#   Using cached langsmith-0.1.125-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain-community)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.2)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Using cached orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Collecting httpx>=0.27.0 (from chromadb)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (13.8.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.38.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.27.0->chromadb)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.6.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.7.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain<0.4.0,>=0.3.0->langchain-community)
#   Using cached langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.0->langchain-community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.2)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (75.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.0.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading langchain_community-0.3.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 43.4 MB/s eta 0:00:00
# Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 18.1 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 15.1 MB/s eta 0:00:00
# Downloading pypdf-5.0.0-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 18.4 MB/s eta 0:00:00
# Downloading chromadb-0.5.7-py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.2/599.2 kB 29.4 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.9 MB/s eta 0:00:00
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 19.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 75.1 MB/s eta 0:00:00
# Downloading langchain-0.3.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.8 MB/s eta 0:00:00
# Downloading langchain_core-0.3.5-py3-none-any.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 32.2 MB/s eta 0:00:00
# Downloading langsmith-0.1.125-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.2/290.2 kB 24.1 MB/s eta 0:00:00
# Downloading mmh3-5.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 6.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 100.7 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 5.7 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 13.5 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.1 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 13.9 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.6.6-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 5.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.6 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 7.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.4 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: pypika, durationpy
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=1f8755d302d1e6294dc28515ade69f41df90837bb211ad7682f589b840e63ae8
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   Building wheel for durationpy (setup.py) ... done
#   Created wheel for durationpy: filename=durationpy-0.7-py3-none-any.whl size=3463 sha256=d4bdb51eb4e39e52b4fa0347a472bb2b7d0c327ab64e5afeaa00319f81ee6d88
#   Stored in directory: /root/.cache/pip/wheels/a2/52/58/701659d0f7467c85c273d8d06d8f74f2646ee7da4145ce77b5
# Successfully built pypika durationpy
# Installing collected packages: pypika, monotonic, durationpy, tenacity, pypdf2, pypdf, overrides, orjson, opentelemetry-util-http, opentelemetry-proto, mypy-extensions, mmh3, marshmallow, jsonpointer, importlib-metadata, humanfriendly, httpcore, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, typing-inspect, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, jsonpatch, httpx, coloredlogs, pydantic-settings, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, langsmith, kubernetes, fastapi, dataclasses-json, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langchain-core, sentence-transformers, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain, chromadb, langchain-community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 chroma-hnswlib-0.7.6 chromadb-0.5.7 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.14 durationpy-0.7 fastapi-0.115.0 httpcore-1.0.5 httpx-0.27.2 humanfriendly-10.0 importlib-metadata-8.4.0 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-31.0.0 langchain-0.3.0 langchain-community-0.3.0 langchain-core-0.3.5 langchain-text-splitters-0.3.0 langsmith-0.1.125 marshmallow-3.22.0 mmh3-5.0.0 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 orjson-3.10.7 overrides-7.7.0 posthog-3.6.6 pydantic-settings-2.5.2 pypdf-5.0.0 pypdf2-3.0.1 pypika-0.48.9 sentence-transformers-3.1.1 starlette-0.38.5 tenacity-8.5.0 typing-inspect-0.9.0
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.6)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.6->google-generativeai) (1.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.23.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install --quiet pytesseract

# %%
# !pip install "unstructured[all-docs]" pillow pydantic lxml matplotlib
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting unstructured[all-docs]
#   Downloading unstructured-0.15.13-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.2.0)
# Collecting filetype (from unstructured[all-docs])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured[all-docs])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.3)
# Collecting emoji (from unstructured[all-docs])
#   Downloading emoji-2.13.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.6.7)
# Collecting python-iso639 (from unstructured[all-docs])
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured[all-docs])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 46.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.26.4)
# Collecting rapidfuzz (from unstructured[all-docs])
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.2)
# Collecting unstructured-client (from unstructured[all-docs])
#   Downloading unstructured_client-0.25.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.9.5)
# Collecting python-oxmsg (from unstructured[all-docs])
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[all-docs])
#   Downloading unstructured.pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Collecting python-docx>=1.1.2 (from unstructured[all-docs])
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting pikepdf (from unstructured[all-docs])
#   Downloading pikepdf-9.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# Collecting python-pptx>=1.0.1 (from unstructured[all-docs])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.1.4)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.7)
# Collecting google-cloud-vision (from unstructured[all-docs])
#   Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting unstructured-inference==0.7.36 (from unstructured[all-docs])
#   Downloading unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.1.5)
# Collecting pdf2image (from unstructured[all-docs])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting onnx (from unstructured[all-docs])
#   Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting pypandoc (from unstructured[all-docs])
#   Downloading pypandoc-1.13-py3-none-any.whl.metadata (16 kB)
# Collecting pdfminer.six (from unstructured[all-docs])
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.0.1)
# Collecting pi-heif (from unstructured[all-docs])
#   Downloading pi_heif-0.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.3)
# Collecting effdet (from unstructured[all-docs])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.0.0)
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting python-multipart (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (0.24.7)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (1.19.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (2.4.1+cu121)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading timm-1.0.9-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.44.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=1.0.1->unstructured[all-docs])
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[all-docs]) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured[all-docs]) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (0.19.1+cu121)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (2.0.8)
# Collecting omegaconf>=2.0 (from effdet->unstructured[all-docs])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (2.19.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (3.20.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (2024.9.11)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[all-docs]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[all-docs]) (43.0.1)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from pikepdf->unstructured[all-docs]) (1.2.14)
# Collecting olefile (from python-oxmsg->unstructured[all-docs])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[all-docs]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[all-docs]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[all-docs]) (2024.8.30)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured[all-docs])
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (0.27.2)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured[all-docs])
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.6.0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured[all-docs])
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.17.1)
# Collecting orderly-set==5.2.2 (from deepdiff>=6.0->unstructured-client->unstructured[all-docs])
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.65.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (0.14.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[all-docs])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]) (6.0.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.13.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->unstructured-inference==0.7.36->unstructured[all-docs]) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (3.16.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2024.6.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.36->unstructured[all-docs]) (0.19.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs]) (1.13.1)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[all-docs]) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (10.0)
# Collecting portalocker (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2.1.5)
# Collecting pdfminer.six (from unstructured[all-docs])
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.3.0)
# Downloading unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.3 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 10.9 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 13.0 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 9.1 MB/s eta 0:00:00
# Downloading emoji-2.13.0-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 29.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.5/467.5 kB 27.4 MB/s eta 0:00:00
# Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 39.3 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pi_heif-0.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (984 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.8/984.8 kB 33.9 MB/s eta 0:00:00
# Downloading pikepdf-9.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 32.1 MB/s eta 0:00:00
# Downloading pypandoc-1.13-py3-none-any.whl (21 kB)
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 18.7 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 38.7 MB/s eta 0:00:00
# Downloading unstructured-0.15.13-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.2 MB/s eta 0:00:00
# Downloading unstructured_client-0.25.9-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.7 MB/s eta 0:00:00
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 4.7 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.1 MB/s eta 0:00:00
# Downloading timm-1.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.8 MB/s eta 0:00:00
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 13.4 MB/s eta 0:00:00
# Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 26.0 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 2.7 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.0 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 27.6 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 53.4 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: langdetect, antlr4-python3-runtime, iopath
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=38140ac0eca165f4d3ede1d3372913d0ab86f553c8da34a61dbc920d0256f771
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=56440949d29c05a8ffddc52b283776e6606534f5375d29b3112f743978058bc3
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=6e72f16299d5614e52f2e8f9482c98db40324c541a9defc01b21ad5a84464b53
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built langdetect antlr4-python3-runtime iopath
# Installing collected packages: filetype, antlr4-python3-runtime, XlsxWriter, unstructured.pytesseract, rapidfuzz, python-multipart, python-magic, python-iso639, python-docx, pypdfium2, pypandoc, portalocker, pi-heif, pdf2image, orderly-set, onnx, omegaconf, olefile, langdetect, jsonpath-python, emoji, requests-toolbelt, python-pptx, python-oxmsg, pikepdf, iopath, deepdiff, unstructured-client, pdfminer.six, unstructured, timm, pdfplumber, layoutparser, google-cloud-vision, effdet, unstructured-inference
# Successfully installed XlsxWriter-3.2.0 antlr4-python3-runtime-4.9.3 deepdiff-8.0.1 effdet-0.4.1 emoji-2.13.0 filetype-1.2.0 google-cloud-vision-3.7.4 iopath-0.1.10 jsonpath-python-1.0.6 langdetect-1.0.9 layoutparser-0.3.4 olefile-0.47 omegaconf-2.3.0 onnx-1.16.2 orderly-set-5.2.2 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.4 pi-heif-0.18.0 pikepdf-9.2.1 portalocker-2.10.1 pypandoc-1.13 pypdfium2-4.30.0 python-docx-1.1.2 python-iso639-2024.4.27 python-magic-0.4.27 python-multipart-0.0.9 python-oxmsg-0.0.1 python-pptx-1.0.2 rapidfuzz-3.9.7 requests-toolbelt-1.0.0 timm-1.0.9 unstructured-0.15.13 unstructured-client-0.25.9 unstructured-inference-0.7.36 unstructured.pytesseract-0.3.13

# %%
# !sudo apt-get update

# %%
# !sudo apt-get install poppler-utils

# %%
# !sudo apt-get install libleptonica-dev tesseract-ocr libtesseract-dev python3-pil tesseract-ocr-script-latn

# %%
# !pip install unstructured-pytesseract
# !pip install tesseract-ocr
# !pip install --quiet pdf2image pytesseract pillow

# %%
# !pip install git+https://github.com/giuliano-oliveira/gdown_folder.git

# %%
# !pip install numpy
# !pip install accelerate
# !pip install --quiet reportlab
# !pip install --quiet pandas pymongo sentence_transformers transformers accelerate
# !python -m pip install "pymongo[srv]"
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# !pip install openai
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.4.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.24.7)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 44.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.10/dist-packages (4.9.1)
# WARNING: pymongo 4.9.1 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo[srv]) (2.6.1)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.26.0 (from python-Levenshtein)
#   Downloading levenshtein-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.26.0->python-Levenshtein) (3.9.7)
# Downloading python_Levenshtein-0.26.0-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.26.0 python-Levenshtein-0.26.0
# Collecting openai
#   Downloading openai-1.47.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.47.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 27.7 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 25.8 MB/s eta 0:00:00
# Installing collected packages: jiter, openai
# Successfully installed jiter-0.5.0 openai-1.47.0

# %% [markdown]
# ##Installed Folder and files from google drive

# %%
url = 'https://drive.google.com/drive/u/1/folders/1oDIeJGjqS1jY-iqyOZpEi0sK-MTn6nGr'
import gdown
import time
time.sleep(100)
gdown.download_folder(url,quiet=False)

# %% [markdown]
# ##Import Packages

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
import os
import textwrap
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_name" in HuggingFaceInferenceAPIEmbeddings has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %% [markdown]
# #Text Based RAG

# %% [markdown]
# ##Splitting PDF

# %%
pdf_path = "/content/AI_integration_kernel/MediBee_MBBS_AI/All Prof Course/3rd Prof/Pathology/Guide/(rej)Arif’s Representation on Pathology & Haematology.pdf"

# %%
def split_pdf(file_path, chunk_size, chunk_overlap):
    loader = PyPDFLoader(file_path)
    pages = loader.load_and_split()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    docs = text_splitter.split_documents(pages)
    return docs

# %%
docs =split_pdf(pdf_path, chunk_size=3000, chunk_overlap=500)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def split_text_file(file_path, chunk_size, chunk_overlap):
  with open(file_path) as f:
      guide_book = f.read()

  text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
      chunk_size=chunk_size,
      chunk_overlap=chunk_overlap,
      length_function=len,
      is_separator_regex=False,
  )
  docs = text_splitter.create_documents([guide_book])
  return docs

# %%
from unstructured.partition.pdf import partition_pdf

# %%
from pdf2image import convert_from_path
from PIL import Image
def pdf_to_images(pdf_path, first_page = 1, last_page = 5):
    images = convert_from_path(pdf_path, first_page=first_page, last_page=last_page)
    for image in images[:1]:
        Image.fromarray(image).show()
    return images

# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
import tempfile
import os
from tqdm import tqdm

def pdf_to_images(pdf_path, first_page=1, last_page=100):
    images = convert_from_path(pdf_path, first_page=first_page, last_page=last_page)
    return images

def images_to_text(images):
    text_list = []
    for idx, image in enumerate(tqdm(images)):
        # Save each image as a temporary file
        temp_image_path = f"temp_image_{idx}.png"
        image.save(temp_image_path, format='PNG')

        # Use pytesseract to perform OCR on the temporary image file
        text = pytesseract.image_to_string(temp_image_path)
        text_list.append(text.strip())  # Strip any leading/trailing whitespace

        # Clean up temporary file
        os.remove(temp_image_path)

    return text_list

# %%
def extract_text_from_pdf(pdf_path):
    images = pdf_to_images(pdf_path)
    texts = images_to_text(images)
    return texts

# %%
import torch
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
from tqdm import tqdm
import os
from multiprocessing import Pool, Manager
import numpy as np
from PyPDF2 import PdfReader

# Function to get the total number of pages in the PDF
def get_total_pages(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfReader(f)
        return len(pdf.pages)

# Function to convert a batch of PDF pages to images
def pdf_to_images_batch(pdf_path, first_page, last_page):
    images = convert_from_path(pdf_path, first_page=first_page, last_page=last_page)
    return images

# Function to process a batch of images and extract text
def process_batch(batch_info, result_list):
    pdf_path, page_numbers, device = batch_info

    text_list = []
    for page_number in tqdm(page_numbers, desc=f"Processing batch on device {device}"):
        # Convert the specific page to an image
        images = pdf_to_images_batch(pdf_path, first_page=page_number, last_page=page_number)
        image = images[0]  # Only one image since we're processing one page at a time

        # Save the image as a temporary file
        temp_image_path = f"temp_image_{device}_{page_number}.png"
        image.save(temp_image_path, format='PNG')

        # Use pytesseract to perform OCR on the temporary image file
        text = pytesseract.image_to_string(temp_image_path)
        text_list.append((page_number, text.strip()))  # Strip any leading/trailing whitespace

        # Clean up temporary file
        os.remove(temp_image_path)

    result_list.append(text_list)

def extract_text_from_pdf(pdf_path, num_batches=10):
    # Check if CUDA (GPU) is available
    use_cuda = torch.cuda.is_available()

    # Get the total number of pages in the PDF
    total_pages = get_total_pages(pdf_path)

    # Calculate the number of pages per batch
    pages_per_batch = (total_pages + num_batches - 1) // num_batches  # Ensure we cover all pages

    # Create batches
    batches = []
    for i in range(num_batches):
        start_page = i * pages_per_batch + 1
        end_page = min((i + 1) * pages_per_batch, total_pages)
        page_numbers = list(range(start_page, end_page + 1))

        # Choose device (GPU or CPU)
        if use_cuda:
            device = torch.device('cuda', i % torch.cuda.device_count())
        else:
            device = torch.device('cpu')

        batches.append((pdf_path, page_numbers, device))

    # Use multiprocessing to process batches in parallel
    manager = Manager()
    result_list = manager.list()
    with Pool(processes=len(batches)) as pool:
        for batch in batches:
            pool.apply_async(process_batch, args=(batch, result_list))

        # Close the pool and wait for all processes to finish
        pool.close()
        pool.join()

    # Combine results from result_list
    extracted_texts = [text for batch_result in result_list for text in batch_result]
    extracted_texts.sort(key=lambda x: x[0])

    # Return only the texts, discarding the page numbers
    return [text for _, text in extracted_texts]

# %%
extracted_texts = extract_text_from_pdf(pdf_path, num_batches=10)

for page_number, text in enumerate(extracted_texts, start=1):
    print(f"Page {page_number}:\n{text}\n")

# %%
def save_text_list_to_file(text_list, file_path):
    with open(file_path, 'w') as file:
        for line in text_list:
            file.write(line + '\n')

# %%
file_path ="/content/AI_integration_kernel/MediBee_MBBS_AI/All Prof Course/3rd Prof/Pathology/Guide/Arif_Representation_on_Pathology_Haematology.txt"
save_text_list_to_file(extracted_texts, file_path)

# %% [markdown]
# ##Data To Mongo

# %%
import pandas as pd

# %%
docs = split_text_file(file_path, chunk_size=3000, chunk_overlap=500)

# %%
# Prepare data for DataFrame
data = []
for doc in docs:
    data.append({
        'text': doc.page_content,
        'source': doc.metadata['source'],
        'page': doc.metadata['page'],
    })

# Create DataFrame
df = pd.DataFrame(data)

# %%
# For imaged pdf :
    #Prepare data for DataFrame
data = []
i=0
for doc in docs:
    data.append({
        'text': doc.page_content,
        'source': file_path,
        'page': i+1,
        'subject': 'Pathology'
    })
    i+=1

# Create DataFrame
df = pd.DataFrame(data)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

from google.colab import userdata
uri = userdata.get('MongoDB_URL')

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['RAG_application']

# %%
db.Medical_Books_RAG.distinct('source')
# Out:
# ['/content/drive/MyDrive/All Prof Course/1st Prof/Anatomy/Text Book/Vishram Singh Textbook of Anatomy  Head, Neck, and Brain..pdf',
#  '/content/drive/MyDrive/All Prof Course/1st Prof/Anatomy/Text Book/vishram singh textbook of anatomy abdomen and lower limb.pdf',
#  '/content/drive/MyDrive/All Prof Course/2nd Prof/Microbiology/Text Book/Lange Medical Microbiology 28th Edition.pdf',
#  '/content/drive/MyDrive/All Prof Course/2nd Prof/Pharmacology/Text Book/Basic & Clinical Pharmacology (Katzung).pdf',
#  '/content/femur.png',
#  '/content/gdrive/MyDrive/AI_integration_kernel/Reddy Forensic 33rd.pdf']

# %%
updated_results = db.Medical_Books_RAG.update_many({'source': '/content/gdrive/MyDrive/AI_integration_kernel/Reddy Forensic 33rd.pdf'}, {'$set': {'subject': 'Forensic Medicine'}})
print(f"Updated {updated_results.modified_count} documents")

# %% [markdown]
# ##Processing PDF for Mongo

# %%
emb_csv = pd.read_csv("/content/AI_integration_kernel/MediBee_MBBS_AI/All Prof Course/1st Prof/Anatomy/Text Book/vishram singh textbook of anatomy abdomen and lower limb.csv")

# %%
emb_df =pd.DataFrame(emb_csv)
emb_df.head()

# %%
emb_df['embedding'].dtype
# Out:
# dtype('O')

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)

emb_df['embedding'] =emb_df['embedding'].apply(str_to_list)

emb_df.head()

# %%
for c in emb_df.columns:
  print(emb_df[c].dtype)
# Out:
# int64
# object
# object
# int64
# object

# %%
emb_df.rename(columns={'page_content': 'text'}, inplace=True)

# %%
emb_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
emb_df['flag'] =0

# %%
emb_df.count()

# %%
book_documents = emb_df.to_dict('records')
result = db.Medical_Books_RAG.insert_many(book_documents)
print(f"Inserted {len(result.inserted_ids)} documents into the collection.")
# Out:
# Inserted 501 documents into the collection.

# %%
{
    "fields":[{
        "numDimensions" : 1024,
        "path" : "embedding",
        "similarity": "cosine",
        "type": "vector"
    }]
}
# Out:
# {'fields': [{'numDimensions': 1024,
#    'path': 'embedding',
#    'similarity': 'cosine',
#    'type': 'vector'}]}

# %% [markdown]
# ##Topic Database

# %%
from pymongo import MongoClient
from pymongo.errors import CollectionInvalid

# Define the collection name
topic_name = 'topic'

# Define the question schema
topic_schema = {
    'prof': {
        'type': 'string',
        'required': True,
    },
    'term':{
        'type': 'string',
    },
    'subject': {
        'type': 'string',
        'required': True,
    },
    'card': {
        'type': 'string',
        'required': True,
    },
    'topic': {
        'type': 'string',
        'required': True,
    },
    'subTopic': {
        'type': 'string',
    }
}

# Initialize the validator
validator = {
    '$jsonSchema': {
        'bsonType': 'object',
        'properties': {}
    }
}

required = []

def process_field(field_key, field, parent_required, parent_properties):
    properties = {'bsonType': field['type']}
    if 'min_length' in field:
        properties['minLength'] = field['min_length']
    if 'required' in field and field['required']:
        parent_required.append(field_key)
    parent_properties[field_key] = properties

for field_key, field in topic_schema.items():
    process_field(field_key, field, required, validator['$jsonSchema']['properties'])

if required:
    validator['$jsonSchema']['required'] = required


# Create the collection with the validator
try:
    db.create_collection(topic_name, validator=validator)
    print(f"Collection '{topic_name}' created with validator.")
except CollectionInvalid:
    print(f"Collection '{topic_name}' already exists or validation failed.")

print(validator)
# Out:
# Collection 'topic' already exists or validation failed.
# {'$jsonSchema': {'bsonType': 'object', 'properties': {'prof': {'bsonType': 'string'}, 'term': {'bsonType': 'string'}, 'subject': {'bsonType': 'string'}, 'card': {'bsonType': 'string'}, 'topic': {'bsonType': 'string'}, 'subTopic': {'bsonType': 'string'}}, 'required': ['prof', 'subject', 'card', 'topic']}}

# %%
topics_csv= pd.read_csv('/content/AI_integration_kernel/MediBee_MBBS_AI/topics_clean_v2.csv')

# %%
topics_df = pd.DataFrame(topics_csv)

# %%
topics_df.columns
# Out:
# Index(['prof', 'subject', 'card', 'topic', 'subTopic'], dtype='object')

# %%
topic_documents = topics_df.to_dict('records')
topic_documents

# %%
db.list_collection_names()
# Out:
# ['viva_question_collection', 'topic', 'Medical_Books_RAG']

# %%
results = db.topic.insert_many(topic_documents)
print(f"Inserted {len(results.inserted_ids)} documents into the collection.")

# %%
import json
from bson import ObjectId

collection = db['topic']

def fix_oid(data):
    if isinstance(data, dict):
        for key, value in data.items():
            if key == '_id' and '$oid' in value:
                data[key] = ObjectId(value['$oid'])  # Convert $oid to ObjectId
            else:
                fix_oid(value)
    elif isinstance(data, list):
        for item in data:
            fix_oid(item)
    return data
# Load JSON data from file
with open('/content/test.topic.json', 'r') as file:
    data = json.load(file)

fixed_data = fix_oid(data)

if isinstance(fixed_data, list):
    collection.insert_many(fixed_data)
else:  # If it's a single JSON object
    collection.insert_one(fixed_data)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %% [markdown]
# ##Embedding

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-large")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
def get_embedding(text:str)->list[float]:
  if not text.strip():
    print("Attemted to do embedding on an empty text")
    return []
  embedding = embedding_model.encode(text)
  return embedding.tolist()

# %%
def vector_search(user_query, collection):
    query_embedding = get_embedding(user_query)
    print(query_embedding)

    if query_embedding is None:
        return "Invalid Query Embedding"

    pipeline = [
        {
            "$vectorSearch": {
                "index": "vector_index",
                "queryVector": query_embedding,
                "path": "embedding",
                "numCandidates": 10,
                "limit": 2,
            }
        },
        {
            "$project": {
                "text": 1,
                "flag": 1,
                "_id": 1,
                "score": {"$meta": "vectorSearchScore"},
            }
        },
        {
            "$match": {
                "flag": 0,
                "$expr": {
                    "$gte": [{"$strLenCP": "$text"}, 100]
                }
            }
        },
    ]

    # Run the aggregation pipeline
    result = list(collection.aggregate(pipeline))

    # Extract document IDs from the result
    document_ids = [doc["_id"] for doc in result]

    # Update the flag value to 1 for the matched documents
    if document_ids:
        update_result = collection.update_many(
            {"_id": {"$in": document_ids}},
            {"$set": {"flag": 1}}
        )
        print(f"Updated {update_result.modified_count} documents")

    return result

# %%
def get_knowledge(user_query, collection):
  get_knowledge = vector_search(user_query, collection)
  return get_knowledge

# %%
def get_search_result(get_knowledge):
  search_result = ""

  for result in get_knowledge:
    score = result.get('score')
    print(score)
    text = result.get('text',' ')
    text = textwrap.fill(text, width=100)
    print(text)
    text_length = len(text)
    print(text_length)
    if score > 0.8 and text_length > 200:
     search_result += f"{text}\n"

  return search_result

# %%
df['embedding'] = df['text'].apply(get_embedding)

# %%
df.columns

# %%
documents = df.to_dict('records')

# %%
df.to_csv('/content/AI_integration_kernel/MediBee_MBBS_AI/All Prof Course/2nd Prof/Forensic Medicine/Text Book/reddy_forensic_documents.csv', index=False)

# %%
len(documents)

# %% [markdown]
# ##Find Data from Mongo

# %%
book_collection = db['Medical_Books_RAG']

# %%
results = list(db.topic.find())
topic_list = []
for result in results:
  topic_list.append(result)

# %%
len(topic_list)
# Out:
# 485

# %%
question_topics = db.viva_question_collection.distinct("topic")
len(question_topics)
# Out:
# 31

# %%
query = ' Head neck: pharyngeal arches'
knowledge = get_knowledge(query, book_collection)
context = get_search_result(knowledge)
context
# Out:
# [-0.0022918186150491238, 0.008685228414833546, -0.017084909602999687, 0.009746587835252285, 0.01889963075518608, -0.018930120393633842, -0.006156123708933592, 0.03561919927597046, 0.027654284611344337, 0.05163608491420746, 0.04634861648082733, -0.012617578729987144, 0.012248323298990726, -0.038723696023225784, -0.027578089386224747, 0.020923208445310593, -0.039142705500125885, -0.03837312012910843, -0.01940949633717537, 0.024770962074398994, -0.00037492476985789835, -0.01055862382054329, -0.07302655279636383, 0.007441373076289892, -0.0001338961155852303, 0.03094548173248768, 0.015771090984344482, -0.0007005534134805202, 0.040412019938230515, 0.056433528661727905, -0.0057858373038470745, -0.0016936162719503045, 0.023819440975785255, -0.05216193199157715, -0.02239096723496914, -0.049870897084474564, 0.030964676290750504, -0.06639441847801208, 0.007878364063799381, -0.04956795647740364, 0.021987777203321457, -0.017063412815332413, 0.007371310610324144, -0.006488760933279991, -0.01726909913122654, -0.020836371928453445, -0.011376720853149891, -0.026693228632211685, 0.022187191992998123, -0.015819169580936432, 0.012558424845337868, -0.03757817670702934, 0.01577337644994259, 0.018424300476908684, 0.0271077249199152, -0.005991042125970125, 0.05387643352150917, -0.0025212413165718317, -0.03731340914964676, 0.008578227832913399, 0.019125623628497124, 0.021305913105607033, -0.007313086651265621, -0.03390935808420181, 0.016072584316134453, 0.036047857254743576, 0.005872052162885666, 0.009170759469270706, 0.007181170396506786, -0.009612894617021084, -0.01556129939854145, -0.0009516821010038257, 0.0056105200201272964, -0.03127555176615715, -0.020082810893654823, -0.03758843615651131, 0.004148551728576422, -0.014265158213675022, 0.001023489865474403, 0.019682636484503746, 0.003230672562494874, 0.07519758492708206, 0.00208208872936666, 0.008846103213727474, -0.04242323338985443, 0.011473040096461773, -0.017684606835246086, 0.0176534466445446, -0.01549125462770462, -0.009901009500026703, 0.01937798783183098, 0.03136551380157471, 0.02116241678595543, -0.008147737942636013, 0.04621491953730583, 0.033320389688014984, -0.054974187165498734, 0.0349314846098423, -0.028216222301125526, 0.004565010312944651, 0.026189792901277542, 0.019146103411912918, -0.01238986849784851, 0.05153895914554596, -0.014593321830034256, -0.001675677951425314, 0.004069934133440256, -0.0030123768374323845, 0.007658100686967373, -0.03982551023364067, -0.0020731997210532427, -0.01318676769733429, 0.005761801265180111, 0.010333968326449394, 0.0055026221089065075, 0.027690930292010307, -0.007905622944235802, 0.06312760710716248, -0.04205746203660965, 0.013506310060620308, 0.010432638227939606, 0.008219732902944088, 0.04435134679079056, 0.0003299002710264176, 0.021741408854722977, -0.006590087898075581, -0.03277145326137543, 0.033999379724264145, -0.044602081179618835, 0.014990575611591339, 0.020213212817907333, -0.0420655682682991, -0.004969832021743059, -0.0011448545847088099, 0.005430764518678188, 0.008324445225298405, -0.043643467128276825, 0.02005941979587078, -0.007481585722416639, -0.03730457276105881, 0.025570062920451164, 0.05763103440403938, 0.012508136220276356, 0.08592671155929565, 0.03134438022971153, 0.02317771688103676, 0.005198538303375244, 0.008927562274038792, -0.015686962753534317, -0.002318131271749735, -0.009294720366597176, 0.040761105716228485, -0.026082973927259445, 0.009371483698487282, -0.01165281143039465, 0.02334217168390751, -0.02515442483127117, 0.009372740052640438, 0.0007627077866345644, 0.03525969386100769, 0.018408820033073425, -0.002162532415241003, -0.007970948703587055, 0.05652055889368057, 0.008161711506545544, 0.04636482894420624, -0.03190665319561958, -0.028412722051143646, 0.01404383685439825, -0.04987295717000961, 0.005888290703296661, 0.0029889342840760946, 0.010877163149416447, 0.002597259357571602, -0.019580548629164696, 0.045158952474594116, 0.01793372817337513, -0.01536200288683176, 0.029574599117040634, 0.038507021963596344, -0.01 ...
# Updated 2 documents
# 0.940393328666687
# Pharynx and Palate 217 Golden Facts to Remember  /g34Killian’s dehiscence A weak area in the
# posterior wall of pharynx  between the two parts of inferior constrictor muscle  /g34Principal
# artery of tonsil Tonsillar branch of the facial artery  /g34Common source of bleeding after
# tonsillectomy Paratonsillar vein  /g34Tonsillar lymph node Jugulodigastric lymph node  /g34Most
# common variety of cleft palate Unilateral cleft palate involving the hard palate  /g34Largest
# tonsils Palatine tonsils  /g34Quinsy Chronic infection of peritonsillar space  /g34Coffin corner
# Lingual tonsillar sulcus Case 1 A 47-year-old man came in the emergency OPD and  complained that
# while eating fish something got stuck  in his throat. It was causing pain and lot of discomfort.
# The physical examination of throat revealed that  discomfort increases on moving the thyroid
# cartilage  from side to side. The physician concluded that the fish  bone was stuck in the piriform
# fossa. Questions 1. What is piriform fossa? 2. What are medial and lateral boundaries of the
# piriform fossa? 3. What nerve is likely to be injured during the  removal of the fish bone? Answers
# 1. Recess in the lateral wall of laryngopharynx, one on  either side of laryngeal inlet. 2. Piriform
# fossa is bounded medially by  aryepiglottic fold and quadrangular membrane  of the larynx and
# laterally by inner surface of the  thyrohyoid membrane and lamina of thyroid  cartilage. 3. Internal
# laryngeal nerve.Case 2 An 8-year-old boy was taken by his parents to the  physician and complained
# that their son was suffering  from recurrent attacks of sore throat and for the past  few days he
# has difficulty in swallowing and feeling pain  not only in his throat but also in his ears. On
# examination of oropharynx, the physician found that  both the tonsils were enlarged and almost
# touching  each other in the midline. The palpation of cervical  lymph nodes revealed enlarged and
# tender tonsillar  nodes. The boy was diagnosed as a case of tonsillitis. Questions 1. What is meant
# by the term tonsil? 2. What are tonsillar lymph nodes? 3. What was the cause of ear ache? Answers 1.
# Unless otherwise stated, reference to tonsil always  refers to the palatine tonsil. 2.
# Jugulodigastric lymph nodes. 3. The tonsil is supplied by the glossopharyngeal nerve  and tympanic
# branch of this nerve supplies mucous  membrane of the middle ear (tympanic cavity).  Therefore pain
# of tonsillitis is referred to the ear.Clinical Case Study
# 2472
# 0.9395277500152588
# 14Pharynx and PalateCHAPTER PHARYNX The pharynx is a funnel-shaped fibromuscular tube,  extending
# from the base of the skull to the esophagus  (Fig. 14.1). It is lined throughout with mucous
# membrane.  The pharynx acts as a common channel (Fig. 14.2) for both  food (deglutition) and air
# (respiration). MEASUREMENTS Length:  12–14 cm, Width:  3.5 cm at its base, and  1.5 cm at
# pharyngoesophageal junction.LOCATION It is situated behind the cavities of nose, mouth, and the
# larynx with which it communicates (Fig. 14.1). BOUNDARIES AND RELATIONS Superior:  Base of skull
# including the posterior part of the  body of sphenoid and basilar part of occipital  bone in front
# of pharyngeal tubercle. Inferior:  Continuous with the esophagus at the level of  lower border of
# cricoid cartilage anteriorly and  lower border of C6 vertebra posteriorly. Posterior:   Prevertebral
# fascia in front of cervical spine. The  pharynx is separated from prevertebral fascia  only by a
# layer of loose areolar tissue, which  allows the pharynx to slide freely on this fascia  during
# swallowing. Anterior:  Opens into nasal cavities, mouth, and larynx. Lateral:   Neurovascular bundle
# of neck and styloid process  with its attached muscles and ligaments. SUBDIVISIONS (Figs 14.2–14.4)
# The pharynx is divided into three parts. From above  downwards these are as follows: 1. Nasopharynx
# , lying behind the nose. 2. Oropharynx , lying behind the oral cavity. 3. Laryngopharynx , lying
# behind the larynx. NASOPHARYNX The nasopharynx lies behind the nasal cavities and above the  soft
# palate. Boundaries Roof:  It is formed by: (a) Body of sphenoid. (b) Basilar part of the occipital
# bone.Fig. 14.1  The sagittal section through the nose, mouth,  pharynx, and larynx.Tubal tonsil Body
# of sphenoid Nasopharyngeal bursa Pharyngeal tonsil Pharyngeal recess Anterior arch of atlasBasilar
# part of occipital bone Passavant’s ridge Laryngeal inlet Arytenoid cartilage Cricoid cartilage
# (lamina) Cricoid cartilage (anterior arch)Thyroid cartilage Laryngeal cavityNasal cavity Oral cavity
# Hyoid bonePalatopharyngeal foldTonsilPalatoglossal fold EpiglottisTubal opening Rathke’s pouch C6
# 2150
# 'Pharynx and Palate 217 Golden Facts to Remember  /g34Killian’s dehiscence A weak area in the\nposterior wall of pharynx  between the two parts of inferior constrictor muscle  /g34Principal\nartery of tonsil Tonsillar branch of the facial artery  /g34Common source of bleeding after\ntonsillectomy Paratonsillar vein  /g34Tonsillar lymph node Jugulodigastric lymph node  /g34Most\ncommon variety of cleft palate Unilateral cleft palate involving the hard palate  /g34Largest\ntonsils Palatine tonsils  /g34Quinsy Chronic infection of peritonsillar space  /g34Coffin corner\nLingual tonsillar sulcus Case 1 A 47-year-old man came in the emergency OPD and  complained that\nwhile eating fish something got stuck  in his throat. It was causing pain and lot of discomfort.\nThe physical examination of throat revealed that  discomfort increases on moving the thyroid\ncartilage  from side to side. The physician concluded that the fish  bone was stuck in the piriform\nfossa. Questions 1. What is piriform fossa? 2. What are medial and lateral boundaries of the\npiriform fossa? 3. What nerve is likely to be injured during the  removal of the fish bone? Answers\n1. Recess in the lateral wall of laryngopharynx, one on  either side of laryngeal inlet. 2. Piriform\nfossa is bounded medially by  aryepiglottic fold and quadrangular membrane  of the larynx and\nlaterally by inner surface of the  thyrohyoid membrane and lamina of thyroid  cartilage. 3. Internal\nlaryngeal nerve.Case 2 An 8-year-old boy was taken by his parents to the  physician and complained\nthat their son was suffering  from recurrent attacks of sore throat and for the past  few days he\nhas difficulty in swallowing and feeling pain  not only in his throat but also in his ears. On\nexamination of oropharynx, the physician found that  both the tonsils were enlarged and almost\ntouching  each other in the midline. The palpation of cervical  lymph nodes revealed enlarged and\ntender tonsillar  nodes. The boy was diagnosed as a case of tonsillitis. Questions 1. What is meant\nby the term tonsil? 2. What are tonsillar lymph nodes? 3. What was the cause of ear ache? Answers 1.\nUnless otherwise stated, reference to tonsil always  refers to the palatine tonsil. 2.\nJugulodigastric lymph nodes. 3. The tonsil is supplied by the glossopharyngeal nerve  and tympanic\nbranch of this nerve supplies mucous  membrane of the middle ear (tympanic cavity).  Therefore pain\nof tonsillitis is referred to the ear.Clinical Case Study\n14Pharynx and PalateCHAPTER PHARYNX The pharynx is a funnel-shaped fibromuscular tube,  extending\nfrom the base of the skull to the esophagus  (Fig. 14.1). It is lined throughout with mucous\nmembrane.  The pharynx acts as a common channel (Fig. 14.2) for both  food (deglutition) and air\n(respiration). MEASUREMENTS Length:  12–14 cm, Width:  3.5 cm at its base, and  1.5 cm at\npharyngoesophageal junction.LOCATION It is situated behind the cavities of nose, mouth, and the\nlarynx with which it communicates (Fig. 14.1). BOUNDARIES AND RELATIONS Superior:  Base of skull\nincluding the posterior part of the  body of sphenoid and basilar part of occipital  bone in front\nof pharyngeal tubercle. Inferior:  Continuous with the esophagus at the level of  lower border of\ncricoid cartilage anteriorly and  lower border of C6 vertebra posteriorly. Posterior:   Prevertebral\nfascia in front of cervical spine. The  pharynx is separated from prevertebral fascia  only by a\nlayer of loose areolar tissue, which  allows the pharynx to slide freely on this fascia  during\nswallowing. Anterior:  Opens into nasal cavities, mouth, and larynx. Lateral:   Neurovascular bundle\nof neck and styloid process  with its attached muscles and ligaments. SUBDIVISIONS (Figs 14.2–14.4)\nThe pharynx is divided into three parts. From above  downwards these are as follows: 1. Nasopharynx\n, lying behind the nose. 2. Oropharynx , lying behind the oral cavity. 3. Laryngopharynx , lying\nbehind the larynx. NASOPH ...

# %%
document_ids = [doc["_id"] for doc in knowledge]

# Update the flag value to 1 for the matched documents
if document_ids:
  update_result = book_collection.update_many(
            {"_id": {"$in": document_ids}},
            {"$set": {"flag": 0}}
   )
  print(f"Updated {update_result.modified_count} documents")
# Out:
# Updated 2 documents

# %%
collection = db['topic']

# %%
import re
topic = 'Thoracic wall, intercostal space, thoracic inlet'
regex = re.compile(rf'^\s*{topic}\s*$', re.IGNORECASE)

# Query to find documents where the topic or subtopic matches the regex
query = {
    "$or": [
        {"topic": regex},
        {"subtopic": regex}
    ]
}

# Execute the query and save the results into a list
results = list(collection.find(query))
print(results)
# Out:
# [{'_id': ObjectId('66b71568cd747a509166a19c'), 'prof': 'First', 'subject': 'Anatomy', 'card': 'Thorax ', 'topic': ' Thoracic wall, intercostal space, thoracic inlet', 'subTopic': ' Thoracic wall, intercostal space, thoracic inlet'}]

# %% [markdown]
# ##Question Set Up

# %%
from pymongo.errors import CollectionInvalid

# Define the collection name
question_collection_name = 'viva_question_collection'

# Define the question schema
question_schema = {
    'prof': {
        'type': 'string',
        'required': True,
    },
    'subject': {
        'type': 'string',
        'required': True,
    },
    'card': {
        'type': 'string',
        'required': True,
    },
    'version': {
        'type': 'string',
        'required': True,
    },
    'topic': {
        'type': 'string',
        'required': True,
    },
    'question': {
        'type': 'string',
        'required': True,
    },
    'hint': {
        'type': 'string',
        'required': True,
    },
    'subTopic':{
        'type': 'string',
    },
    'correct_answer': {
        'type': 'string',
        'required': True,
    },
    'extra': {
        'oneof': [
            {
                'type': 'string',
            },
            {
                'type': 'null',
            },
        ],
        'required': True,
    },
    'difficulty_score': {
        'type': 'number',
        'required': True,
    },
}

# Initialize the validator
validator = {
    '$jsonSchema': {
        'bsonType': 'object',
        'properties': {}
    }
}

required = []

def process_field(field_key, field, parent_required, parent_properties):
    if 'oneof' in field:
        properties = {'bsonType': []}
        for option in field['oneof']:
            properties['bsonType'].append(option['type'])
    else:
        properties = {'bsonType': field['type']}

    if 'min_length' in field:
        properties['minLength'] = field['min_length']

    if 'required' in field and field['required']:
        parent_required.append(field_key)

    parent_properties[field_key] = properties

for field_key, field in question_schema.items():
    process_field(field_key, field, required, validator['$jsonSchema']['properties'])

if required:
    validator['$jsonSchema']['required'] = required

# Create the collection with the validator
try:
    db.create_collection(question_collection_name, validator=validator)
    print(f"Collection '{question_collection_name}' created with validator.")
except CollectionInvalid:
    print(f"Collection '{question_collection_name}' already exists or validation failed.")

print(validator)
# Out:
# Collection 'viva_question_collection' already exists or validation failed.
# {'$jsonSchema': {'bsonType': 'object', 'properties': {'prof': {'bsonType': 'string'}, 'subject': {'bsonType': 'string'}, 'card': {'bsonType': 'string'}, 'version': {'bsonType': 'string'}, 'topic': {'bsonType': 'string'}, 'question': {'bsonType': 'string'}, 'hint': {'bsonType': 'string'}, 'subTopic': {'bsonType': 'string'}, 'correct_answer': {'bsonType': 'string'}, 'extra': {'bsonType': ['string', 'null']}, 'difficulty_score': {'bsonType': 'number'}}, 'required': ['prof', 'subject', 'card', 'version', 'topic', 'question', 'hint', 'correct_answer', 'extra', 'difficulty_score']}}

# %% [markdown]
# ##Prompts Set Up

# %%
def get_prompt_QUESTION(query, context, nQuestion):
    context = context.replace("'", "").replace('"', "").replace('\n', "")

    # Define the prompt with the formatted string
    prompt = ("""You are assisting a medical student in preparing for an exam. Here is your TASK:
You should generate VIVA questions for medical students based on the given context. You will also generate HINT, ANSWER and ADDITIONAL INFORMATION for \
each question. HINT or clue will be used to help student answering the question and the ANSWER will be used to evaluate the student's response. ADDITIONAL \
INFORMATION will be related to the TOPIC based on given CONTEXT to provide extra knowledge. Here are the KEY POINTS you must consider:
1. Do not ask questions if the context is irrelevant.
2. Focus on questions that can be answered within 100 words or around 5 lines.
3. Generate questions in full sentences. You should generate only viva-standard questions.
4. HINT should be small and precise, and it should not directly contain the answer.
5. Generate a helpful hint without directly answering the question.
6. The ANSWER to VIVA questions should be based on the given CONTEXT.
7. ADDITIONAL INFORMATION should be related to the TOPIC based on the given CONTEXT.
8. Add a difficulty score of the questions between 1 to 10, where 1 is the easiest and 10 is the hardest.
9. Generate questions from all difficulty levels between 1 to 10.
10. Return your response in the following JSON format:
[
  {{
    "question": "/* one question */",
    "hint": "/* hint */",
    "answer": "/* answer */",
    "extra": "/* additional information */",
    "difficulty_score": "/* difficulty score */"
  }},
  ... /* {nQuestion} number of questions */
]
Here is the topic, number of questions, and context: \
TOPIC: '{query}' NUMBER OF QUESTIONS: '{nQuestion}' CONTEXT: '{context}' \
QUESTION:""").format(query=query, context=context, nQuestion=nQuestion)

    return prompt

# %%
def get_prompt_viva(query, context):
    context = context.replace("'", "").replace('"', "").replace('\n', "")
    prompt = (
        f"""You are assisting a medical student in preparing for an exam. Your task is to generate a viva question based on the given MCQ, Multiple Choice Question, Single Best answer, SQA question and True-False Question using \
medical terminology. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate Viva Question and you are given the Question Format. \
Make sure to generate questions in full sentence. Your task is to create the viva question.  \
Question should be answerable in 1-2 sentences. You have 5 tasks here: \
1. You can generate as many questions you can. \
2. You should provide corresponding hints for those questions. \
3. You should also provide answers for those questions. Answers should be around 2-3 sentences. \
4. You must provide extra information for the questions. If you do not find anything to add give null \
5. Output should be a perfect json object with proper format. \
Do not add any extra characters. \
The output should be a JSON object in the following format: (Output only the json object nothing else, not even a single extra character)
{{
    "Questions": [
        {{
            "Question": "Q1?",
            "Hint": "H1",
            "Answer": "A1",
            "Extra": "E1"
        }}
    ]
}}
The response should strictly be a  JSON object. Just a JSON object in the above format. Maintain the mentioned format strictly. Replace\
Based on the following question format.
Question Format:
Q1 will be replaced by actual question created from the context. H1 will be replaced by the relevant hint to answer the question. A1 will be replaced by the actual answer to the question. \
E1 will be replaced by extra information. You need to generate actual questions in this format using the following context. Number of questions will be 10. \
TOPIC: '{query}'
CONTEXT: '{context}'"""
    )
    return prompt

# %%
def get_answer_prompt(actual_answer, question, answer):
  actual_answer = actual_answer.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""`You are assisting a medical student in preparing for an exam. The student has answered a QUESTION and want to check if the ANSWER is correct\
  As an assistant your job is to examine the ANSWER and provide a feedback. You are given the QUESTION and the student's ANSWER to that QUESTION. Also, the Actual Answer of that question is given.\
  Now evaluate the student's answer and compare it with the correct answer given below. Give a detailed feedback in first person under 100 words. BE STRICT about the evaluation and criticise the given answer properly. Generate normal text. No need to make the text bold.If the answer is incorrect\
  also provide the correct answer.\
  QUESTION: '{question}'
  Correct Answer: '{actual_answer}',
  STUDENT'S ANSWER: '{answer}'
  YOUR FEEDBACK:  """).format(actual_answer=actual_answer, question=question, answer=answer)
  return prompt

# %%
def get_prompt_TrueFalse(query, context):
  context = context.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""You are assisting a medical student in preparing for an exam. Your task is to generate true false questions based on the given Single Best answer, SQA question and True False Question using\
   medical terminology. You need to avoid making Single Best answer questions even if you get those questions. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate True/False Question and you are given the Question Format.\
   Make sure to generate questions in full sentence. Your task is to generate true false quesions in the given format. \
   The questions should be true of false. The format of question is first mention a topic and follow it with 5-6 sentences, the sentences can be true or false. \
TOPIC: '{query}'
CONTEXT: '{context}'
True/False QUESTIONS Format:
  Topic: T1
  Sentences:
  1. S1
  2. S2
  3. S3
  4. S4
  5. S5
  M1: True
  M2: False
  M3: True
  M4: False
  M5: True
""").format(query=query, context=context)
  return prompt

# %%
def get_prompt_SBA(query, context):
  context = context.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""You are assisting a medical student in preparing for an exam. Your task is to generate multiple choice questions based on the given MCQ, Multiple Choice Question, Single Best answer, SQA question and True False Question using\
   medical terminology. You need to avoid making True False questions even if you get those questions. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate Multiple Choice Question and you are given the Question Format.\
   Make sure to generate questions in full sentence. Your task is to generate Single Based quesions or Multiple Choice Questions in the given format. \
In the topic, you will multiple topics in comma seperated format. For example: Topic: T1, T2. You need to generate question for each topic. \
TOPIC: '{query}'
CONTEXT: '{context}'
MCQ QUESTIONS Format:
  Question: Q1
  options: A1, A2, A3, A4
  Answer: A1
  Question: Q2
  options: A1, A2, A3, A4
  Answer: A2
You can create as many mcq questions as you like.
""").format(query=query, context=context)
  return prompt

# %% [markdown]
# ##Gemini Run

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GeminiKey')

# %%
import google.generativeai as genai
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel(model_name='gemini-pro')

# %%
len(topic_list)
# Out:
# 0

# %%
for topic in topic_list[:4]:
  print(topic)
# Out:
# {'_id': ObjectId('66b71568cd747a509166a1a3'), 'prof': 'First', 'subject': 'Anatomy', 'card': 'Thorax ', 'topic': ' Vessels, nerves & lymphatics of thorax', 'subTopic': ' Vessels, nerves & lymphatics of thorax'}
# {'_id': ObjectId('66b71568cd747a509166a1b5'), 'prof': 'First', 'subject': 'Anatomy', 'card': 'Abdomen ', 'topic': ' Articulated pelvis', 'subTopic': ' Articulated pelvis'}
# {'_id': ObjectId('66b71568cd747a509166a1b2'), 'prof': 'First', 'subject': 'Anatomy', 'card': 'Abdomen ', 'topic': ' Hip bone', 'subTopic': ' Hip bone'}
# {'_id': ObjectId('66b71568cd747a509166a1b0'), 'prof': 'First', 'subject': 'Anatomy', 'card': 'Upper limb ', 'topic': ' Palm & back of the hand', 'subTopic': ' Palm & back of the hand'}

# %%
import time
import json

questions_list = []

for topic in topic_list[:2]:
    query = topic['topic']

    try:
        flag = False
       # for topic in question_topics:
        #    if topic == query:
         #       flag = True

        # Get the context and prompt
        if flag == False:
          knowledge = get_knowledge(query, book_collection)
          context = get_search_result(knowledge)
          print("Context: ", context)
          prompt = get_prompt_viva(query=query, context=context)

          # Print input tokens
          print('Input tokens: ', model.count_tokens(prompt))

          # Generate the question and print it
          question = model.generate_content(prompt).text
          print(question, '\n\n')

          # Print output tokens
          print('Output tokens: ', model.count_tokens(question))

          # Add the question to the list
          questions_list.append(question)

    except ValueError as e:
        print(f"Error generating content for topic '{topic}': {e}")
        continue

    # Add a 10-second wait time
    time.sleep(20)
# Out:
# [-0.014027365483343601, -0.02319750003516674, -0.009003140963613987, -0.006833345163613558, -0.002484127413481474, -0.012373109348118305, -0.02741677314043045, 0.017728906124830246, 0.026186276227235794, 0.028114985674619675, 0.02890779636800289, -0.04917038232088089, 0.005562399979680777, -0.026771044358611107, -0.046426136046648026, 0.01975085586309433, -0.0012702817330136895, -0.039525218307971954, -0.021938487887382507, -0.0030335928313434124, 0.006249471567571163, 0.029723860323429108, -0.06995139271020889, -0.022730156779289246, -0.014345330186188221, 0.02659728191792965, 0.002533570397645235, -0.01912079006433487, 0.022142183035612106, 0.027231452986598015, -0.04782351478934288, -0.03586329519748688, 0.04056774452328682, -0.06328614056110382, 0.005103146657347679, -0.029756631702184677, 0.04060786962509155, -0.037121791392564774, -0.02257535234093666, -0.037242185324430466, 0.019647525623440742, -0.009943024255335331, 0.054655902087688446, -0.02837095782160759, -0.02359088882803917, 0.0055299121886491776, 0.003636302426457405, -0.027974167838692665, 0.011033538728952408, -0.005759367253631353, 0.006140261888504028, -0.016853991895914078, 0.020598886534571648, -0.026871347799897194, 0.015057612210512161, -0.01253411453217268, 0.01463317684829235, -0.010824971832334995, -0.0008749882690608501, 0.0282035693526268, 0.04483901709318161, -0.014294737949967384, 0.020142601802945137, -0.06429243087768555, 0.010039830580353737, 0.04529757797718048, 0.0002518387627787888, -0.03215958923101425, 0.019065886735916138, -0.02192947268486023, -0.0018413923680782318, -0.0062473248690366745, -0.022892635315656662, -0.007049590349197388, -0.0042662108317017555, -0.01670479029417038, 0.0003516569850035012, -4.3869051296496764e-05, 0.0033068591728806496, -0.0032718509901314974, 0.042598627507686615, 0.04421715810894966, 0.019598932936787605, 0.004586692433804274, -0.04115808382630348, -0.022161807864904404, -0.03732741251587868, 0.023455558344721794, 0.02548748254776001, 0.01600133627653122, -0.006092915311455727, 0.052665937691926956, 0.011159210465848446, -0.0026568383909761906, 0.021469449624419212, 0.052472423762083054, -0.04396221041679382, 0.029566433280706406, 0.001329954364337027, -0.009262574836611748, 0.03734556585550308, 0.021462833508849144, -0.014272797852754593, 0.06638767570257187, -0.04276202619075775, -0.010153153911232948, 0.003195444354787469, 0.002466326579451561, 0.0027603250928223133, -0.05809119716286659, 0.013535693287849426, -0.006180312484502792, 0.000537436455488205, 0.03317219018936157, -0.0056355977430939674, 0.0471830852329731, 0.0017856236081570387, 0.031575556844472885, -0.04573248326778412, 0.01157537940889597, 0.021848956122994423, 0.005490953102707863, 0.034754667431116104, -0.02936110645532608, 0.0052368054166436195, -0.011547190137207508, -0.011662851087749004, 0.06381898373365402, -0.03115929663181305, -0.007342147175222635, -0.012646952643990517, -0.03142622858285904, -0.025518419221043587, 0.009854858741164207, 0.003494404023513198, -0.0003168653347529471, -0.0269117783755064, 0.007757712621241808, 0.0004080081998836249, -0.03636116161942482, 0.02224309928715229, 0.01996001973748207, 0.006176930386573076, 0.07751670479774475, 0.012749230489134789, 0.03875555843114853, -0.0009711429011076689, 0.0010159697849303484, -0.011532011441886425, 0.026131421327590942, -0.03349055349826813, 0.018414560705423355, 0.001818365417420864, 0.009149229153990746, 0.018072757869958878, -0.014591546729207039, -0.004836495965719223, -0.01100363302975893, 0.03049273043870926, 0.03812258690595627, -0.023777155205607414, 0.010782282799482346, -0.004252864979207516, 0.03864365443587303, -0.0049329414032399654, 0.052595678716897964, -0.00714162876829505, -0.018099360167980194, 0.0030602719634771347, -0.03168148174881935, 0.022248325869441032, -0.014641347341239452, 0.016497088596224785, 0.0035156363155692816, 0.03789369761943817, 0.043616995215415955, 0.050942838191986084, -0.010487118735909462, 0.047479353845119476, 0.04729498 ...
# Updated 2 documents
# 0.9135618209838867
# 1038     SECTION IX  Toxicology Cyanosis may be caused by hypoxemia or by methemoglobinemia.
# Icterus may suggest hepatic necrosis due to acetaminophen or Amanita phalloides mushroom poisoning.
# 5. Abdomen— Abdominal examination may reveal ileus, which  is typical of poisoning with
# antimuscarinic, opioid, and sedative drugs. Hyperactive bowel sounds, abdominal cramping, and
# diarrhea are common in poisoning with organophosphates, iron, arsenic, theophylline, A phalloides,
# and A muscaria. 6. Nervous system— A careful neurologic examination is essen - tial. Focal seizures
# or motor deficits suggest a structural lesion (eg, intracranial hemorrhage due to trauma) rather
# than toxic or metabolic encephalopathy. Nystagmus, dysarthria, and ataxia are typical of phenytoin,
# carbamazepine, alcohol, and other sedative intoxication. T witching and muscular hyperactivity are
# common with atropine and other anticholinergic agents, and cocaine and other sympathomimetic drugs.
# Muscular rigidity can be caused by haloperidol and other antipsychotic agents, and by strychnine or
# by tetanus. Generalized hypertonicity of muscles and lower extremity clonus are typical of serotonin
# syndrome. Seizures are often caused by overdose with antidepressants (especially tricyclic
# antidepressants and bupropion [as in the case study]), cocaine, amphetamines, theophylline,
# isoniazid, and diphenhydramine. Flaccid coma with absent reflexes and even an isoelectric elec-
# troencephalogram may be seen with deep coma due to sedative-hypnotic or other CNS depressant
# intoxication and may be mistaken for brain death. Laboratory & Imaging Procedures A. Arterial Blood
# Gases Hypoventilation results in an elevated P co2 (hypercapnia) and a  low P o2 (hypoxia). The P o2
# may also be low in a patient with aspi - ration pneumonia or drug-induced pulmonary edema. Poor
# tissue oxygenation due to hypoxia, hypotension, or cyanide poisoning will result in metabolic
# acidosis. The P o 2 measures only oxygen  dissolved in the plasma and not total blood oxygen content
# or oxyhemoglobin saturation and may appear normal in patients with severe carbon monoxide poisoning.
# Pulse oximetry may also give falsely normal results in carbon monoxide intoxication. B. Electrolytes
# Sodium, potassium, chloride, and bicarbonate should be measured. The anion gap is then calculated by
# subtracting the measured anions from cations: Anion gap = (Na+ + K+) – (HCO 3– + Cl–) Normally, the
# sum of the cations exceeds the sum of the  anions by no more than 12–16 mEq/L (or 8–12 mEq/L if the
# formula used for estimating the anion gap omits the potassium level). A larger than expected anion
# gap is caused by the pres - ence of unmeasured anions (lactate, etc) accompanying metabolic
# acidosis. This may occur with numerous conditions, such as dia - betic ketoacidosis, renal failure,
# or shock-induced lactic acidosis. Drugs that may induce an elevated anion gap metabolic acidosis (
# Table 58–1 ) include aspirin, metformin, methanol, ethylene  glycol, isoniazid, and iron.
# Alterations in the serum potassium level are hazardous because  they can result in cardiac
# arrhythmias. Drugs that may cause hyperkalemia despite normal renal function include potassium
# itself, β blockers, digitalis glycosides, potassium-sparing diuretics,  and fluoride. Drugs
# associated with hypokalemia include barium, β agonists, caffeine, theophylline, and thiazide and
# loop diuretics. C. Renal Function Tests Some toxins have direct nephrotoxic effects; in other cases,
# renal failure is due to shock or myoglobinuria. Blood urea nitrogen and creatinine levels should be
# measured and urinalysis performed. Elevated serum creatine kinase (CK) and myoglobin in the urine
# suggest muscle necrosis due to seizures or muscular rigidity. Oxalate crystals in large numbers in
# the urine suggest ethylene glycol poisoning. D. Serum Osmolality
# 3855
# 0.9095984697341919
# exposed to rodents in known endemic areas. Rapid recogni - tion and laboratory confirmation of the
# disease are essential  to institute lifesaving therapy. A. Specimens Blood is taken for culture and
# aspirates of enlarged lymph  nodes for smear and culture. Acute and convalescent sera  may be
# examined for antibody levels. In pneumonia, spu - tum is cultured; in possible meningitis,
# cerebrospinal fluid is  taken for smear and culture. B. Smears Y. pestis  are small Gram-negative
# bacilli that appear as single  cells or as pairs or short chains in clinical material. Wright,
# Giemsa, or Wayson stains may be more useful when staining  material from a suspected buboes or a
# positive blood culture  result because of the striking bipolar appearance (safety pin  shape) of the
# organism using these stains that is not evident on a  FIGURE 19-1  Y. pestis  (arrows) in blood,
# Wright-Giemsa stain. Some  of the Y. pestis  have bipolar staining, which gives them a hairpin-like
# appearance. Original magnification ×1000. (Courtesy of K Gage, Plague  Section, Centers for Disease
# Control and Prevention, Ft. Collins, CO.) Riedel_CH19_p289-p294.indd   290 04/04/19   4:48 PM
# 1165
# Context:  1038     SECTION IX  Toxicology Cyanosis may be caused by hypoxemia or by methemoglobinemia.
# Icterus may suggest hepatic necrosis due to acetaminophen or Amanita phalloides mushroom poisoning.
# 5. Abdomen— Abdominal examination may reveal ileus, which  is typical of poisoning with
# antimuscarinic, opioid, and sedative drugs. Hyperactive bowel sounds, abdominal cramping, and
# diarrhea are common in poisoning with organophosphates, iron, arsenic, theophylline, A phalloides,
# and A muscaria. 6. Nervous system— A careful neurologic examination is essen - tial. Focal seizures
# or motor deficits suggest a structural lesion (eg, intracranial hemorrhage due to trauma) rather
# than toxic or metabolic encephalopathy. Nystagmus, dysarthria, and ataxia are typical of phenytoin,
# carbamazepine, alcohol, and other sedative intoxication. T witching and muscular hyperactivity are
# common with atropine and other anticholinergic agents, and cocaine and other sympathomimetic drugs.
# Muscular rigidity can be caused by haloperidol and other antipsychotic agents, and by strychnine or
# by tetanus. Generalized hypertonicity of muscles and lower extremity clonus are typical of serotonin
# syndrome. Seizures are often caused by overdose with antidepressants (especially tricyclic
# antidepressants and bupropion [as in the case study]), cocaine, amphetamines, theophylline,
# isoniazid, and diphenhydramine. Flaccid coma with absent reflexes and even an isoelectric elec-
# troencephalogram may be seen with deep coma due to sedative-hypnotic or other CNS depressant
# intoxication and may be mistaken for brain death. Laboratory & Imaging Procedures A. Arterial Blood
# Gases Hypoventilation results in an elevated P co2 (hypercapnia) and a  low P o2 (hypoxia). The P o2
# may also be low in a patient with aspi - ration pneumonia or drug-induced pulmonary edema. Poor
# tissue oxygenation due to hypoxia, hypotension, or cyanide poisoning will result in metabolic
# acidosis. The P o 2 measures only oxygen  dissolved in the plasma and not total blood oxygen content
# or oxyhemoglobin saturation and may appear normal in patients with severe carbon monoxide poisoning.
# Pulse oximetry may also give falsely normal results in carbon monoxide intoxication. B. Electrolytes
# Sodium, potassium, chloride, and bicarbonate should be measured. The anion gap is then calculated by
# subtracting the measured anions from cations: Anion gap = (Na+ + K+) – (HCO 3– + Cl–) Normally, the
# sum of the cations exceeds the sum of the  anions by no more than 12–16 mEq/L (or 8–12 mEq/L if the
# formula used for estimating the anion gap omits the potassium level). A larger than expected anion
# gap is caused by the pres - ence of unmeasured anions (lactate, etc) accompanying metabolic
# acidosis. This may occur with numerous conditions, such as dia - betic ketoacidosis, renal failure,
# or shock-induced lactic acidosis. Drugs that may induce an elevated anion gap metabolic acidosis (
# Table 58–1 ) include aspirin, metformin, methanol, ethylene  glycol, isoniazid, and iron.
# Alterations in the serum potassium level are hazardous because  they can result in cardiac
# arrhythmias. Drugs that may cause hyperkalemia despite normal renal function include potassium
# itself, β blockers, digitalis glycosides, potassium-sparing diuretics,  and fluoride. Drugs
# associated with hypokalemia include barium, β agonists, caffeine, theophylline, and thiazide and
# loop diuretics. C. Renal Function Tests Some toxins have direct nephrotoxic effects; in other cases,
# renal failure is due to shock or myoglobinuria. Blood urea nitrogen and creatinine levels should be
# measured and urinalysis performed. Elevated serum creatine kinase (CK) and myoglobin in the urine
# suggest muscle necrosis due to seizures or muscular rigidity. Oxalate crystals in large numbers in
# the urine suggest ethylene glycol poisoning. D. Serum Osmolality
# exposed to rodents in known endemic areas. Rapid recogni - tion and laboratory confirmation of the
# disease are essential  to institute lifesaving therapy. A. Specimens Blood is taken for culture and
# aspirates of enlarged lymph  nodes for smear and culture. Acute and convalescent sera  may be
# examined for antibody levels. In pneumonia, spu - tum is cultured; in possible meningitis,
# cerebrospinal fluid is  taken for smear and culture. B. Smears Y. pestis  are small Gram-negative
# bacilli that appear as single  cells or as pairs or short chains in clinical material. Wright,
# Giemsa, or Wayson stains may be more useful when staining  material from a suspected buboes or a
# positive blood culture  result because of the striking bipolar appearance (safety pin  shape) of the
# organism using these stains that is not evident on a  FIGURE 19-1  Y. pestis  (arrows) in blood,
# Wright-Giemsa stain. Some  of the Y. pestis  have bipolar staining, which gives them a hairpin-like
# appearance. Original magnification ×1000. (Courtesy of K Gage, Plague  Section, Centers for Disease
# Control and Prevention, Ft. Collins, CO.) Riedel_CH19_p289-p294.indd   290 04/04/19   4:48 PM
#
# Input tokens:  total_tokens: 1552
#
# {
#     "Questions": [
#         {
#             "Question": "Can cyanosis be caused by reasons other than hypoxemia?",
#             "Hint": "Refer to the first sentence of the context.",
#             "Answer": "Yes, cyanosis can also be caused by methemoglobinemia.",
#             "Extra": null
#         },
#         {
#             "Question": "What abnormality or presence might suggest hepatic necrosis?",
#             "Hint": "Refer to the second sentence of the context.",
#             "Answer": "Icterus may suggest hepatic necrosis.",
#             "Extra": "This can be due to acetaminophen or Amanita phalloides mushroom poisoning."
#         },
#         {
#             "Question": "What finding might indicate poisoning with anticholinergic drugs?",
#             "Hint": "Refer to the fifth sentence of the context.",
#             "Answer": "Ileus is a typical finding in poisoning with anticholinergic drugs.",
#             "Extra": "Other drugs that can cause ileus include opioids and sedatives."
#         },
#         {
#             "Question": "What symptoms are common in poisoning with organophosphates?",
#             "Hint": "Refer to the fifth sentence of the context.",
#             "Answer": "Hyperactive bowel sounds, abdominal cramping, and diarrhea are common symptoms in poisoning with organophosphates.",
#             "Extra": "Other drugs that can cause these symptoms include iron, arsenic, theophylline, A. phalloides, and A. muscaria."
#         },
#         {
#             "Question": "What neurologic signs might suggest a structural lesion rather than toxic or metabolic encephalopathy?",
#             "Hint": "Refer to the first paragraph of the context.",
#             "Answer": "Focal seizures or motor deficits may suggest a structural lesion.",
#             "Extra": "Intracranial hemorrhage due to trauma is an example of such a lesion."
#         },
#         {
#             "Question": "What is a typical finding in phenytoin or carbamazepine intoxication?",
#             "Hint": "Refer to the second paragraph of the context.",
#             "Answer": "Nystagmus, dysarthria, and ataxia are typical findings in phenytoin or carbamazepine intoxication.",
#             "Extra": "Alcohol and other sedatives can also cause these symptoms."
#         },
#         {
#             "Question": "What is a common neurologic finding in poisoning with atropine or cocaine?",
#             "Hint": "Refer to the second paragraph of the context.",
#             "Answer": "Twitching and muscular hyperactivity are common neurologic findings in poisoning with atropine or cocaine.",
#             "Extra": "Other sympathomimetic drugs can also cause these symptoms."
#         },
#         {
#             "Question": "What drugs can cause muscular rigidity?",
#             "Hint": "Refer to the second paragraph of the context.",
#             "Answer": "Muscular rigidity can be caused by haloperidol, other antipsychotic agents, strychnine, or tetanus.",
#             "Extra": null
#         },
#         {
#             "Question": "What is a typical finding in serotonin syndrome?",
#             "Hint": "Refer to the second paragraph of the context.",
#             "Answer": "Generalized hypertonicity of muscles and lower extremity clonus are typical findings in serotonin syndrome.",
#             "Extra": null
#         },
#         {
#             "Question": "What is a common cause of seizures in overdose?",
#             "Hint": "Refer to the third paragraph of the context.",
#             "Answer": "Seizures are often caused by overdose with antidepressants (especially tricyclic antidepressants and bupropion), cocaine, amphetamines, theophylline, isoniazid, or diphenhydramine.",
#             "Extra": null
#         }
#     ]
# }
#
#
# Output tokens:  total_tokens: 811
#
# [-0.008104195818305016, -0.01881827600300312, 0.009994231164455414, 0.0006667258567176759, -0.005449768155813217, -0.011696470901370049, -0.031102953478693962, 0.02300887368619442, 0.01822647824883461, 0.040548309683799744, 0.03355063125491142, 0.024350576102733612, 0.010457766242325306, -0.026602305471897125, -0.010609777644276619, 0.01440887339413166, -0.04675189405679703, -0.03573167696595192, -0.030561190098524094, -0.02421293966472149, -0.018581226468086243, 0.012743988074362278, -0.0525621697306633, -0.017191817983984947, -0.015404182486236095, 0.03521733358502388, 0.033578820526599884, 0.008621232584118843, 0.04957825690507889, 0.049448221921920776, -0.008903483860194683, -0.04238058999180794, 0.036779820919036865, -0.048204172402620316, -0.03241012245416641, -0.02527947723865509, 0.053360626101493835, -0.040713563561439514, -0.011282538995146751, -0.05663525313138962, 0.007833748124539852, 0.000670870766043663, 0.037375301122665405, -0.03744732216000557, -0.042358219623565674, 0.030505290254950523, -0.03120589256286621, -0.03478303924202919, -0.0027076639235019684, -0.044490519911050797, 0.03369862958788872, -0.00602790666744113, 0.017919722944498062, -0.02556539885699749, -0.017303254455327988, -0.016167104244232178, 0.00808627437800169, 0.007480938918888569, 0.006770649924874306, 0.024049833416938782, 0.040958963334560394, 0.009712740778923035, 0.01903580315411091, -0.044069804251194, 0.0036302695516496897, 0.02208436094224453, -0.008783241733908653, -0.0005086439778096974, 0.0030029634945094585, -0.04699995741248131, -0.03090530075132847, 0.018302883952856064, -0.0008648793445900083, -0.02841928042471409, -0.03479551896452904, 0.013627471402287483, 0.0062073287554085255, 0.008071503601968288, -0.026845823973417282, -0.0009198277839459479, 0.006947134155780077, 0.060663048177957535, -0.00617560651153326, 0.014692920260131359, -0.0443592332303524, -0.0008762773941271007, 0.018040189519524574, 0.01997082680463791, 0.009567802771925926, -0.005038233008235693, 0.010922801680862904, 0.05993567407131195, 0.004599188454449177, 0.00354261533357203, 0.04619140923023224, 0.035997312515974045, -0.01654062420129776, 0.03938134387135506, 0.020497087389230728, 0.01987447217106819, 0.03419535234570503, 0.028837325051426888, -0.00387084623798728, 0.040339600294828415, -0.048077210783958435, 0.025555305182933807, 0.0035665256436914206, -0.006288634613156319, 0.0022915909066796303, -0.02105684019625187, 0.03593021631240845, -0.0395110622048378, 0.002781578339636326, -0.010824915952980518, -0.0013976498739793897, 0.04507377743721008, 0.016259022057056427, 0.017753176391124725, -0.03629915788769722, 0.03150998428463936, -0.006813224405050278, 0.03621857613325119, 0.03865009918808937, -0.041170552372932434, 0.025103960186243057, -0.02413683384656906, -0.020140284672379494, 0.040999747812747955, -0.016891779378056526, -0.0019419508753344417, 0.017522355541586876, -0.018902454525232315, -0.0029418189078569412, 0.02774914726614952, -0.005330740008503199, 0.004561312031000853, -0.005467262119054794, 0.053590890020132065, 0.015135161578655243, -0.03346818685531616, 0.015824347734451294, 0.014403089880943298, -0.015792198479175568, 0.07442697882652283, 0.017100775614380836, 0.04405840486288071, 0.014926733449101448, -0.014900919049978256, -0.03490699827671051, 0.032952290028333664, -0.027849942445755005, 0.006332940887659788, -0.003230384085327387, 0.004894178826361895, 0.004670543130487204, -0.027679968625307083, 0.013052085414528847, 0.012730797752737999, 0.01889221742749214, 0.033348213881254196, -0.014287480153143406, -0.01165000069886446, 0.016648855060338974, 0.04030264541506767, -0.00913289189338684, 0.0358944796025753, -0.03190061077475548, -0.0029864453244954348, -0.0397489070892334, -0.0182918980717659, 0.0032745201606303453, -0.03732858970761299, 0.00817933864891529, 0.020779144018888474, 0.03837360441684723, 0.026839205995202065, 0.0601838082075119, 0.017912769690155983, 0.07291004061698914, 0.05300217866897583, 0.00044306501513347 ...
# Updated 2 documents
# 0.9074958562850952
# CHAPTER 3  Classification of Bacteria   45 bacterial cell surface structures such as
# lipopolysaccharide  (LPS), flagella, or capsular antigens. The terms “serotype,”  “serogroups,” and
# “serovars” are, for all practical purposes,  identical—they all use the specificity of these
# antibodies to subdivide strains of a specific bacterial species. In essence,  these reagents are
# “forensic” agents, establishing a fingerprint  that links the source of an organism to a disease
# caused in  an individual. In certain circumstances (eg, an epidemic), it  is important to
# distinguish among strains of a given species  or to identify a specific strain. This is called
# subtyping  and  is accomplished by examining bacterial isolates for charac - teristics that allow
# discrimination below the species level.  Classically, subtyping has been accomplished by biotyping,
# serotyping, antimicrobial susceptibility testing, and bacte - riophage typing. For example, more
# than 130 serogroups of  Vibrio cholerae  have been identified based on antigenic dif - ferences in
# the O-polysaccharide of their LPS; however, only  the O1 and O139 serogroups are associated with
# epidemic and  pandemic cholera. Within these serogroups, only strains that  produce a toxin-
# coregulated pili and cholera toxin are viru - lent and cause the disease cholera. By contrast,
# nontoxigenic  V. cholerae  strains, which are not associated with epidemic  cholera, are generally
# isolated from environmental speci - mens, from food, or from patients with sporadic diarrhea.Gram +
# cocci catalase t est Catalase – streptococciCatalase + staph ylococci Coagulase test – Staphy
# lococcus epiderm idis+ Staphy lococcus aureus FIGURE 3-1  Algorithm for differentiating the Gram-
# positive cocci. TABLE 3-2  Common Microbial Biochemical Tests Used to Differentiate Among Bacteria
# 1. Carbohydrate breakdown.  The ability to produce acidic metabolic products, fermentatively or
# oxidatively, from a range of carbohydrates  (eg, glucose, sucrose, and lactose) has been applied to
# the identification of most groups of bacteria (eg, Escherichia  spp. ferment lactose,  whereas
# Salmonella  spp. do not). Such tests are crude and imperfect in defining mechanisms but have proved
# useful for taxonomic purposes.  More recently, gas chromatographic identification of specific short-
# chain fatty acids produced by fermentation of glucose has proved useful in  classifying many
# anaerobic bacteria. 2. Catalase production.  The enzyme catalase catalyzes the conversion of
# hydrogen peroxide to water and oxygen. When a colony is placed in  hydrogen peroxide, liberation of
# oxygen as gas bubbles can be seen. The test is particularly useful in differentiation of
# staphylococci (positive)  from streptococci (negative), but it also has taxonomic application to
# Gram-negative bacteria. 3. Citrate utilization.  An agar medium that contains sodium citrate as the
# sole carbon source may be used to determine ability to use citrate.  Bacteria such as Klebsiella
# pneumoniae  that grow on this medium are termed citrate-positive. 4. Coagulase.  The enzyme
# coagulase acts with a plasma factor to convert fibrinogen to a fibrin clot. It is used to
# differentiate Staphylococcus  aureus  from other, less pathogenic staphylococci. 5. Decarboxylases
# and deaminases.  The decarboxylation or deamination of the amino acids lysine, ornithine, and
# arginine is detected by the  effect of the amino products on the pH of the reaction mixture or by
# the formation of colored products. These tests are used primarily with  Gram-negative rods. 6.
# Hydrogen sulfide.  The ability of some bacteria to produce H2S from amino acids or other sulfur-
# containing compounds is helpful in taxonomic  classification. The black color of the sulfide salts
# formed with heavy metals such as iron is the usual means of detection. This test is useful in
# distinguishing between the Gram-negative rods.
# 3891
# 0.9020270109176636
# to relatively few groups. An example of a dichotomous key is  shown in Figure 3-1. Numerical
# Taxonomy Using Biochemical  Measures of Activity Numerical taxonomy became widely used in the 1970s.
# These  classification schemes use a number of unweighted, taxo - nomically useful characteristics.
# For these assays, an indi - vidual bacterial colony must be isolated and used to inoculate  the test
# format. One example of this is the Analytical Pro - file Index (API), which uses numerical taxonomy
# to identify  a wide range of medically important microorganisms. APIs  consist of several plastic
# strips, each of which has about 20  miniature compartments containing biochemical reagents  (Figure
# 3-2). Almost all cultivatable bacterial groups and  more than 550 different species can be
# identified using the  results of these API tests. These identification systems have  extensive
# databases of microbial biochemical reactions. The  numerical clusters derived from these tests
# identify different  FIGURE 3-2  API test demonstrating how bacteria can be differentiated using a
# series of biochemical tests. Each small compartment  contains a dehydrated powder that is inoculated
# from a bacterial culture. After incubation, the colorimetric changes can be scored numerically  to
# produce a number that matches to a specific bacterial species and genus. (Courtesy of bioMerieux,
# Inc.) Riedel_CH03_p043-p054.indd   46 05/04/19   4:02 PM
# 1425
# Context:  CHAPTER 3  Classification of Bacteria   45 bacterial cell surface structures such as
# lipopolysaccharide  (LPS), flagella, or capsular antigens. The terms “serotype,”  “serogroups,” and
# “serovars” are, for all practical purposes,  identical—they all use the specificity of these
# antibodies to subdivide strains of a specific bacterial species. In essence,  these reagents are
# “forensic” agents, establishing a fingerprint  that links the source of an organism to a disease
# caused in  an individual. In certain circumstances (eg, an epidemic), it  is important to
# distinguish among strains of a given species  or to identify a specific strain. This is called
# subtyping  and  is accomplished by examining bacterial isolates for charac - teristics that allow
# discrimination below the species level.  Classically, subtyping has been accomplished by biotyping,
# serotyping, antimicrobial susceptibility testing, and bacte - riophage typing. For example, more
# than 130 serogroups of  Vibrio cholerae  have been identified based on antigenic dif - ferences in
# the O-polysaccharide of their LPS; however, only  the O1 and O139 serogroups are associated with
# epidemic and  pandemic cholera. Within these serogroups, only strains that  produce a toxin-
# coregulated pili and cholera toxin are viru - lent and cause the disease cholera. By contrast,
# nontoxigenic  V. cholerae  strains, which are not associated with epidemic  cholera, are generally
# isolated from environmental speci - mens, from food, or from patients with sporadic diarrhea.Gram +
# cocci catalase t est Catalase – streptococciCatalase + staph ylococci Coagulase test – Staphy
# lococcus epiderm idis+ Staphy lococcus aureus FIGURE 3-1  Algorithm for differentiating the Gram-
# positive cocci. TABLE 3-2  Common Microbial Biochemical Tests Used to Differentiate Among Bacteria
# 1. Carbohydrate breakdown.  The ability to produce acidic metabolic products, fermentatively or
# oxidatively, from a range of carbohydrates  (eg, glucose, sucrose, and lactose) has been applied to
# the identification of most groups of bacteria (eg, Escherichia  spp. ferment lactose,  whereas
# Salmonella  spp. do not). Such tests are crude and imperfect in defining mechanisms but have proved
# useful for taxonomic purposes.  More recently, gas chromatographic identification of specific short-
# chain fatty acids produced by fermentation of glucose has proved useful in  classifying many
# anaerobic bacteria. 2. Catalase production.  The enzyme catalase catalyzes the conversion of
# hydrogen peroxide to water and oxygen. When a colony is placed in  hydrogen peroxide, liberation of
# oxygen as gas bubbles can be seen. The test is particularly useful in differentiation of
# staphylococci (positive)  from streptococci (negative), but it also has taxonomic application to
# Gram-negative bacteria. 3. Citrate utilization.  An agar medium that contains sodium citrate as the
# sole carbon source may be used to determine ability to use citrate.  Bacteria such as Klebsiella
# pneumoniae  that grow on this medium are termed citrate-positive. 4. Coagulase.  The enzyme
# coagulase acts with a plasma factor to convert fibrinogen to a fibrin clot. It is used to
# differentiate Staphylococcus  aureus  from other, less pathogenic staphylococci. 5. Decarboxylases
# and deaminases.  The decarboxylation or deamination of the amino acids lysine, ornithine, and
# arginine is detected by the  effect of the amino products on the pH of the reaction mixture or by
# the formation of colored products. These tests are used primarily with  Gram-negative rods. 6.
# Hydrogen sulfide.  The ability of some bacteria to produce H2S from amino acids or other sulfur-
# containing compounds is helpful in taxonomic  classification. The black color of the sulfide salts
# formed with heavy metals such as iron is the usual means of detection. This test is useful in
# distinguishing between the Gram-negative rods.
# to relatively few groups. An example of a dichotomous key is  shown in Figure 3-1. Numerical
# Taxonomy Using Biochemical  Measures of Activity Numerical taxonomy became widely used in the 1970s.
# These  classification schemes use a number of unweighted, taxo - nomically useful characteristics.
# For these assays, an indi - vidual bacterial colony must be isolated and used to inoculate  the test
# format. One example of this is the Analytical Pro - file Index (API), which uses numerical taxonomy
# to identify  a wide range of medically important microorganisms. APIs  consist of several plastic
# strips, each of which has about 20  miniature compartments containing biochemical reagents  (Figure
# 3-2). Almost all cultivatable bacterial groups and  more than 550 different species can be
# identified using the  results of these API tests. These identification systems have  extensive
# databases of microbial biochemical reactions. The  numerical clusters derived from these tests
# identify different  FIGURE 3-2  API test demonstrating how bacteria can be differentiated using a
# series of biochemical tests. Each small compartment  contains a dehydrated powder that is inoculated
# from a bacterial culture. After incubation, the colorimetric changes can be scored numerically  to
# produce a number that matches to a specific bacterial species and genus. (Courtesy of bioMerieux,
# Inc.) Riedel_CH03_p043-p054.indd   46 05/04/19   4:02 PM
#
# Input tokens:  total_tokens: 1562
#
# {
#     "Questions": [
#         {
#             "Question": "In what aspect can the terms "serotype," "serogroups," and "serovars" be used interchangeably?",
#             "Hint": "Take into account the context of bacterial cell surface structures.",
#             "Answer": "All three terms, "serotype," "serogroups," and "serovars," are used to classify strains of a particular bacterial species based on the specificity of antibodies targeting their cell surface antigens.",
#             "Extra": null
#         },
#         {
#             "Question": "Explain what subtyping involves in the context of bacterial identification.",
#             "Hint": "Consider the goal and methods of subtyping.",
#             "Answer": "Subtyping refers to the process of further distinguishing among strains of a given bacterial species or identifying a specific strain. It involves examining bacterial isolates for characteristics that allow discrimination below the species level.",
#             "Extra": null
#         },
#         {
#             "Question": "What is the basis of differentiating staphylococci from streptococci using the catalase test?",
#             "Hint": "Think about the enzyme activity and its role in the test.",
#             "Answer": "The catalase test differentiates staphylococci from streptococci based on their production of the enzyme catalase. Staphylococci are catalase-positive, meaning they can convert hydrogen peroxide to water and oxygen, while streptococci are catalase-negative and lack this ability.",
#             "Extra": null
#         },
#         {
#             "Question": "How is coagulase testing utilized to distinguish Staphylococcus aureus from other staphylococci?",
#             "Hint": "Consider the action of the coagulase enzyme.",
#             "Answer": "Coagulase testing is used to differentiate Staphylococcus aureus from other staphylococci. Coagulase is an enzyme that acts with a plasma factor to convert fibrinogen to a fibrin clot. S. aureus is coagulase-positive, meaning it can produce coagulase and form a clot, while other staphylococci are coagulase-negative.",
#             "Extra": null
#         },
#         {
#             "Question": "What is the significance of hydrogen sulfide production in bacterial classification?",
#             "Hint": "Think about the detection methods and taxonomic applications.",
#             "Answer": "The ability of some bacteria to produce hydrogen sulfide (H2S) from amino acids or sulfur-containing compounds is useful in taxonomic classification. The black color of the sulfide salts formed with heavy metals such as iron is the usual means of detection. This test helps distinguish between different Gram-negative bacterial groups.",
#             "Extra": null
#         },
#         {
#             "Question": "How does numerical taxonomy contribute to bacterial identification using biochemical measures?",
#             "Hint": "Consider the methodology and applications of numerical taxonomy.",
#             "Answer": "Numerical taxonomy uses a number of unweighted, taxonomically useful biochemical characteristics to classify bacteria. Individual bacterial colonies are isolated and inoculated into test formats, such as the Analytical Profile Index (API). The numerical clusters derived from the test results help identify different bacterial species and genera by matching to extensive databases of microbial biochemical reactions.",
#             "Extra": null
#         }
#     ]
# }
#
#
# Output tokens:  total_tokens: 676

# %%
document_ids = [doc["_id"] for doc in knowledge]

# Update the flag value to 1 for the matched documents
if document_ids:
  update_result = book_collection.update_many(
            {"_id": {"$in": document_ids}},
            {"$set": {"flag": 0}}
   )
  print(f"Updated {update_result.modified_count} documents")
# Out:
# Updated 2 documents

# %%
query = {"flag": 1}

    # Update the flag to 0
new_values = {"$set": {"flag": 0}}

    # Perform the update
results = db.Medical_Books_RAG.update_many(query, new_values)
print(f"Updated {results.modified_count} documents")
# Out:
# Updated 2 documents

# %%
import re
import json

def extract_json(text):
    # Regex to match JSON objects
    json_regex = re.compile(r'\{(?:[^{}]*|\{(?:[^{}]*|\{[^{}]*\})*\})*\}')

    # Function to recursively parse JSON objects
    def parse_json(match):
        try:
            json_object = json.loads(match)
            # Check if there are nested JSON objects
            for key, value in json_object.items():
                if isinstance(value, str) and re.match(json_regex, value):
                    json_object[key] = parse_json(value)
            return json_object
        except json.JSONDecodeError:
            return None

    # Find all JSON objects in the text
    json_matches = json_regex.findall(text)

    # Parse the JSON objects
    json_objects = []
    for json_match in json_matches:
        json_object = parse_json(json_match)
        if json_object is not None:
            json_objects.append(json_object)

    return json_objects

# %%
docs = []
question_jsons = []
for question in questions_list:
        question_text = f"[{question}]"
        new_question_jsons = extract_json(question_text)
        question_jsons.append(new_question_jsons)

# %%
for question_json in question_jsons:
  print(question_json)
# Out:
# [{'Questions': [{'Question': 'Can cyanosis be caused by reasons other than hypoxemia?', 'Hint': 'Refer to the first sentence of the context.', 'Answer': 'Yes, cyanosis can also be caused by methemoglobinemia.', 'Extra': None}, {'Question': 'What abnormality or presence might suggest hepatic necrosis?', 'Hint': 'Refer to the second sentence of the context.', 'Answer': 'Icterus may suggest hepatic necrosis.', 'Extra': 'This can be due to acetaminophen or Amanita phalloides mushroom poisoning.'}, {'Question': 'What finding might indicate poisoning with anticholinergic drugs?', 'Hint': 'Refer to the fifth sentence of the context.', 'Answer': 'Ileus is a typical finding in poisoning with anticholinergic drugs.', 'Extra': 'Other drugs that can cause ileus include opioids and sedatives.'}, {'Question': 'What symptoms are common in poisoning with organophosphates?', 'Hint': 'Refer to the fifth sentence of the context.', 'Answer': 'Hyperactive bowel sounds, abdominal cramping, and diarrhea are common symptoms in poisoning with organophosphates.', 'Extra': 'Other drugs that can cause these symptoms include iron, arsenic, theophylline, A. phalloides, and A. muscaria.'}, {'Question': 'What neurologic signs might suggest a structural lesion rather than toxic or metabolic encephalopathy?', 'Hint': 'Refer to the first paragraph of the context.', 'Answer': 'Focal seizures or motor deficits may suggest a structural lesion.', 'Extra': 'Intracranial hemorrhage due to trauma is an example of such a lesion.'}, {'Question': 'What is a typical finding in phenytoin or carbamazepine intoxication?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Nystagmus, dysarthria, and ataxia are typical findings in phenytoin or carbamazepine intoxication.', 'Extra': 'Alcohol and other sedatives can also cause these symptoms.'}, {'Question': 'What is a common neurologic finding in poisoning with atropine or cocaine?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Twitching and muscular hyperactivity are common neurologic findings in poisoning with atropine or cocaine.', 'Extra': 'Other sympathomimetic drugs can also cause these symptoms.'}, {'Question': 'What drugs can cause muscular rigidity?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Muscular rigidity can be caused by haloperidol, other antipsychotic agents, strychnine, or tetanus.', 'Extra': None}, {'Question': 'What is a typical finding in serotonin syndrome?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Generalized hypertonicity of muscles and lower extremity clonus are typical findings in serotonin syndrome.', 'Extra': None}, {'Question': 'What is a common cause of seizures in overdose?', 'Hint': 'Refer to the third paragraph of the context.', 'Answer': 'Seizures are often caused by overdose with antidepressants (especially tricyclic antidepressants and bupropion), cocaine, amphetamines, theophylline, isoniazid, or diphenhydramine.', 'Extra': None}]}]
# []

# %%
db.topic.create_index([("topic", "text")])
# Out:
# 'topic_text'

# %%
from fuzzywuzzy import fuzz
def fuzzy_search_topic(topic_name, threshold=80):
    topics = db.topic.find()
    best_match = None
    highest_score = 0
    for topic in topics:
        score = fuzz.ratio(topic_name.lower(), topic['topic'].lower())
        if score > highest_score and score >= threshold:
            best_match = topic
            highest_score = score
    return best_match

# %%
import json

# Function to convert JSON to a list of documents
def convert_json_to_documents(topic_name, questions):
    documents = []
    for question in question_json:
        if len(questions) > 0:
            for question in questions:
                doc = {
                    'prof': topic_name['prof'],
                    'subject': topic_name['subject'],
                    'card': topic_name['card'],
                    'topic': topic_name['topic'],
                    'subTopic': topic_name['subTopic'],
                    'question': question['Question'],
                    'version': '2',
                    'hint': question['Hint'],
                    'correct_answer': question['Answer'],
                    'extra': question.get('Extra', "No extra info to add")
                }
                documents.append(doc)
    return documents

# %%
for question_json, topic in zip(question_jsons, topic_list):
    try:
        # Check if question_json has elements and process accordingly
        if question_json and isinstance(question_json, list) and 'Questions' in question_json[0]:
            questions = question_json[0]['Questions']
            print(f"Topic_name: {topic['topic']}")
            print(f"Questions: {questions}")

            documents = convert_json_to_documents(topic, questions)
            docs.append(documents)
        else:
            print("Invalid question_json structure or empty list")
            print("---------------------------------------------------------------------------------")
    except json.JSONDecodeError:
        print(f"Invalid JSON: {question_json}")
        print("---------------------------------------------------------------------------------")
    except (KeyError, TypeError, IndexError) as e:
        print(f"Error processing question: {question_json}")
        print(f"Exception: {e}")
        print("---------------------------------------------------------------------------------")
# Out:
# Topic_name: Autopsy
# Questions: [{'Question': 'Can cyanosis be caused by reasons other than hypoxemia?', 'Hint': 'Refer to the first sentence of the context.', 'Answer': 'Yes, cyanosis can also be caused by methemoglobinemia.', 'Extra': None}, {'Question': 'What abnormality or presence might suggest hepatic necrosis?', 'Hint': 'Refer to the second sentence of the context.', 'Answer': 'Icterus may suggest hepatic necrosis.', 'Extra': 'This can be due to acetaminophen or Amanita phalloides mushroom poisoning.'}, {'Question': 'What finding might indicate poisoning with anticholinergic drugs?', 'Hint': 'Refer to the fifth sentence of the context.', 'Answer': 'Ileus is a typical finding in poisoning with anticholinergic drugs.', 'Extra': 'Other drugs that can cause ileus include opioids and sedatives.'}, {'Question': 'What symptoms are common in poisoning with organophosphates?', 'Hint': 'Refer to the fifth sentence of the context.', 'Answer': 'Hyperactive bowel sounds, abdominal cramping, and diarrhea are common symptoms in poisoning with organophosphates.', 'Extra': 'Other drugs that can cause these symptoms include iron, arsenic, theophylline, A. phalloides, and A. muscaria.'}, {'Question': 'What neurologic signs might suggest a structural lesion rather than toxic or metabolic encephalopathy?', 'Hint': 'Refer to the first paragraph of the context.', 'Answer': 'Focal seizures or motor deficits may suggest a structural lesion.', 'Extra': 'Intracranial hemorrhage due to trauma is an example of such a lesion.'}, {'Question': 'What is a typical finding in phenytoin or carbamazepine intoxication?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Nystagmus, dysarthria, and ataxia are typical findings in phenytoin or carbamazepine intoxication.', 'Extra': 'Alcohol and other sedatives can also cause these symptoms.'}, {'Question': 'What is a common neurologic finding in poisoning with atropine or cocaine?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Twitching and muscular hyperactivity are common neurologic findings in poisoning with atropine or cocaine.', 'Extra': 'Other sympathomimetic drugs can also cause these symptoms.'}, {'Question': 'What drugs can cause muscular rigidity?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Muscular rigidity can be caused by haloperidol, other antipsychotic agents, strychnine, or tetanus.', 'Extra': None}, {'Question': 'What is a typical finding in serotonin syndrome?', 'Hint': 'Refer to the second paragraph of the context.', 'Answer': 'Generalized hypertonicity of muscles and lower extremity clonus are typical findings in serotonin syndrome.', 'Extra': None}, {'Question': 'What is a common cause of seizures in overdose?', 'Hint': 'Refer to the third paragraph of the context.', 'Answer': 'Seizures are often caused by overdose with antidepressants (especially tricyclic antidepressants and bupropion), cocaine, amphetamines, theophylline, isoniazid, or diphenhydramine.', 'Extra': None}]
# Invalid question_json structure or empty list
# ---------------------------------------------------------------------------------

# %%
for doc in docs:
  if(len(doc)> 0):
    results = db.viva_question_collection.insert_many(doc)
    print(f"Inserted {len(results.inserted_ids)} documents")
# Out:
# Inserted 10 documents
# Inserted 10 documents

# %%
print(len(docs))
# Out:
# 2

# %%
updated_results = db.viva_question_collection.update_many({'topic':'isaster & accident'},{'$set':{'topic':'Disaster & accident'}})
print(f"Updated {updated_results.modified_count} documents")
# Out:
# Updated 0 documents

# %%
import re
topic_info = list(db.topic.find({"topic": re.compile(r"\s*Body fluids & semen analysis\s*")}))
topic_info
# Out:
# [{'_id': ObjectId('66b71568cd747a509166a324'),
#   'prof': 'Third',
#   'subject': 'Pathology',
#   'card': 'Clinical Pathology',
#   'topic': ' Body fluids & semen analysis',
#   'subTopic': ' Body fluids & semen analysis'}]

# %%
topic_name = topic_info[0]
topic_name
# Out:
# {'_id': ObjectId('66b71568cd747a509166a324'),
#  'prof': 'Third',
#  'subject': 'Pathology',
#  'card': 'Clinical Pathology',
#  'topic': ' Body fluids & semen analysis',
#  'subTopic': ' Body fluids & semen analysis'}

# %%
db.viva_question_collection.insert_many(documents)

# %%
collection = db['viva_question_collection']

# Fields to extract
fields = ['subject', 'topic', 'question', 'hint', 'correct_answer']

# Query to get all documents
documents = collection.find({"subject":"Community Medicine"}, {field: 1 for field in fields})

# Convert documents to DataFrame
df = pd.DataFrame(list(documents), columns=fields)

# %%
csv_file_path = 'community_medicine_questions.csv'

# Write DataFrame to CSV file
df.to_csv(csv_file_path, index=False)

print(f"CSV file '{csv_file_path}' has been created.")
# Out:
# CSV file 'community_medicine_questions.csv' has been created.

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer

pdf_file_path = 'viva_questions.pdf'
doc = SimpleDocTemplate(pdf_file_path, pagesize=letter)
styles = getSampleStyleSheet()
story = []

# Add content to the PDF
for index, row in df.iterrows():
    story.append(Paragraph(f"Subject: {row['subject']}", styles['Heading2']))
    story.append(Paragraph(f"Topic: {row['topic']}", styles['Heading3']))
    story.append(Spacer(1, 12))
    story.append(Paragraph(f"Question: {row['question']}", styles['BodyText']))
    story.append(Spacer(1, 12))
    story.append(Paragraph(f"Hint: {row['hint']}", styles['BodyText']))
    story.append(Spacer(1, 12))
    story.append(Paragraph(f"Answer: {row['correct_answer']}", styles['BodyText']))
    story.append(Spacer(1, 24))

# Build the PDF
doc.build(story)

print(f"PDF file '{pdf_file_path}' has been created.")
# Out:
# PDF file 'viva_questions.pdf' has been created.

# %% [markdown]
# ##Run OpenAI

# %%
topic_list = db.topic.find()
topic_list = list(topic_list)

# %%
len(topic_list)
# Out:
# 486

# %%
topic_list[:2]
# Out:
# [{'_id': ObjectId('668e1dae34c6b43f3955e40d'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Sternum with joints',
#   'subtopic': 'Sternum with joints'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e40e'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Typical rib with joints',
#   'subtopic': 'Typical rib with joints'}]

# %%
query = "Head"
knowledge = get_knowledge(query, book_collection)
context = get_search_result(knowledge)
prompt = get_prompt_QUESTION(query=query, context=context, nQuestion=10)
prompt
# Out:
# [0.003369350917637348, -0.009024985134601593, -0.005425000563263893, -0.027685411274433136, -0.002223437884822488, -0.003325390163809061, 0.00783743616193533, 0.00933422613888979, 0.039363179355859756, 0.00585462711751461, 0.029920395463705063, -0.03179478272795677, 0.027497753500938416, -0.01880066841840744, -0.012361550703644753, 0.02306537516415119, -0.037682950496673584, -0.025275902822613716, -0.010663425549864769, -0.004175587557256222, 0.020106693729758263, 0.00731809064745903, -0.06821944564580917, -0.01675819419324398, -0.020977161824703217, 0.02612103894352913, 0.025822820141911507, -0.010245281271636486, 0.07745673507452011, 0.059794917702674866, -0.03603480011224747, -0.021086491644382477, 0.030742177739739418, -0.0776183232665062, 0.004147338680922985, -0.033967189490795135, 0.03215474262833595, -0.054670535027980804, -0.027509571984410286, -0.044833336025476456, 0.028977414593100548, -0.002864697016775608, -0.006569428835064173, -0.03604865446686745, -0.016304001212120056, -0.010752935893833637, -0.03085908479988575, -0.03400072082877159, 0.005855723284184933, -0.03442849963903427, 0.011671103537082672, -0.017714135348796844, 0.016263704746961594, 0.0072667403146624565, 0.01646820455789566, -0.0019363330211490393, 0.046975623816251755, 0.005103890784084797, -0.016643591225147247, 0.05364153906702995, 0.05003739148378372, 0.005474664270877838, 0.013357982039451599, -0.05145803093910217, 0.012628416530787945, 0.05126292258501053, 0.01532436441630125, -0.03288367763161659, 0.022607507184147835, -0.020261872559785843, -0.038425642997026443, -0.005247801076620817, -0.0358794704079628, -0.009472828358411789, 0.018250208348035812, -0.027295932173728943, 0.012071458622813225, 0.006846813019365072, 0.00733436131849885, 0.0011763583170250058, 0.009326218627393246, 0.06034814193844795, 0.005040791817009449, 0.018745344132184982, -0.04385168477892876, -0.008138529025018215, -0.026001695543527603, 0.04930192604660988, -0.000995768466964364, -0.005095630418509245, 0.005915953312069178, 0.04316635802388191, -0.0007166012655943632, -0.007323247380554676, 0.04111839830875397, 0.046900879591703415, -0.04307253286242485, 0.051635291427373886, -0.026389682665467262, -0.025553230196237564, 0.03513360768556595, 0.05152321606874466, -0.00899843592196703, 0.04641740769147873, -0.034256160259246826, -0.025560589507222176, -0.002748565049842, 0.029400909319519997, 0.007139967754483223, -0.04152367264032364, 0.013910863548517227, -0.02505052462220192, 0.028466476127505302, -0.0004870294942520559, 0.003213126678019762, 0.059041913598775864, -0.008616256527602673, 0.02019176073372364, -0.03641907498240471, -0.023595746606588364, 0.029637696221470833, 0.009162887930870056, 0.05837090313434601, -0.008801604621112347, 0.010233020409941673, -0.004638610407710075, -0.02559240348637104, 0.06624200940132141, -0.03415059670805931, 0.00642374437302351, 0.0003042707103304565, -0.049089215695858, -0.009461265988647938, -0.013160319067537785, 0.004127920139580965, 0.03981902077794075, -0.01321253553032875, -0.005356169305741787, 0.007656848058104515, -0.060166019946336746, 0.030299635604023933, 0.0412847138941288, -0.0014091728953644633, 0.0902109295129776, -0.0018112552352249622, 0.048847321420907974, -0.011334588751196861, 0.014415424317121506, -0.018632223829627037, 0.009631018154323101, -0.013689333572983742, 0.029665056616067886, -0.004715126007795334, -0.004432864487171173, -0.001823047292418778, 0.00023565362789668143, -0.02027292177081108, 0.020034486427903175, 0.02134675346314907, 0.03174940496683121, -0.033594101667404175, 0.009074040688574314, -0.00280275521799922, 0.0543275848031044, 0.0024447585456073284, 0.04225220903754234, -0.01816166751086712, -0.03588727116584778, -0.022292256355285645, -0.043020185083150864, 0.048130638897418976, 0.008758213371038437, 0.018830224871635437, 0.02175811491906643, 0.014482103288173676, 0.03190149366855621, 0.03457967936992645, 0.009527210146188736, 0.023425133898854256, 0.03794625774025917, -0.00704323640 ...
# 'You are assisting a medical student in preparing for an exam. Here is your TASK:\nYou should generate VIVA questions for medical students based on the given context. You will also generate HINT, ANSWER and ADDITIONAL INFORMATION for each question. HINT or clue will be used to help student answering the question and the ANSWER will be used to evaluate the student\'s response. ADDITIONAL INFORMATION will be related to the TOPIC based on given CONTEXT to provide extra knowledge. Here are the KEY POINTS you must consider:\n1. Do not ask questions if the context is irrelevant.\n2. Focus on questions that can be answered within 100 words or around 5 lines.\n3. Generate questions in full sentences. You should generate only viva-standard questions.\n4. HINT should be small and precise, and it should not directly contain the answer.\n5. Generate a helpful hint without directly answering the question.\n6. The ANSWER to VIVA questions should be based on the given CONTEXT.\n7. ADDITIONAL INFORMATION should be related to the TOPIC based on the given CONTEXT.\n8. Add a difficulty score of the questions between 1 to 10, where 1 is the easiest and 10 is the hardest.\n9. Generate questions from all difficulty levels between 1 to 10.\n10. Return your response in the following JSON format:\n[\n  {\n    "question": "/* one question */",\n    "hint": "/* hint */",\n    "answer": "/* answer */",\n    "extra": "/* additional information */",\n    "difficulty_score": "/* difficulty score */"\n  },\n  ... /* 10 number of questions */\n]\nHere is the topic, number of questions, and context: TOPIC: \'Head\' NUMBER OF QUESTIONS: \'10\' CONTEXT: \'\' QUESTION:'

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OpenAIKey')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
import os
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Tell me This is something",
        }
    ],
    model="gpt-3.5-turbo",
)

# %%
chat_completion
# Out:
# ChatCompletion(id='chatcmpl-A9pJjGxvzlGxudi4BLV9iVJLF39SD', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is something.', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726905579, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=4, prompt_tokens=12, total_tokens=16, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))

# %%
import json

# Function to convert JSON to a list of documents
def convert_json_to_documents(topic_name, questions):
    documents = []
    for question in question_json:
        if len(questions) > 0:
            for question in questions:
                doc = {
                    'prof': topic_name['prof'],
                    'subject': topic_name['subject'],
                    'card': topic_name['card'],
                    'topic': topic_name['topic'],
                    'subTopic': topic_name['subTopic'],
                    'question': question['Question'],
                    'version': '2',
                    'hint': question['Hint'],
                    'correct_answer': question['Answer'],
                    'extra': question.get('Extra', "No extra info to add")
                }
                documents.append(doc)
    return documents

# %%
import re
import json

def extract_json(text):
    # Regex to match JSON objects
    json_regex = re.compile(r'\{(?:[^{}]*|\{(?:[^{}]*|\{[^{}]*\})*\})*\}')

    # Function to recursively parse JSON objects
    def parse_json(match):
        try:
            json_object = json.loads(match)
            # Check if there are nested JSON objects
            for key, value in json_object.items():
                if isinstance(value, str) and re.match(json_regex, value):
                    json_object[key] = parse_json(value)
            return json_object
        except json.JSONDecodeError:
            return None

    # Find all JSON objects in the text
    json_matches = json_regex.findall(text)

    # Parse the JSON objects
    json_objects = []
    for json_match in json_matches:
        json_object = parse_json(json_match)
        if json_object is not None:
            json_objects.append(json_object)

    return json_objects

# %%
import time
import json

questions_list = []
input_token_count = 0
output_token_count = 0
for topic in topic_list[:10]:
    query = topic['topic']

    try:
        flag = False
        #for topic in question_topics:
         #   if topic == query:
          #      flag = True
        # Get the context and prompt
        if flag == False:
          knowledge = get_knowledge(query, book_collection)
          context = get_search_result(knowledge)
          prompt = get_prompt_QUESTION(query=query, context=context, nQuestion=10)
          chat_completion = client.chat.completions.create(
          messages=[
               {
                "role": "user",
                "content": prompt,
              }
           ],
            model="gpt-3.5-turbo",
           )
          input_token_count += chat_completion.usage.prompt_tokens
          output_token_count += chat_completion.usage.completion_tokens
          question = chat_completion.choices[0].message.content
          questions_list.append(question)
    except ValueError as e:
        print(f"Error generating content for topic '{topic}': {e}")
        continue

    # Add a 10-second wait time
    time.sleep(20)
# Out:
# [0.004073788411915302, -0.019049635156989098, 0.014215992763638496, 0.00017457600915804505, -0.014145315624773502, -0.027361780405044556, -0.001665780320763588, 0.04319839924573898, 0.024860722944140434, 0.03284634277224541, 0.030367812141776085, -0.016597285866737366, 0.014360697008669376, -0.026750659570097923, 0.007294148206710815, 0.01958860643208027, -0.013604486361145973, -0.028514718636870384, -0.026641955599188805, 0.0017972005298361182, -0.015341256745159626, -0.009907563216984272, -0.0851631909608841, -0.013619424775242805, 0.006792734377086163, 0.04157160967588425, 0.028039470314979553, 0.0029779979959130287, 0.06975404918193817, 0.061755694448947906, -0.04082841798663139, -0.027097102254629135, 0.03949875012040138, -0.058857183903455734, -0.025343017652630806, -0.023524267598986626, 0.021531857550144196, -0.03264087066054344, -0.0031531257554888725, -0.06541623175144196, 0.02376406639814377, -0.030685050413012505, 0.01226954534649849, -0.016362251713871956, -0.02290383167564869, -0.01718054711818695, -0.026710668578743935, -0.028914304450154305, -0.0054126582108438015, -0.03237196430563927, 0.04077465087175369, -0.024812228977680206, 0.022136185318231583, -0.005386228673160076, -0.008702881634235382, 0.02489537000656128, 0.0013015031581744552, -0.002923842053860426, -0.009817446582019329, 0.010219298303127289, 0.03181096538901329, -0.0312676839530468, 0.006755299866199493, -0.06826998293399811, 0.02895396575331688, 0.02210121974349022, -0.0017188461497426033, 0.004374530166387558, 0.008541245013475418, 0.015665628015995026, 0.006461779121309519, 0.004014904145151377, 0.007164322771131992, -0.046538420021533966, -0.012464571744203568, -0.007893060334026814, -0.01524621993303299, 0.009968479163944721, -0.013266284018754959, -0.027696359902620316, 0.03479555621743202, 0.07543888688087463, 0.014508110471069813, 0.02583940327167511, -0.05787978321313858, -0.002694780472666025, 0.0026698189321905375, 0.041854437440633774, 0.003925798460841179, -0.020055223256349564, 0.01936090551316738, 0.05743806064128876, 0.012554708868265152, -0.00839686393737793, 0.04344030097126961, 0.02657587267458439, -0.04139183461666107, 0.055668845772743225, -0.0035437261685729027, 0.02779560163617134, 0.021519839763641357, 0.035087503492832184, -0.02718842588365078, 0.0261706430464983, -0.01850186660885811, -0.011599812656641006, 0.0048142061568796635, -0.008703844621777534, 0.024178538471460342, -0.03304162621498108, 0.012534549459815025, -0.030771849676966667, 0.008653216063976288, 0.022643987089395523, 0.018383203074336052, 0.03035200573503971, -0.00759013369679451, 0.040276382118463516, -0.022336361929774284, 0.05068106949329376, 0.010543950833380222, 0.0072470069862902164, 0.0324394553899765, -0.003776807803660631, 0.020819570869207382, 0.0029595610685646534, -0.02138812281191349, 0.04834073409438133, -0.010296772234141827, -0.012629619799554348, 0.010387198999524117, -0.02894013375043869, -0.015967367216944695, 0.036597542464733124, -0.01424395851790905, 0.0022611739113926888, -0.01472538337111473, 0.03148449584841728, 0.006601844914257526, -0.0572081059217453, 0.03371584415435791, 0.0361914336681366, 0.024359451606869698, 0.07882858067750931, 0.011228423565626144, 0.02399437129497528, 0.012798046693205833, -0.02474779635667801, -0.043257441371679306, -0.00445847911760211, -0.04951203987002373, 0.02876208908855915, -0.00821133516728878, 0.004274190869182348, -0.002421805402263999, 0.02539224363863468, -0.03290696069598198, 0.027920670807361603, 0.001541816396638751, 0.04389917850494385, -0.007003248203545809, -0.014886933378875256, 0.01923752762377262, 0.04307185858488083, -0.0006552597042173147, 0.035195641219615936, -0.03397812321782112, -0.011901244521141052, -0.004829774610698223, -0.040363702923059464, 0.003455683821812272, 0.02623101882636547, 0.0009391680359840393, -0.00870358943939209, 0.016056949272751808, 0.0681929886341095, 0.029818089678883553, 0.009979537688195705, 0.02440311759710312, 0.04319293424487114, -0.006530905142426 ...
# Updated 2 documents
# 0.93300461769104
# 26Hip JointCHAPTER The hip joint is a ball and socket type of synovial joint  between the head of
# the femur and the acetabulum of the hip  bone (Fig. 26.1). It is the largest ball and socket type of
# joint  in the body. Its main functions are: (a) to support the body  weight during standing and (b)
# to transmit the forces  generated by movements of trunk femur during walking. It  is multiaxial and
# permits same movements as shoulder joint  in the upper limb because the long and narrow neck of
# femur  acts as strut and makes an angle with the shaft (neck–shaft  angle). However, its range of
# movements is restricted due to  its role in weight bearing. TYPE Synovial joint of ball and socket
# varietyARTICULAR SURFACES The head of the femur articulates with the horse-shoe- shaped acetabulum
# of the hip bone to form the hip joint.  (Fig. 26.2): 1. The head of femur  forms more than half of a
# sphere. It  is covered by the articular hyaline cartilage except for a  small pit—the fovea capitis
# for ligamentum teres. 2. The acetabulum (Latin acetabulum /H11005 vinegar cup)  presents three
# features: a horseshoe-shaped lunate  surface, acetabular notch, and acetabular fossa. Out of  these,
# only lunate surface is articular and covered by an  articular cartilage. The depth of the acetabulum
# is  increased by the acetabular labrum. Fig. 26.1 Hip joint: A, line diagram of the right hip joint;
# B, radiograph of the right hip joint.Acetabulum of hip boneHead of femur A B Hip bone FemurHip bone
# Acetabulum of hip bone Head of femur Femur
# 1532
# 0.93300461769104
# 26Hip JointCHAPTER The hip joint is a ball and socket type of synovial joint  between the head of
# the femur and the acetabulum of the hip  bone (Fig. 26.1). It is the largest ball and socket type of
# joint  in the body. Its main functions are: (a) to support the body  weight during standing and (b)
# to transmit the forces  generated by movements of trunk femur during walking. It  is multiaxial and
# permits same movements as shoulder joint  in the upper limb because the long and narrow neck of
# femur  acts as strut and makes an angle with the shaft (neck–shaft  angle). However, its range of
# movements is restricted due to  its role in weight bearing. TYPE Synovial joint of ball and socket
# varietyARTICULAR SURFACES The head of the femur articulates with the horse-shoe- shaped acetabulum
# of the hip bone to form the hip joint.  (Fig. 26.2): 1. The head of femur  forms more than half of a
# sphere. It  is covered by the articular hyaline cartilage except for a  small pit—the fovea capitis
# for ligamentum teres. 2. The acetabulum (Latin acetabulum /H11005 vinegar cup)  presents three
# features: a horseshoe-shaped lunate  surface, acetabular notch, and acetabular fossa. Out of  these,
# only lunate surface is articular and covered by an  articular cartilage. The depth of the acetabulum
# is  increased by the acetabular labrum. Fig. 26.1 Hip joint: A, line diagram of the right hip joint;
# B, radiograph of the right hip joint.Acetabulum of hip boneHead of femur A B Hip bone FemurHip bone
# Acetabulum of hip bone Head of femur Femur
# 1532
# [-0.009688062593340874, -0.012641157023608685, 0.004435415845364332, -0.02106550708413124, -0.009083986282348633, -0.01827343925833702, 0.0038455661851912737, 0.03042304888367653, 0.025135140866041183, 0.04143749549984932, 0.042178843170404434, -0.019338788464665413, -0.0068552992306649685, -0.02506669983267784, -0.006219604983925819, 0.020655199885368347, -0.03410949185490608, -0.03390191122889519, -0.021170400083065033, -0.01806747168302536, 0.005306547041982412, -0.009685113094747066, -0.0983039140701294, -0.011570040136575699, -0.013554712757468224, 0.050728850066661835, 0.054895155131816864, 0.010446074418723583, 0.07423462718725204, 0.061452221125364304, -0.05364687740802765, -0.017993692308664322, 0.031624145805835724, -0.053139835596084595, -0.034342169761657715, -0.028308307752013206, 0.03291755169630051, -0.014543804340064526, -0.02836701087653637, -0.04272205010056496, 0.020966242998838425, -0.01287145260721445, 0.009399926289916039, -0.030657151713967323, -0.0190594419836998, -0.0028084763325750828, -0.02498309314250946, -0.035497210919857025, 0.018632903695106506, -0.04359860345721245, 0.03567223250865936, -0.01687033660709858, 0.0014610684011131525, -0.025230765342712402, -0.013032026588916779, 0.019938407465815544, -0.00694041745737195, -0.005849271081387997, -0.022581255063414574, 0.016126316040754318, 0.026874253526329994, -0.021874235942959785, 0.0030546411871910095, -0.06874768435955048, 0.015083590522408485, 0.0032026662956923246, -0.0027178053278476, 0.020305287092924118, 0.02550450712442398, -0.02924608811736107, -0.0015983222983777523, 0.02957088127732277, -0.016764365136623383, -0.041780684143304825, -0.0077217696234583855, 0.008336672559380531, 0.008895688690245152, 0.018395865336060524, -0.02765994518995285, -0.016277721151709557, 0.02613040618598461, 0.06601932644844055, 0.01523924432694912, 0.03307552635669708, -0.06661596149206161, 0.0028619973454624414, -0.025538956746459007, 0.03175650164484978, 0.0004961621598340571, -0.022494057193398476, 0.006064210552722216, 0.05019627884030342, 0.014086548238992691, -0.017048900946974754, 0.048688631504774094, 0.025980623438954353, -0.030344709753990173, 0.062451936304569244, -0.00586684700101614, 0.010999616235494614, 0.03676806390285492, 0.03322022035717964, -0.020068679004907608, 0.0353543646633625, -0.034940846264362335, -0.02257371135056019, -0.003115098923444748, -0.005199375096708536, -0.012051766738295555, -0.04658324643969536, -0.0184169914573431, -0.047145452350378036, 0.00802794098854065, 0.03543636575341225, 0.030096448957920074, 0.02243812195956707, 0.002372805029153824, 0.045734748244285583, -0.02191929519176483, 0.03838711604475975, 0.004540286958217621, 0.015194082632660866, 0.03301563486456871, -0.014684144407510757, 0.020978936925530434, 0.007753507699817419, -0.028956014662981033, 0.06456922739744186, -0.025182222947478294, -0.014725317247211933, 0.015893273055553436, -0.04045649617910385, -0.024724991992115974, 0.031683385372161865, -0.011497985571622849, 0.013261633925139904, -0.027236374095082283, 0.061608072370290756, 0.011425919830799103, -0.04790855199098587, 0.0439700148999691, 0.027582794427871704, -0.004022338893264532, 0.08700129389762878, 0.011292831040918827, 0.034925736486911774, 0.014884383417665958, -0.028915278613567352, -0.022329911589622498, -0.002049685688689351, -0.048056311905384064, 0.014890026301145554, -0.016852525994181633, 0.018359515815973282, -0.008093376643955708, 0.02240927889943123, -0.02201761305332184, 0.02254144288599491, 0.0177414882928133, 0.04564225301146507, -0.006304170936346054, -0.024661220610141754, 0.002976351883262396, 0.04786551743745804, -0.0337897390127182, 0.03943147882819176, -0.0449998639523983, -0.027668269351124763, -0.011695954017341137, -0.04878184199333191, 0.018460137769579887, 0.003534565446898341, 0.011802325025200844, -0.012349973432719707, 0.006007099989801645, 0.0642557367682457, 0.030653996393084526, 0.009078753180801868, 0.04326047748327255, 0.05051843076944351, 0.0120041798800 ...
# Updated 2 documents
# 0.9321764707565308
# 2Osteology of  the AbdomenCHAPTER The osteology of abdomen deals with the bones of the  abdomen and
# pelvis. The bones of the abdomen and pelvis are as follows  (Fig. 2.1): 1. Lower ribs and costal
# cartilages. 2. Lumbar vertebrae. 3. Sacrum. 4. Coccyx. 5. Hip or innominate bone. LOWER RIBS AND
# COSTAL CARTILAGES The ribs and costal cartilages are described in detail in Textbook of Anatomy:
# Upper Limb and Thorax, 2nd Edition by  Vishram Singh. The costal cartilages of 7th, 8th, 9th, and
# 10th ribs articulate with each other to form the costal margin. The  11th and 12th ribs are shorter
# and do not articulate either  with the transverse processes of 11th and 12th thoracic  vertebrae or
# with the adjacent costal cartilages. As a result  they can move independently, hence are termed
# floating ribs. LUMBAR VERTEBRAE The lumbar vertebrae consist of the same elements as the  thoracic
# vertebrae but are more massive in keeping with the  greater load, which they have to transmit. There
# are five  lumbar vertebrae out of which first four (L1 to L4) are typical  and fifth (L5) is
# atypical. Identifying features of the lumbar vertebrae are as follows: 1. Massive reniform bodies.
# 2. Absence of costal facets on the body. 3. Absence of foramina transversaria in the transverse
# processes. 4. Presence of accessory and mammillary processes. 5. Thick quadrilateral spinous
# processes. FEATURES OF TYPICAL LUMBAR VERTEBRAE  (L1, L2, L3, L4) General Features (Fig. 2.2) Body
# 1. The body is massive and reniform. 2. Its transverse diameter is more than the anteroposterior
# diameter. 3. It is constricted in front and at the sides. 4. The size of the body increases
# progressively from first to  fifth lumbar vertebra. 5. The length of the body is slightly greater
# anteriorly. This  contributes to the forward convexity of the lumbar  vertebral column. 6. The body
# has no costal facets on its sides. Xiphoid process Costal marginsLower ribs and costal cartilages
# Iliac crestLumbar vertebrae Sacrum Coccyx Pubic symphysisTubercle of iliac crest Anterior superior
# iliac spine Inguinal ligament Pectineal line7 8 9 10 L5L4L3L2L1 Hip bone Fig. 2.1 Bones of the
# abdomen and pelvis.
# 2163
# 0.9321764707565308
# 2Osteology of  the AbdomenCHAPTER The osteology of abdomen deals with the bones of the  abdomen and
# pelvis. The bones of the abdomen and pelvis are as follows  (Fig. 2.1): 1. Lower ribs and costal
# cartilages. 2. Lumbar vertebrae. 3. Sacrum. 4. Coccyx. 5. Hip or innominate bone. LOWER RIBS AND
# COSTAL CARTILAGES The ribs and costal cartilages are described in detail in Textbook of Anatomy:
# Upper Limb and Thorax, 2nd Edition by  Vishram Singh. The costal cartilages of 7th, 8th, 9th, and
# 10th ribs articulate with each other to form the costal margin. The  11th and 12th ribs are shorter
# and do not articulate either  with the transverse processes of 11th and 12th thoracic  vertebrae or
# with the adjacent costal cartilages. As a result  they can move independently, hence are termed
# floating ribs. LUMBAR VERTEBRAE The lumbar vertebrae consist of the same elements as the  thoracic
# vertebrae but are more massive in keeping with the  greater load, which they have to transmit. There
# are five  lumbar vertebrae out of which first four (L1 to L4) are typical  and fifth (L5) is
# atypical. Identifying features of the lumbar vertebrae are as follows: 1. Massive reniform bodies.
# 2. Absence of costal facets on the body. 3. Absence of foramina transversaria in the transverse
# processes. 4. Presence of accessory and mammillary processes. 5. Thick quadrilateral spinous
# processes. FEATURES OF TYPICAL LUMBAR VERTEBRAE  (L1, L2, L3, L4) General Features (Fig. 2.2) Body
# 1. The body is massive and reniform. 2. Its transverse diameter is more than the anteroposterior
# diameter. 3. It is constricted in front and at the sides. 4. The size of the body increases
# progressively from first to  fifth lumbar vertebra. 5. The length of the body is slightly greater
# anteriorly. This  contributes to the forward convexity of the lumbar  vertebral column. 6. The body
# has no costal facets on its sides. Xiphoid process Costal marginsLower ribs and costal cartilages
# Iliac crestLumbar vertebrae Sacrum Coccyx Pubic symphysisTubercle of iliac crest Anterior superior
# iliac spine Inguinal ligament Pectineal line7 8 9 10 L5L4L3L2L1 Hip bone Fig. 2.1 Bones of the
# abdomen and pelvis.
# 2163
# [0.010828325524926186, -0.002016096841543913, 0.027184199541807175, -0.010312029160559177, -0.027042347937822342, -0.005842954386025667, -0.013801381923258305, 0.0289537962526083, 0.01321620587259531, 0.04586394503712654, 0.03185168653726578, -0.009478191845119, -0.000384790007956326, -0.051111020147800446, -0.02017519250512123, -0.0016260852571576834, -0.025794507935643196, -0.05101105943322182, -0.03593882545828819, 0.0011196460109204054, 0.0016889522084966302, -0.004530355799943209, -0.08745449781417847, -0.010985961183905602, -0.035724952816963196, 0.034885283559560776, 0.03862675651907921, -0.007330731488764286, 0.06599313765764236, 0.07441453635692596, -0.03783928602933884, -0.01108301617205143, 0.043576717376708984, -0.04642832651734352, -0.03989386186003685, -0.0029868304263800383, 0.03203452005982399, -0.012535739690065384, -0.033315204083919525, -0.051188837736845016, 0.02121238224208355, 0.003327249316498637, -0.00015756116772536188, -0.03031971864402294, -0.015334333293139935, -0.0311902966350317, -0.044028639793395996, -0.009944791905581951, -0.004552692174911499, -0.04435383528470993, 0.012562325224280357, -0.023254383355379105, 0.024456795305013657, -0.03084588050842285, 0.0002804112446028739, 0.03290729969739914, 0.009202500805258751, -0.02729387953877449, -0.013534462079405785, 0.007204119116067886, 0.019813669845461845, -0.008160519413650036, 0.011530185118317604, -0.05284162238240242, 0.014189843088388443, -0.005300553049892187, 0.008323020301759243, 0.020090701058506966, 0.0251226294785738, -0.021738631650805473, -0.004252464510500431, 0.033690813928842545, -0.011876718141138554, -0.04451840743422508, -0.02176917903125286, 0.014560363255441189, -0.0156291201710701, 0.011242575943470001, -0.01645006239414215, 0.011821193620562553, 0.0241822712123394, 0.06505030393600464, 0.024069830775260925, 0.02493305504322052, -0.05325836315751076, 0.017116622999310493, -0.024727774783968925, 0.026056449860334396, -0.0037898847367614508, 0.014102412387728691, 0.008358561433851719, 0.04138318449258804, 0.012155002914369106, -0.010064149275422096, 0.048290666192770004, 0.045660410076379776, -0.036076389253139496, 0.04153341054916382, 0.022114591673016548, -0.022959770634770393, 0.04658481851220131, 0.029000600799918175, 0.0023032608442008495, 0.03008836880326271, -0.05214516818523407, -0.009725000709295273, -0.019602805376052856, -0.003737170249223709, -0.011179057881236076, -0.014787675812840462, 0.0004275470564607531, -0.036607857793569565, 0.03300810605287552, 0.024532999843358994, -0.01100348960608244, 0.04121655598282814, 0.016360055655241013, 0.019251573830842972, -0.048032376915216446, 0.030812175944447517, 0.012455512769520283, 0.016085777431726456, 0.02471320331096649, -0.019459091126918793, 0.024598637595772743, -0.003166527021676302, -0.022991864010691643, 0.047058261930942535, -0.03642391785979271, -0.026085209101438522, -0.013534755446016788, -0.023303061723709106, -0.006292416714131832, 0.030306460335850716, 0.0029113830532878637, 0.007208060007542372, -0.04167981818318367, 0.05656753480434418, 0.002228234428912401, -0.05035283789038658, 0.0415399931371212, 0.030685093253850937, -0.003357411129400134, 0.08523229509592056, 0.017506087198853493, 0.05771760269999504, 0.03244224190711975, -0.032614123076200485, -0.02226078510284424, 0.009746091440320015, -0.04945345222949982, 0.03486495092511177, -0.015062112361192703, 0.01921636238694191, -0.016703780740499496, 0.03174961358308792, -0.041492901742458344, -0.00306417397223413, -0.0026643823366612196, 0.03774155676364899, 0.0019426329527050257, -0.01493937335908413, 0.029123691841959953, 0.0521424300968647, -0.024952620267868042, 0.05276220291852951, -0.030094031244516373, -0.00494298106059432, 0.008606224320828915, -0.05476585030555725, 0.02148282714188099, 0.001116271479986608, 0.007230088114738464, 0.01651865616440773, -0.0033396624494343996, 0.05974197015166283, 0.018942661583423615, -0.002241260837763548, 0.04076209291815758, 0.03249754011631012, -0.0027115936 ...
# [0.012789808213710785, -0.00858243927359581, 0.0033223978243768215, -0.0029433388262987137, 0.004640396684408188, -0.026068544015288353, -0.0158902108669281, 0.02993667684495449, 0.021503321826457977, 0.045786865055561066, 0.014194550924003124, -0.007937191985547543, -0.0025428568478673697, -0.014101343229413033, -0.00015227857511490583, 0.018771497532725334, -0.024934882298111916, -0.0015191242564469576, -0.011530812829732895, 0.016860481351614, -0.0023940394166857004, -0.0017286038491874933, -0.09684329479932785, 0.0070276567712426186, -0.002865600399672985, 0.025814127177000046, 0.03774644434452057, 0.014964689500629902, 0.06991293281316757, 0.07036687433719635, -0.03814287483692169, -0.020636193454265594, 0.04271639883518219, -0.059474192559719086, -0.03452135995030403, -0.01408153586089611, 0.020118359476327896, -0.01639997959136963, -0.0017599737038835883, -0.046828415244817734, 0.02841780334711075, -0.021044937893748283, 0.0010554799810051918, -0.03801843896508217, -0.02274712733924389, -0.02500171586871147, -0.004040946718305349, -0.023263849318027496, 0.0003844434686470777, -0.05161767080426216, 0.05636664852499962, -0.019674217328429222, 0.0025198496878147125, -0.015748480334877968, -0.032143011689186096, 0.02067328616976738, -0.0013066106475889683, 0.019104085862636566, -0.012269862927496433, 0.013583843596279621, 0.009771007113158703, -0.021466897800564766, -0.007950316183269024, -0.061703991144895554, 0.029805028811097145, 0.004908482078462839, 0.004829138517379761, 0.027864325791597366, 0.014423765242099762, -0.015264512039721012, -0.015215086750686169, -2.9333636121009476e-05, 0.0021931289229542017, -0.019316621124744415, -0.01959388516843319, 0.00233125570230186, 0.008626538328826427, 0.005248280242085457, 0.0023750984109938145, 0.004225198645144701, 0.03944629430770874, 0.0643249973654747, 0.010070080868899822, 0.0231170617043972, -0.0650763288140297, 0.02558184415102005, -0.0029643080197274685, 0.03644539415836334, 0.003592697437852621, 0.00690413499251008, 0.03682411462068558, 0.046580784022808075, 0.03998708352446556, -0.006043136119842529, 0.03581705316901207, 0.024953866377472878, -0.04543664678931236, 0.06450561434030533, 0.009815672412514687, 0.006306249648332596, 0.0051441253162920475, 0.0356384702026844, -0.025501294061541557, 0.036230288445949554, -0.013928061351180077, -0.000793959537986666, 0.011848725378513336, -0.003830494126304984, 0.02032792754471302, -0.028962157666683197, 0.005419784225523472, -0.001652421778999269, 0.011187097989022732, 0.045543745160102844, 0.014965945854783058, 0.04406559839844704, -0.002038052538409829, 0.028479017317295074, -0.04058874398469925, 0.048974812030792236, 0.005541111342608929, -0.0007568637374788523, 0.030049579218029976, 0.012019946239888668, 0.02355760708451271, -0.011155000887811184, -0.029972711578011513, 0.04659195989370346, -0.013706492260098457, -0.008050345815718174, 0.0186315905302763, -0.050224971026182175, -0.03149043396115303, 0.0032964451238512993, -0.005372804123908281, 0.006557282526046038, -0.039529651403427124, 0.04622553661465645, 0.010601725429296494, -0.055565591901540756, 0.04166151210665703, 0.046323031187057495, 0.006042462773621082, 0.0748092457652092, 0.015315083786845207, 0.03162200003862381, 0.016793856397271156, -0.028711840510368347, -0.043503325432538986, -0.008491657674312592, -0.029663506895303726, 0.03260898217558861, -0.012927095405757427, 0.027353869751095772, -0.0164956022053957, -0.000514632964041084, -0.0391572080552578, 0.032029204070568085, 0.017105745151638985, 0.05028407648205757, -0.0047931913286447525, -0.01407645270228386, 0.018542999401688576, 0.031038207933306694, 0.0002510360791347921, 0.052539922297000885, -0.03194453567266464, -0.02646133117377758, -0.011926922015845776, -0.05282280966639519, 0.019154230132699013, 0.005834690295159817, 0.007805573288351297, -0.001850523054599762, 0.011552848853170872, 0.05239220708608627, 0.0366213396191597, -0.003114675637334585, 0.01946885697543621, 0.035824622958898544, -0. ...
# Updated 1 documents
# 0.9429855346679688
# Textbook of Anatomy: Head, Neck, and Brain 104 It is named after mythological Greek Titan who was
# reputed  to support the heavens on his shoulders. The 2nd cervical  vertebra is called axis, because
# its odontoid process forms a  pivot around which atlas rotates and carries the skull. The  atlas and
# axis are specialized vertebrae. The atlas has neither  body nor spine . It is ring-like and consists
# of two lateral  masses, connected by a short anterior arch and long  posterior arch (Fig. 2.29B).
# The axis possesses, tooth-like  odontoid process which projects upwards from the body.  The 3rd–6th
# cervical vertebrae are regarded as typical  vertebrae . The cervical vertebrae are described in
# detail in  Chapter 2. JOINTS OF THE NECK  The joints of the neck include intervertebral joints
# between  the lower 6 cervical vertebrae and craniovertebral joints. The  joints between the lower 6
# cervical vertebrae are typical  cervical joints . These are similar to those in the other parts of
# the vertebral column. They permit flexion, extension, and  lateral bending but little rotation. The
# joints between 1st and  2nd cervical vertebrae and those between 1st cervical  vertebrae and skull
# permit rotation and nodding of head,  respectively. The joints of neck are clinically important due
# to high incidence of spondylosis, disc prolapse, and fracture  dislocation in the cervical region.
# TYPICAL CERVICAL JOINTS These are the joints between lower 6 cervical vertebrae. They include joints
# between the vertebral bodies,  vertebral arches, and vertebral articular processes. Joints Between
# the Vertebral Bodies They are of two types, viz. 1. Secondary cartilaginous (intervertebral disc)
# between  the bodies of adjacent vertebrae.2. Synovial (joints of Luschka), between the lateral
# margins  of the bodies of adjacent vertebrae. Secondary Cartilaginous Joints (Fig. 7.13) These are
# articulations between two bodies of adjacent  vertebrae from 2nd to 7th cervical vertebrae. The
# adjacent articular surfaces are covered by the plates of  hyaline cartilage and held together by an
# intervertebral disc. The disc is fibrocartilaginous in nature. It consists of  an outer part formed
# by a series of fibrocartilaginous  laminae called annulus fibrosus  and an inner part  consisting of
# jelly-like material called nucleus pulposus . The most peripheral laminae of annulus fibrosus are
# formed of pure collagenous tissue and on the front and on  the back they blend with strong anterior
# and the weak  posterior longitudinal ligaments. The discs are firmly  bound to the edges of the
# hyaline cartilages and bodies of  the vertebrae. The intervertebral discs are thick anteriorly  in
# the cervical region contributing to the anterior  convexity of the neck. No discs are found between
# the first  two cervical vertebrae. The intervertebral disc along with hyaline cartilage  covering
# the upper and lower articular surfaces of the  adjoining vertebral bodies form the intervertebral
# symphysis . Ligaments Anterior longitudinal ligament (Fig. 7.14):  It extends  anterior to the
# anterior arch of atlas and bodies of remaining  cervical vertebrae. It is a strong ligament and
# consists of long  and short fibres. The long fibres are superficial and bridge  across several
# vertebrae whereas short fibres are deep and  bridge across a single pair of vertebrae, and blend
# with the  annulus fibrous of the intervertebral disc.Fig. 7.13  Secondary cartilaginous joints
# (symphyses)  between the vertebral bodies.Ventral ramus of cervical spinal nerveRaised lip of upper
# surface of the body Facet for  joint of Luschka Foramen transversarium containing vertebral artery
# Superior articular facet Fig. 7.12  Typical cervical vertebra (superior aspect). Annulus fibrosus
# Vertebral bodiesNucleus pulposus Plate of hyaline cartilage Intervertebral discs
# 3820
# [-0.003811367554590106, -0.006286561954766512, 0.010684175416827202, -0.015490677207708359, -0.009669746272265911, -0.018854789435863495, -0.020695053040981293, 0.03433047980070114, 0.014134247787296772, 0.04692327603697777, 0.014154411852359772, 0.024612778797745705, -0.024596070870757103, -0.033098310232162476, 0.00907078105956316, -0.0068687633611261845, -0.016829775646328926, -0.031126489862799644, -0.01794341206550598, -0.00035455854958854616, -0.00824593286961317, -0.0024166821967810392, -0.08308760076761246, 0.006008494179695845, 3.2495270716026425e-05, 0.02199685201048851, 0.037162456661462784, 0.029186012223362923, 0.04928568750619888, 0.05113283917307854, -0.02237359806895256, -0.017324872314929962, 0.0481683723628521, -0.05895552784204483, -0.02721819095313549, 0.0012428398476913571, 0.03983447328209877, -0.04239960387349129, -0.0025579503271728754, -0.05011278763413429, 0.014719747938215733, -0.021104296669363976, -0.002345176413655281, -0.04148878529667854, -0.026632966473698616, -0.015144545584917068, 0.005351188126951456, -0.014707669615745544, 0.021350862458348274, -0.05433131754398346, 0.021233199164271355, -0.029283426702022552, 0.020265230908989906, -0.033898260444402695, -0.029851755127310753, 0.00921851210296154, -0.002585367066785693, 0.00146248540841043, -0.025779936462640762, 0.022332800552248955, 0.023966951295733452, -0.006739079486578703, -0.020024288445711136, -0.06681693345308304, 0.0362347811460495, 0.030782731249928474, 0.010958065278828144, 0.018859360367059708, 0.00679808622226119, 0.0008435723138973117, -0.013096557930111885, -0.001859059208072722, 0.00990906823426485, -0.010740378871560097, -0.010182898491621017, 0.006319946143776178, -0.0055279601365327835, -0.002932514762505889, -0.010270887985825539, -0.001512828515842557, 0.0485667884349823, 0.07502027601003647, 0.026417290791869164, 0.013450109399855137, -0.0684020072221756, 0.021542200818657875, -0.007273364346474409, 0.026098594069480896, 0.010545006021857262, 0.013249496929347515, 0.008411814458668232, 0.04764299467206001, 0.022157855331897736, -0.014183679595589638, 0.03323303908109665, 0.0352301150560379, -0.0534089170396328, 0.03567773848772049, -0.004980028606951237, -0.010309443809092045, 0.053573574870824814, 0.03631680831313133, -0.021884920075535774, 0.030690455809235573, -0.06832170486450195, 0.009285853244364262, 0.019170338287949562, 0.01615932211279869, 0.007446527015417814, -0.012296298518776894, 0.012527947314083576, -0.018749743700027466, 0.003270789049565792, 0.004858676344156265, 0.02149759791791439, 0.05982925742864609, -0.0036771129816770554, 0.04521100968122482, -0.05852958559989929, 0.025679148733615875, -0.018506797030568123, 0.025064151734113693, 0.02332318387925625, -0.03181925788521767, -0.013308915309607983, -0.03193570300936699, -0.03297344222664833, 0.028721531853079796, -0.011686224490404129, -0.019505932927131653, 0.005080922972410917, -0.03576631844043732, -0.00681033730506897, 0.031792234629392624, -0.025387918576598167, -0.0033272365108132362, -0.03039550967514515, 0.038050293922424316, -0.011847863905131817, -0.053504928946495056, 0.03396477550268173, 0.037674617022275925, 0.012466215528547764, 0.07011968642473221, 0.0038132090121507645, 0.03212335333228111, 0.023250818252563477, -0.017544575035572052, -0.029500938951969147, 0.001162525499239564, -0.04909934848546982, 0.05434552580118179, -0.019732266664505005, 0.01723235286772251, -0.0030906260944902897, 0.016060536727309227, -0.023373397067189217, 0.030688254162669182, -0.013724368996918201, 0.02589399367570877, 0.007233801297843456, -0.011570747941732407, 0.019169123843312263, 0.053508732467889786, -0.010681265965104103, 0.058717627078294754, -0.023916181176900864, -0.014406552538275719, -0.007167366798967123, -0.03396778926253319, 0.004431775771081448, -0.01939290761947632, 0.01265747006982565, 0.01555775385349989, 0.007180176209658384, 0.07023221254348755, 0.037084974348545074, 0.00021644419757649302, 0.013992034830152988, 0.050935328006744385, - ...
# Updated 2 documents
# 0.9249153137207031
# Textbook of Anatomy: Head, Neck, and Brain 176 The cervical pleura is strengthened by the
# suprapleural  membrane (also called Sibson’s fascia ) so that the root of the  neck is not puffed up
# and down during respiration. Relations Anterior: 1. Subclavian artery. 2. Scalenus anterior.
# Posterior: Neck of first rib and structures crossing in front of it. Lateral: 1. Scalenus medius. 2.
# Lower trunk of brachial plexus. Medial: 1. Vertebral bodies. 2. Trachea and esophagus. 3. Recurrent
# laryngeal nerve in the tracheoesophageal  groove. 4. Thoracic duct on the left side. 5. Large blood
# vessels of the neck. N.B. Structures crossing in front of the neck of 1st rib from  medial to
# lateral side are: • Sympathetic chain. • First posterior intercostal vein.• Superior intercostal
# artery. • First thoracic nerve (large ascending branch of its ventral  ramus). LYMPH TRUNKS AT THE
# ROOT OF THE NECK The lymph from head and neck region is returned to the  venous blood via left and
# right lymph trunks, which converge  at the root of neck at the junction of internal jugular and
# subclavian veins. The various lymph trunks which converge  on the right and left side of the root of
# the neck are as  described in the following text: On the right side of neck —the three trunks that
# converge  are as follows: 1. Right jugular trunk extends along the ventrolateral  aspect of the
# internal jugular vein. It drains lymph from  right half of the head and neck. 2. Right subclavian
# trunk  extends along the axillary and  subclavian veins and draws lymph from the right upper  limb
# and superficial tissues of the right half of the  thoracoabdominal wall down to the umbilicus
# anteriorly  and iliac crest posteriorly. 3. Right bronchomediastinal trunk  ascends over the
# trachea. It drains lymph from right lung, bronchi and  trachea, and right half of the mediastinum.
# The right jugular and subclavian trunks may unite  to form right lymphatic duct , which ends in a
# similar  way to that of the thoracic duct (see page 177).Fig. 12.15  Deep structures at the root of
# the neck.C6 C7 T1Middle cervical sympathetic ganglion Scalenus medius Scalenus anteriorVertebral
# artery Inferior thyroid artery Phrenic nerve Thoracic duct Transverse cervical artery Suprascapular
# artery Subclavian artery Internal jugular vein Subclavian vein TracheaEsophagusRecurrent laryngeal
# nerveInferior cervical sympathetic ganglion Upper Middle Lower Longus colliDorsal scapular artery
# Left common carotid arteryTrunks of brachial plexus
# 2492
# 0.9245122075080872
# Anterior Abdominal Wall 33 The three flat muscles are fleshy posterolaterally and  aponeurotic
# anteromedially. The aponeuroses of these  muscles pass toward the midline to enclose the rectus
# abdominis and pyramidalis, and then fuse with each other  and with the aponeuroses of the muscles of
# the opposite side  in the median fibrous raphe extending from the xiphoid  process to the pubic
# symphysis, forming the linea alba. N.B. If you place your hands on either side of your abdomen  with
# fingertips just touching in the midline, the palms of  your hands lie mainly over the fleshy
# portions of flat muscles  and fingers over their aponeuroses. Thus, anterior part of  the abdominal
# wall is mostly aponeurotic except for the  rectus abdominis and pyramidalis, which are enclosed
# within  the aponeurosis.  FLAT MUSCLES The three anterolateral flat muscles (external oblique,
# internal oblique, and transversus abdominis) form three  distinct layers in the anterior abdominal
# wall, similar to  those in the intercostal space, and as in the intercostal space  the neurovascular
# structures lie between the internal oblique  and transversus abdominis muscles. External Oblique
# Muscle (Fig. 3.16) Origin The external oblique muscle arises from eight fleshy slips  from the outer
# surfaces (the middle of the shaft) of lower  eight ribs.Insertion Most of the fleshy fibres run
# downward, forward, and  medially in the same direction as the fingers do when you  put the hand
# inside the side pocket of your pantaloon. The insertion occurs as follows: 1. The posterior-most
# fibres pass vertically downward to  be inserted on to the outer lip of the anterior two-third  of
# the iliac crest. The posterior border of muscle is thus  free. 2. The remaining fibres pass
# downward, forward and  medially to end in a broad aponeurosis, which is inserted  into the linea
# alba extending from the xiphoid process to  the pubic symphysis. (a) The upper border of the
# aponeurosis is free and  overlapped by the fibres of pectoralis major muscle. (b) The lower border
# of the aponeurosis is free and  jumps from anterior superior iliac spine to the  pubic tubercle
# bridging across the muscles, nerves,  and vessels that enter the thigh from the abdomen. The free
# lower border of the aponeurosis is thickened and  rolled inward on itself to form the inguinal
# ligament . N.B. Additional points of interest: • The upper four slips of origin interdigitate with
# the slips  of serratus anterior and lower four slips with the slips of  latissimus dorsi. • Above
# the pubic symphysis the aponeurosis presents a  triangular gap called superficial inguinal ring.
# Fig. 3.16 External oblique muscle. 5 6 7 8 9 10 11 12Xiphoid process Linea alba Aponeurosis Line of
# demarcation between muscular and aponeurotic parts of muscle Superficial inguinal ringIntercrural
# fibres Pubic tuberclePubic crestRibs Posterior-free border Iliac crest Anterior superior iliac spine
# Inguinal ligament
# 2938
# [-0.00923076644539833, 0.00906478799879551, -0.004720246884971857, -0.0029754936695098877, -0.018978474661707878, -0.006113988347351551, -0.03968570753931999, 0.05467525124549866, 0.035219963639974594, 0.017129462212324142, 0.030974453315138817, -0.005387826357036829, 0.016379423439502716, -0.011879293248057365, -0.04808467999100685, 0.006672660820186138, -0.03748808801174164, -0.056165728718042374, -0.027519091963768005, -0.003456762759014964, -0.015595339238643646, 0.005937490612268448, -0.06283102184534073, -0.01992856152355671, -0.007852945476770401, 0.0307247806340456, 0.038885995745658875, 0.0036143409088253975, 0.05182010680437088, 0.04897888004779816, -0.02714412286877632, -0.0011837717611342669, 0.012442056089639664, -0.026214029639959335, -0.01956283301115036, 0.010707510635256767, 0.05746223405003548, -0.04368164390325546, -0.013174248859286308, -0.07304228097200394, 0.022252123802900314, -0.03449343144893646, 0.030933445319533348, -0.0028965529054403305, -0.05012562498450279, -0.017542049288749695, -0.016201019287109375, 0.00044709965004585683, -0.00020432208839338273, -0.035270530730485916, 0.033424630761146545, -0.025826241821050644, 0.009094313718378544, -0.022680632770061493, 0.008148279041051865, 0.029179081320762634, -0.0006952101830393076, -0.038846809417009354, -0.008427944965660572, 0.036784034222364426, 0.018729105591773987, -0.023305827751755714, 0.019139166921377182, -0.0775841698050499, 0.010461198166012764, 0.031207235530018806, -0.008076544851064682, -0.022192955017089844, -0.009676541201770306, -0.023144466802477837, -0.03879040107131004, 0.0015836487291380763, -0.0019581199157983065, -0.003019925905391574, -0.0015334357740357518, -0.020030781626701355, -0.011351429857313633, 0.008297033607959747, -0.04737937077879906, -0.011276393197476864, 0.013221118599176407, 0.046766869723796844, 0.022619925439357758, 4.8806166887516156e-05, -0.05370960384607315, 0.004303231835365295, -0.015229016542434692, 0.02638794295489788, -0.025187937542796135, 0.004174811765551567, 0.025987504050135612, 0.04995143413543701, -0.004036946687847376, 0.00890677236020565, 0.02804895117878914, 0.04861040040850639, -0.04013105481863022, 0.03635735437273979, -0.018300073221325874, -0.00017473164189141244, 0.047649726271629333, 0.014316168613731861, -0.01056733913719654, 0.04370381683111191, -0.03661993891000748, -0.0029539987444877625, -0.0053169806487858295, 0.007854330353438854, -0.008096913807094097, -0.013365496881306171, -0.006543584167957306, -0.02576104924082756, 0.01647195778787136, 0.008966571651399136, 0.020676665008068085, 0.034389521926641464, 0.011204883456230164, 0.04048163816332817, -0.05514167994260788, 0.016516000032424927, -0.010332182049751282, 0.004963904153555632, 0.030935341492295265, -0.015228208154439926, 0.028128914535045624, -0.01158056315034628, -0.0427350252866745, 0.06086473539471626, -0.021732229739427567, -0.014398548752069473, 0.028192739933729172, -0.016441475600004196, -0.03503703325986862, 0.052007149904966354, -0.024222124367952347, -0.010245162062346935, -0.036572765558958054, 0.04165093973278999, 0.057034511119127274, -0.04377447068691254, 0.019626429304480553, 0.03779512643814087, 0.03956689313054085, 0.07371368259191513, -0.0028217206709086895, 0.025433870032429695, 0.02778550237417221, -0.014115363359451294, -0.03982579708099365, 0.022922074422240257, -0.01749236136674881, 0.052710723131895065, 0.0068167163990437984, 0.025516565889120102, -0.026800693944096565, 0.009393248707056046, -0.03322155401110649, 0.009476998820900917, 0.014260548166930676, 0.029149524867534637, -0.03551552817225456, -0.007068590261042118, 0.019904999062418938, 0.04610733687877655, -0.015489471144974232, 0.027098240330815315, -0.01476123183965683, -0.02379957213997841, 0.0012508956715464592, -0.018044479191303253, 0.0010030638659372926, 0.010643558576703072, -0.014724061824381351, 0.01689332351088524, -0.0009333586785942316, 0.023293912410736084, 0.022318579256534576, 0.017680805176496506, 0.013970543630421162, 0.0 ...
# Updated 2 documents
# 0.9064570665359497
# 194CHAPTER 12Vasodilators & the  Treatment of   Angina Pectoris Bertram G. Katzung, MD, PhD*  CASE
# STUDY A 56-year-old woman presents in the office with a history of  recent-onset chest discomfort
# when jogging or swimming vigorously. The pain is dull but poorly localized; it disap - pears after
# 5–10 minutes of rest. She has never smoked but has a history of hyperlipidemia (total cholesterol
# level of 245 mg/dL and low-density lipoprotein [LDL] of 160 mg/dL recorded 1 year ago) and admits
# that she has not been fol - lowing the recommended diet. Her father survived a “heart attack” at age
# 55, and an uncle died of some cardiac disease at age 60. On physical examination, the patient’s
# blood pressure is 145/90 mm Hg, and her heart rate is 80 bpm. She is in no acute distress, and there
# are no other significant physical findings; an electrocardiogram is normal except for slight left
# ventricular hypertrophy. Assuming that a diagno - sis of stable effort angina is correct, what
# medical treatment should be implemented? Ischemic heart disease is one of the most common
# cardiovascular  diseases in developed countries, and angina pectoris is the most common condition
# involving tissue ischemia in which vasodilator drugs are used. The name angina pectoris denotes
# chest pain caused  by accumulation of metabolites resulting from myocardial ischemia. The organic
# nitrates, eg, nitroglycerin, are the mainstay of therapy  for the immediate relief of angina.
# Another group of vasodilators, the calcium channel blockers, is also important, especially for
# prophy - laxis, and β  blockers,  which are not vasodilators, are also useful in  prophylaxis.
# Several newer drugs are available, including drugs that alter myocardial ion currents and selective
# cardiac rate inhibitors. By far, the most common cause of angina is atheromatous  obstruction of the
# large coronary vessels (coronary artery disease, CAD). Inadequate blood flow in the presence of CAD
# results in effort angina, also known as classic angina. Diagnosis is usually  made on the basis of
# the history and stress testing. However, transient spasm of localized portions of these vessels,
# usually associated with underlying atheromas, can also cause significant myocardial ischemia and
# pain (vasospastic or variant angina). Vasospastic angina is also called Prinzmetal angina. Diagnosis
# is made on the basis of history. The primary cause of angina pectoris is an imbalance between  the
# oxygen requirement of the heart and the oxygen supplied to it via the coronary vessels. In effort
# angina, the imbalance occurs when the myocardial oxygen requirement increases, especially during
# exercise, and coronary blood flow does not increase pro - portionately. The resulting ischemia with
# accumulation of acidic metabolites usually leads to pain. In fact, coronary flow reserve is
# frequently impaired in such patients because of endothelial dysfunction, which results in impaired
# vasodilation. As a result, ischemia may even occur at a lower level of myocardial oxygen demand. In
# some individuals, the ischemia is not always accom - panied by pain, resulting in “silent” or
# “ambulatory” ischemia. In variant angina, oxygen delivery decreases as a result of reversible
# coronary vasospasm, which also causes ischemia and pain. *The author thanks Dr. Kanu Chatterjee, MB,
# FRCP , coauthor of this  chapter in prior editions.
# 3369
# 0.9046188592910767
# Multiple Choice Questions 483 (c) Its most fixed part is the pylorus (gastroduodenal  junction) (d)
# Its most fixed part is the cardiac end  (gastroesophageal junction) 2. All of the following arteries
# supply the stomach except : (a) Left gastric artery (b) Left epiploic artery (c) Right gastric
# artery (d) Short gastric artery 3. All of the following structures form the stomach bed  except :
# (a) Body of pancreas (b) Splenic artery (c) Right crus and dome of the diaphragm (d) Transverse
# mesocolon 4. All the structures forming the stomach bed are  separated from the stomach by the
# lesser sac  except : (a) Left kidney (b) Left suprarenal gland (c) Left colic flexure (d) Spleen 5.
# Select the incorrect statement about the gastric canal: (a) It is located along the lesser curvature
# of the stomach (b) It is also called Magenstrasse (c) It is produced due to the absence of
# longitudinal  fold of gastric mucosa (d) It is prone to ulceration 6. Select the incorrect statement
# about the spleen: (a) It is the largest lymphoid organ in the body (b) It filters the microbial
# agents from the circulation (c) It develops in the ventral mesogastrium (d) It is located in the
# left hypochondrium between the  fundus of the stomach and diaphragm 7. Regarding spleen all
# statements are true except : (a) Its upper pole (medial end) lies 3/4 cm lateral to the  spine of
# T10 vertebra (b) Its long axis corresponds to the long axis of the 10th  rib (c) Its lower pole
# (lateral end) extends forward up to  the midclavicular line (d) Its superior border presents one or
# two notches near  its lateral end 8. The hilum of spleen is located on its visceral surface in  the
# region of: (a) Renal impression (b) Gastric impression (c) Colic impression (d) Pancreatic
# impressionAnswers 1. c, 2. b, 3. c, 4. d, 5. c, 6. c, 7. c, 8. b CHAPTER 8 1. Select the incorrect
# statement about the liver: (a) It almost completely occupies right hypochondrium (b) It forms about
# 1/18th of total body weight in a  newborn (c) It lies largely outside the thoracic cage (d) It
# weighs about 1–2 kg 2. Factors keeping the liver in position include all except : (a) Hepatic veins
# (b) Intra-abdominal pressure (c) Ligaments of liver (d) Hepatic pedicle 3. All the statements about
# the bare area of the liver are  correct except : (a) It is the largest non-peritoneal area of the
# liver (b) It is located on the posterior surface of the right lobe (c) It is related to the right
# spleen (d) It is one of the sites of porta systemic anastomosis 4. Select the incorrect statement
# about porta hepatis: (a) It is a horizontal fissure on the inferior surface of the  liver (b) The
# neck of gallbladder lies at its right end (c) The junction of the fissures for ligamentum teres  and
# ligamentum lies at its left end (d) The right and left hepatic ducts enter the liver  through it 5.
# Which of the following structures lie anteriorly in the  hepatic pedicle just above the termination
# of the cystic  duct?  (a) Portal vein (b) Common hepatic duct (c) Right hepatic artery (d) Left
# hepatic artery 6. Select the incorrect statement about the gallbladder: (a) It lies in an elongated
# fossa on the inferior surface  of the right lobe of liver (b) It can store up to 50 ml of bile (c)
# Its body is covered with peritoneum on all sides (d) It is distended in extrinsic obstruction of the
# common bile duct 7. The total number of hepatic segments is: (a) 6 (b) 7
# 3403
# ...
# for therapeutic  purposes in the case of empyema. Blood cultures should be  done in all patients
# admitted to the hospital with acute pneu - monia even though the yield is variable (eg, 20–25% with
# S. pneumoniae , much less in disease caused by H. influenzae ).  Sputum, when available, may be
# useful for Gram-stain and  culture as well. Many patients with bacterial pneumonia and pneu - monia
# due to other causes have mucopurulent sputum.  Rust-colored sputum suggests alveolar involvement and
# is  associated with pneumococcal pneumonia but occurs with  other organisms also. Foul-smelling
# sputum suggests mixed  anaerobic infection. A purulent portion of the sputum should  be chosen for
# Gram-stain and microscopic examination; an  adequate sputum specimen will have over 25 PMN cells and
# fewer than 10 epithelial cells per low-power field (100× mag - nification). Traditionally,
# microscopic examination of the  sputum has been used to help determine the cause of pneu - monia;
# however, it may be difficult to differentiate organ - isms that are part of the normal oropharyngeal
# microbiota  from those that are causing the pneumonia. The finding of  numerous lancet-shaped Gram-
# positive diplococci strongly  suggests S. pneumoniae , but streptococci that are part of the
# oropharyngeal microbiota can have the same appearance.  The major value of stained sputum smears is
# when organ - isms that would not be expected are found (eg, numerous  PMN cells along with numerous
# Gram-negative bacilli sug - gesting enteric bacilli or Pseudomonas , or numerous Gram- positive
# cocci in clusters suggesting staphylococci). Sputum  cultures have many of the same drawbacks as
# smears; it may  be difficult to differentiate normal microbiota or colonizing  bacteria from the
# cause of the pneumonia. True demonstration of the cause of pneumonia comes  from a limited set of
# specimens: a positive blood culture  in a pneumonia patient with no confounding infections;  a
# positive pleural fluid or direct lung aspirate culture;  and detection of circulating antigen of a
# specific organ - ism with no confounding infection (eg, S. pneumoniae  or  L. pneumophila  urinary
# antigen). Bronchoscopy is often  used to obtain material for diagnostic studies in severely  ill
# patients with pneumonia and is recommended for  health care-associated pneumonia and pneumonia in
# the  immunocompromised host. Quantitative bacterial culture performed on a carefully collected
# bronchoalveolar lavage  (BAL) sample using 104 colony-forming units (CFU)/mL of  a specific pathogen
# per sample as the cutoff for clinical sig - nificance is useful for establishing an etiology of
# bacterial  pneumonia in patients not previously treated with antibi - otics. Bronchoscopy with BAL
# may also yield a nonbacte - rial pathogen such as a filamentous mold or viral pathogen  in the at-
# risk patient. Several commercially available multiplex nucleic acid  amplification methods are now
# available to assist in the diag - nosis of viral pneumonia and pneumonia caused by the atyp - ical
# pathogens such as M. pneumoniae  and C. pneumoniae.
# 3960
# 0.906654953956604
# 761(Continued )Pneumonia Sputum, BAL BA, CA, MAC/EMB S. pneumoniae Many PMNs, Gram-positive  cocci
# in pairs or chains.  Capsule can be seenS. pneumoniae  is part of normal microbiota  in nasopharynx.
# Blood cultures positive  in 10–20% of patients S. aureus Gram-positive cocci in   clustersUncommon
# cause of pneumonia. Usually  β-hemolytic, coagulase-positive Enterobacteriaceae and   other Gram-
# negative rodsGram-negative rods Hospital-associated pneumonia. Alcoholic  pneumonia Add ANA Mixed
# anaerobes and   aerobesMixed respiratory tract flora;  sometimes many PMNsAspiration pneumonia,
# often associated  with pleural effusion/abscess Chest empyema Pleural fluid BA, CA. MAC/EMB,
# ANASame as pneumonia, or   mixed flora infectionMixed flora Usually pneumonia; mixed aerobic  and
# anaerobic flora derived from  oropharynx Liver abscess Abscess fluid BA, CA, MAC/EMB,  ANAE. coli ;
# Bacteroides fragilis ;   mixed aerobic or  anaerobic floraGram-negative rods and   mixed
# floraCommonly enteric Gram-negative aerobes  and anaerobes; consider Entamoeba  histolytica
# infection Cholecystitis Bile BA, CA, MAC/EMB,  ANAGram-negative enteric   aerobes, also B.
# fragilisGram-negative rods Usually Gram-negative rods from  gastrointestinal tract Abdominal or
# perirectal  abscessAbscess fluid BA, CA, MAC/EMB,  ANAGastrointestinal flora Mixed flora Aerobic and
# anaerobic bowel flora; often  more than five species grown Enteric fever,  typhoidBlood, stool,
# urineBA, CA, MAC/EMB,  Hektoen, enteric  agarSalmonella  serovar Typhi Not recommended Multiple
# specimens should be cultured;  lactose negative, H2S positive Enteritis,  enterocolitis,  bacterial
# diarrheasStool MAC/EMB, Hektoen,  enteric agar,  Campylobacter   agarSalmonella  species Gram-stain
# or methylene blue  stain may show PMNsNon-lactose-fermenting colonies on  TSI slants: Nontyphoid
# salmonellae  produce acid and gas in butt, alkaline  slant, and H2S Shigella  species Gram-stain or
# methylene blue  stain may show PMNsNon-lactose-fermenting colonies on TSI  slants: Shigellae produce
# alkaline slant,  acid butt without gas or H2S Campylobacter jejuni “Gull wing–shaped” Gram- negative
# rods and often  PMNsIncubate at 42°C in Campylobacter  gas;  colonies oxidase-positive; smear shows
# “gull wing–shaped” rods Add TCBS agar; Vibrio cholerae Not recommended Clinically suspected cases;
# yellow colonies  on TCBS. V. cholerae  is oxidase-positive Add TCBS agar Other Vibrio  species Not
# recommended Differentiate from V. cholerae  by  biochemical and culture tests Add CIN agar Yersinia
# enterocolitica Not recommended Enrichment at 4°C helpful; incubate  cultures at 25°C
# Riedel_CH47_p757-p786.indd   761 05/04/19   5:25 PM
# 2676
# [-0.0037133703008294106, 0.0069466521963477135, -0.006159804295748472, -0.028176479041576385, 0.017397206276655197, -0.0036298877093940973, -0.008867410942912102, 0.013006109744310379, 0.02523246966302395, 0.016518309712409973, 0.025619596242904663, 0.014717639423906803, 0.036417219787836075, -0.024557555094361305, 0.004183701239526272, 0.009412189014256, -0.022522902116179466, -0.042291589081287384, -0.018790353089571, 0.026907747611403465, -0.003444584319368005, 0.04484416916966438, -0.0489429235458374, -0.0021988311782479286, 0.0017925174906849861, 0.0326508991420269, 0.025477813556790352, 0.01990571990609169, 0.0594511404633522, 0.0630846917629242, -0.035870395600795746, -0.031232766807079315, 0.04160378500819206, -0.012528044171631336, -0.04204564169049263, -0.0034154534805566072, 0.03660842403769493, -0.024030188098549843, -0.002603346947580576, -0.053079377859830856, 0.0163497943431139, -0.020208144560456276, 0.035795751959085464, -0.036628223955631256, -0.026288505643606186, -0.01798742078244686, -0.005651475861668587, -0.011392150074243546, 0.02007439360022545, 0.00043275050120428205, 0.026395278051495552, -0.02010495401918888, 0.027811728417873383, -0.01903627999126911, -0.005416645668447018, -0.012892091646790504, 0.031969018280506134, 0.008561287075281143, -0.03148623928427696, 0.02934839390218258, 0.017503701150417328, 0.021075453609228134, -0.002627788810059428, -0.05917362496256828, 0.05702293664216995, 0.04309248924255371, -0.006617140024900436, 0.010733782313764095, 0.002163763390854001, 0.020276138558983803, -0.010977614670991898, 0.009600628167390823, -0.0007853529532440007, -0.011178203858435154, 0.010095376521348953, -0.019432740285992622, -0.01678277552127838, -0.023324958980083466, 0.002510984893888235, 0.016753308475017548, 0.018459707498550415, 0.06836427003145218, 0.02461792528629303, 0.015410073101520538, -0.05431527644395828, -0.013095960021018982, -0.006908036302775145, -0.002873406047001481, 0.002866453258320689, -0.003997967578470707, 0.0203758142888546, 0.04424639418721199, 0.01812150329351425, -0.021814577281475067, 0.027896402403712273, 0.048303283751010895, -0.04627979174256325, 0.04324529692530632, 0.004877480212599039, -0.011938142590224743, 0.05611882731318474, 0.02592221461236477, -0.015562014654278755, 0.03412102907896042, -0.0600549690425396, -0.0038675637915730476, 0.017236391082406044, 0.013914668001234531, 0.011114964261651039, -0.03571198508143425, 0.004051950294524431, -0.01628618873655796, -0.0037202155217528343, 0.0005960206617601216, 0.008204331621527672, 0.03461835905909538, 0.012736525386571884, 0.06650672852993011, -0.07295337319374084, 0.01426455657929182, -0.0019622778054326773, -0.005037860479205847, 0.01769155077636242, -0.019437696784734726, 0.028109390288591385, -0.022569624707102776, -0.03527795523405075, 0.05932120978832245, -0.002925899112597108, 0.005889278370887041, 0.002136076334863901, -0.04984860122203827, -0.0399964302778244, 0.0368986539542675, -0.009502777829766273, 0.009381365031003952, -0.04629558324813843, 0.039680227637290955, 0.009976577013731003, -0.05279814451932907, 0.03958122432231903, 0.038192350417375565, -0.0020659093279391527, 0.06934775412082672, 0.01863745041191578, 0.06038261204957962, -0.009822751395404339, -0.0038400713820010424, -0.04826512560248375, -0.017525922507047653, -0.032706018537282944, 0.0321156308054924, -0.021575137972831726, 0.033755507320165634, -0.019181909039616585, 0.011109326034784317, -0.0028928432147949934, -0.003410619217902422, 0.021693123504519463, 0.03146979212760925, 0.017665566876530647, -0.0034040817990899086, 0.0038235040847212076, 0.05380299687385559, -0.02146761305630207, 0.04094285890460014, 0.0034290344920009375, -0.006438979413360357, -0.009676877409219742, -0.03412199392914772, 0.00816727988421917, -0.008071588352322578, -0.010640579275786877, 0.013247529044747353, 0.019089968875050545, 0.0571557842195034, 0.03191651776432991, -0.005721356254070997, 0.025195321068167686, 0.07173469662666321, -0.013078620657 ...
# Updated 2 documents
# 0.9262962937355042
# Thyroid and Parathyroid Glands, Trachea, and Esophagus 165 esophagus during deglutition. In cross
# section the trachea  appears D-shaped or horseshoe-shaped. The following text  deals with cervical
# part in detail. For thoracic part see  Textbook of Anatomy: Upper Limb and Thorax, Vol. I by
# Vishram Singh. CERVICAL PART OF TRACHEA The cervical part of the trachea is about 7 cm in length and
# extends from the lower border of cricoid cartilage to the  upper border of manubrium sterni. It
# extends downwards  and slightly backwards in front of the esophagus following  curvature of the
# cervical spine and enters the thoracic  cavity in the median plane with slight deviation on the
# right side. Relations of the Cervical Parts of Trachea In the neck, the trachea is relatively
# superficial and has  following relations: Anteriorly , from superficial to deep it is related to:
# (a) skin, (b) superficial fascia containing anterior jugular veins and  jugular venous arch
# (crossing in the suprasternal space  of Burns), (c) investing layer of deep cervical fascia, (d)
# sternothyroid and sternohyoid muscles, (e) isthmus of thyroid gland in front of the 2nd, 3rd, and
# 4th tracheal rings, (f) inferior thyroid veins and arteria thyroidea ima  (occasional), (g) left
# brachiocephalic vein in children may rise in the neck, (h) thymus gland (in children), and (i)
# brachiocephalic artery (sometimes) in children. Posteriorly  it is related to: (a) esophagus, and
# (b) recurrent laryngeal nerve in the tracheoesophageal  groove (on each side). On each side  it is
# related to: (a) lobe of thyroid gland extending up to the 5th or 6th  tracheal ring, and (b) common
# carotid artery in the carotid sheath. BLOOD SUPPLY AND LYMPHATIC DRAINAGE The arterial supply  of
# the cervical part of trachea is derived  mainly from branches of the inferior thyroid arteries. The
# veins from trachea  drain into the left brachiocephalic  vein. The lymph from trachea drains into
# pre- and paratracheal  nodes.NERVE SUPPLY This is by sympathetic and parasympathetic fibres. The
# parasympathetic fibres  are derived from vagus  through the recurrent laryngeal nerve. They are
# secretomotor  and sensory to the mucus membrane and motor to the  trachealis muscle. The sympathetic
# fibres  are derived from the middle cervical  sympathetic ganglion. They are vasomotor in nature.
# Tracheostomy:  It is a life-saving surgical procedure done in  cases of laryngeal obstruction. The
# tracheostomy is  commonly done in the retrothyroid region after di splacing the  isthmus of the
# thyroid gland upwards or downwards. After displacing the isthmus the trachea is opened by a
# vertical incision in the region of the 3rd and 4th or 2nd and  3rd tracheal rings. This is then
# converted into circular opening  and tracheostomy tube is inserted. If the tracheostomy is performed
# above the isthmus it is  called high tracheostomy and if it is performed below the  isthmus it is
# called low tracheostomy. The low tracheostomy is risky in children owing to shortness  of the neck
# and presence of thymus and left brachiocephalic  vein and sometimes brachiocephalic artery. These
# str uctures,  if injured, will cause alarming hemorrhage.Clinical correlation ESOPHAGUS The
# esophagus is 25 cm long muscular tube, which connects  pharynx with the stomach. The esop hagus is
# kept collapsed  anteroposteriorly between trachea and vertebral column. Its  expansion occurs only
# when bolus of food passes through it. The esophagus begins as a continuation of pharynx at the
# lower border of cricoid cartilage opposite the lower border  of C6 vertebra. It passes downwards in
# front of the vertebral column  behind trachea, traverses superior and posterior mediastina of
# thorax, passes through the esophageal opening of the  diaphragm and ends at the cardiac orifice of
# the stomach in  the abdomen about 2.5 cm to the left of the median plane. The esophagus is divided
# into three parts: cervical, thora cic, and abdominal .
# 3945
# 0.9163779020309448
# 11Thyroid and Parathyroid  Glands, Trachea, and  EsophagusCHAPTER The thyroid and parathyroid glands
# and cervical parts of the  trachea and esophagus are closely related structures. In the region of
# neck, thyroid and trachea are routinely  examined by clinicians to diagnose their disorders, e.g.,
# goitre, tracheal tug, etc. The surgical procedures are commonly  performed on these structures,
# e.g., thyroidectomy,  tracheostomy, etc. Therefore, detailed knowledge of anatomy  and relations of
# these structures is extremely important. THYROID GLAND (G. THYREOS = SHIELD;  EDIDOS = FORM) The
# thyroid gland is the largest endocrine gland of the body.  The hormones secreted by the thyroid
# gland include triiodo- thyronine (T3) ,tetraiodothyronine  (T4; commonly called  thyroxine ), and
# calcitonin , which subserve the following  functions: 1. Regulate the basal metabolic rate. 2.
# Stimulate the psychosomatic growth of the body. 3. Play an important role in calcium metabolism.
# Special Features The special features of the thyroid gland are: 1. It is the only endocrine gland,
# which is located  superficially in the body, hence accessible for physical  examination. 2. It is
# the only endocrine gland that depends on external  environment for raw material, iodine, to
# synthesize its  hormones. 3. It is the only endocrine gland, which does not pour its  hormones into
# blood immediately after formation but  stores them and then releases them in blood for use as  and
# when required. 4. It is one of the organ of the body having a very rich  blood flow.LOCATION  The
# thyroid gland is located in the lower part of the front  and side of the neck opposite to the C5,
# C6, C7, and T1  vertebrae (Figs 11.1 and 11.2), clasping the upper part of the  trachea. Parts and
# Features /circle6It is H-shaped and consisting of vertical right and left  lateral lobes and a
# horizontal isthmus connecting them  across the midline. Sometimes a small pyramidal lobe projects
# upwards from the isthmus usually to the left of  the midline. Not infrequently, it is connected to
# the body  Thyroid glandSternocleidomastoid Trachea Fig. 11.1  Location of the thyroid gland.
# 2144

# %%
total_cost = input_token_count*(0.0015/1000) + output_token_count*(0.002/1000)
print(f"Total cost: {total_cost}")
# Out:
# Total cost: 0.0442415

# %%
query = {"flag": 1}

    # Update the flag to 0
new_values = {"$set": {"flag": 0}}

    # Perform the update
results = db.Medical_Books_RAG.update_many(query, new_values)
print(f"Updated {results.modified_count} documents")
# Out:
# Updated 16 documents

# %%
all_questions = ''.join(questions_list)
print(all_questions)
# Out:
# [
#   {
#     "question": "What type of joint is the hip joint?",
#     "hint": "Think about the structure and function of the hip joint.",
#     "answer": "The hip joint is a ball and socket type of synovial joint.",
#     "extra": "The hip joint is the largest ball and socket type of joint in the body.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "Which structures articulate to form the hip joint?",
#     "hint": "Consider the bones involved in the hip joint.",
#     "answer": "The head of the femur articulates with the acetabulum of the hip bone.",
#     "extra": "The acetabulum of the hip bone and the head of the femur form the hip joint.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "What is the main function of the hip joint?",
#     "hint": "Think about the role of the hip joint in the body.",
#     "answer": "The main functions of the hip joint are to support the body weight during standing and transmit forces generated by movements of the trunk and femur during walking.",
#     "extra": "The hip joint permits similar movements as the shoulder joint in the upper limb.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "Describe the articular surfaces of the hip joint.",
#     "hint": "Consider the specific features of the head of the femur and acetabulum.",
#     "answer": "The head of the femur forms more than half of a sphere and is covered by articular hyaline cartilage. The acetabulum presents a horseshoe-shaped lunate surface, acetabular notch, and acetabular fossa.",
#     "extra": "The depth of the acetabulum is increased by the acetabular labrum.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Why is the range of movement in the hip joint restricted?",
#     "hint": "Think about the role of the hip joint in weight bearing.",
#     "answer": "The range of movement in the hip joint is restricted due to its role in weight bearing.",
#     "extra": "The hip joint permits similar movements as the shoulder joint but has limited range due to its supporting function.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "How does the neck-shaft angle of the femur impact the hip joint movements?",
#     "hint": "Consider the structural anatomy of the femur and its role in hip joint movements.",
#     "answer": "The long and narrow neck of the femur acts as a strut and makes an angle with the shaft, impacting the range of hip joint movements.",
#     "extra": "The neck-shaft angle affects the biomechanics of the hip joint.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What type of variety does the hip joint belong to?",
#     "hint": "Think about the classification of joints based on their structure.",
#     "answer": "The hip joint belongs to the synovial joint of ball and socket variety.",
#     "extra": "Synovial joints are characterized by the presence of a joint cavity containing synovial fluid.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "How does the articular cartilage contribute to the function of the hip joint?",
#     "hint": "Consider the role of articular cartilage in joint movement.",
#     "answer": "The articular cartilage covers the articular surfaces of the hip joint, providing smooth movement and reducing friction.",
#     "extra": "Articular cartilage is essential for the protection and lubrication of joint surfaces.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "Explain the role of the ligamentum teres in the hip joint.",
#     "hint": "Think about the specific function of the ligamentum teres.",
#     "answer": "The ligamentum teres is a ligament that attaches to a small pit called the fovea capitis on the head of the femur.",
#     "extra": "The ligamentum teres is involved in hip joint stability and blood supply to the head of the femur.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What are the functions of the acetabular labrum?",
#     "hint": "Consider the role of the acetabular labrum in the hip joint.",
#     "answer": "The acetabular labrum increases the depth of the acetabulum in the hip joint.",
#     "extra": "The acetabular labrum contributes to the stability of the hip joint.",
#     "difficulty_score": "7"
#   }
# ][
#   {
#     "question": "What are the identifying features of typical lumbar vertebrae?",
#     "hint": "Think about the specific characteristics that distinguish lumbar vertebrae from other vertebrae.",
#     "answer": "The identifying features of typical lumbar vertebrae include massive reniform bodies, absence of costal facets on the body, absence of foramina transversaria in the transverse processes, presence of accessory and mammillary processes, and thick quadrilateral spinous processes.",
#     "extra": "Typical lumbar vertebrae, such as L1 to L4, have specific characteristics that set them apart from other vertebrae in the spine.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "What is the term used for the ribs that do not articulate with the transverse processes of thoracic vertebrae or adjacent costal cartilages?",
#     "hint": "Think about ribs that have more freedom of movement compared to others.",
#     "answer": "The ribs that do not articulate with the transverse processes of thoracic vertebrae or adjacent costal cartilages are termed floating ribs.",
#     "extra": "Ribs 11 and 12 are considered floating ribs because they are shorter and do not attach directly to the thoracic vertebrae.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "How many typical lumbar vertebrae are there, and what distinguishes the atypical lumbar vertebrae?",
#     "hint": "Consider the number and unique characteristics of the different lumbar vertebrae.",
#     "answer": "There are five typical lumbar vertebrae (L1 to L4) and the atypical lumbar vertebra (L5) differs from the typical ones in structure and function.",
#     "extra": "Lumbar vertebrae play a crucial role in supporting the weight of the upper body and protecting the spinal cord.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "Describe the body of a typical lumbar vertebra in terms of shape and size.",
#     "hint": "Think about the specific shape and size characteristics mentioned in the context.",
#     "answer": "The body of a typical lumbar vertebra is massive, reniform, and the transverse diameter is greater than the anteroposterior diameter.",
#     "extra": "Understanding the shape and size of the lumbar vertebrae can help in identifying them.",
#     "difficulty_score": "2"
#   },
#   {
#     "question": "What is the term used for the ribs that articulate with each other to form the costal margin?",
#     "hint": "Think about how the ribs connect with each other in the ribcage.",
#     "answer": "The ribs that articulate with each other to form the costal margin are the 7th, 8th, 9th, and 10th ribs.",
#     "extra": "Costal cartilages of these ribs play a significant role in supporting the structure of the ribcage.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "What feature distinguishes the lumbar vertebrae from the thoracic vertebrae in terms of the bodies?",
#     "hint": "Think about what is absent on the lumbar vertebrae bodies compared to the thoracic vertebrae bodies.",
#     "answer": "The lumbar vertebrae bodies lack costal facets, which are present on the bodies of thoracic vertebrae.",
#     "extra": "This absence of costal facets in lumbar vertebrae reflects their different function and structure compared to thoracic vertebrae.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Why are the 11th and 12th ribs termed floating ribs?",
#     "hint": "Consider how the movement and attachment of these ribs differ from the other ribs.",
#     "answer": "The 11th and 12th ribs are termed floating ribs because they do not articulate with the transverse processes of thoracic vertebrae or adjacent costal cartilages, allowing them to move independently.",
#     "extra": "Floating ribs provide flexibility to the ribcage and allow for certain movements that other ribs cannot execute.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What is the significance of the accessory and mammillary processes in the lumbar vertebrae?",
#     "hint": "Think about the additional processes present in the lumbar vertebrae and their purpose.",
#     "answer": "The accessory and mammillary processes in lumbar vertebrae serve as attachment points for ligaments and muscles, contributing to stability and movement.",
#     "extra": "Understanding the role of these processes can help in grasping the overall function of lumbar vertebrae in the spine.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "How does the size of the body of a lumbar vertebra change progressively from L1 to L5?",
#     "hint": "Consider the anterior and posterior dimensions of the lumbar vertebral bodies.",
#     "answer": "The size of the body of lumbar vertebrae increases progressively from L1 to L5, with the length of the body being slightly greater anteriorly.",
#     "extra": "This progressive change in size reflects the differences in load-bearing capacity and function along the lumbar spine.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What specific characteristic of the lumbar vertebrae contributes to the forward convexity of the lumbar vertebral column?",
#     "hint": "Think about the shape or feature of the lumbar vertebrae that influences the curvature of the spine.",
#     "answer": "The length of the body of lumbar vertebrae being slightly greater anteriorly contributes to the forward convexity of the lumbar vertebral column.",
#     "extra": "Understanding the anatomy of the spine can help in recognizing the natural curves that provide stability and flexibility.",
#     "difficulty_score": "4"
#   }
# ][
#   {
#     "question": "What is the atypical feature of the first rib?",
#     "hint": "Think about the unique shape and attachments of the first rib.",
#     "answer": "The first rib is the shortest and most curved rib, with only one facet for articulation on the head.",
#     "extra": "The first rib is also the only rib that has a scalene tubercle for muscle attachment.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "How can you differentiate the second rib from other ribs?",
#     "hint": "Consider the distinguishing characteristics of the second rib compared to the others.",
#     "answer": "The second rib has two facets for articulation on the head, one for the same-numbered vertebra and one for the vertebra above.",
#     "extra": "The second rib is longer and more curved than the first rib but not as much as the later ribs.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What makes the 11th and 12th ribs atypical compared to the typical ribs?",
#     "hint": "Think about the lack of certain features in the 11th and 12th ribs.",
#     "answer": "The 11th and 12th ribs do not have necks or tubercles and only articulate with their corresponding vertebrae.",
#     "extra": "These ribs are also known as 'floating ribs' since they do not attach to the sternum.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Why are the first and second ribs considered atypical?",
#     "hint": "Consider the unique characteristics of the first and second ribs compared to the others.",
#     "answer": "The first and second ribs are atypical due to their specific shapes and articulation features that differ from the rest of the ribs.",
#     "extra": "These atypical ribs play crucial roles in protecting vital structures such as blood vessels and nerves.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "What is the clinical significance of the 11th and 12th ribs as 'floating ribs'?",
#     "hint": "Think about the implications of the lack of sternal attachment.",
#     "answer": "The 11th and 12th ribs are more prone to injuries such as fractures due to their lack of sternal attachment for protection.",
#     "extra": "Clinical examination of the 'floating ribs' is important in determining potential trauma or underlying conditions.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "How do the attachments of the first rib differ from the 11th rib?",
#     "hint": "Compare the specific attachments of the first and 11th ribs.",
#     "answer": "The first rib has a scalene tubercle for muscle attachment while the 11th rib lacks tubercles and only articulates with its corresponding vertebra.",
#     "extra": "Understanding these differences is essential for recognizing each rib's unique anatomical features and functions.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What role do the scalene muscles play in relation to the first rib?",
#     "hint": "Think about the specific muscle attachments on the first rib.",
#     "answer": "The scalene muscles attached to the scalene tubercle on the first rib are important for respiration and neck movement.",
#     "extra": "Injury or hypertonicity of the scalene muscles can lead to respiratory and postural issues.",
#     "difficulty_score": "9"
#   },
#   {
#     "question": "How do the costal cartilages of atypical ribs differ from typical ribs?",
#     "hint": "Consider the sternal attachment variations between atypical and typical ribs.",
#     "answer": "The 1st and 2nd ribs have costal cartilages that directly articulate with the sternum, unlike the floating 11th and 12th ribs.",
#     "extra": "This direct sternal attachment gives added support and stability to the thoracic cage.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What is the embryological reason behind the uniqueness of atypical ribs?",
#     "hint": "Think about how the development of these ribs differs from others.",
#     "answer": "The atypical ribs retain characteristics reminiscent of earlier species during embryonic development stages.",
#     "extra": "These unique features can be attributed to the evolution of the rib structure in different species over time.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "How do thoracic outlet syndrome symptoms relate to the first rib?",
#     "hint": "Consider the anatomical location of the first rib and its potential implications.",
#     "answer": "The compression of nerves and blood vessels superior to the first rib can lead to thoracic outlet syndrome symptoms.",
#     "extra": "Understanding the anatomical relationships of the first rib is crucial for diagnosing and treating thoracic outlet syndrome.",
#     "difficulty_score": "8"
#   }
# ][
#   {
#     "question": "What is the anatomical name for the 2nd cervical vertebra and why is it called so?",
#     "hint": "It forms a pivot for the skull.",
#     "answer": "The 2nd cervical vertebra is called the axis because its odontoid process forms a pivot around which atlas rotates and carries the skull.",
#     "extra": "The axis is named after the mythological Greek Titan 'Atlas' who was reputed to support the heavens on his shoulders.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "Describe the structural characteristics of the atlas and the axis vertebrae.",
#     "hint": "The atlas has a ring-like structure with lateral masses connected by an arch.",
#     "answer": "The atlas has neither body nor spine and consists of two lateral masses connected by a short anterior arch and long posterior arch. The axis possesses a tooth-like odontoid process projecting upwards from the body.",
#     "extra": "Structural differences in the atlas and axis make them specialized vertebrae with unique functions.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "What is the clinical importance of joints in the neck?",
#     "hint": "Consider conditions like spondylosis and disc prolapse.",
#     "answer": "The joints of the neck are clinically important due to the high incidence of spondylosis, disc prolapse, and fracture dislocation in the cervical region.",
#     "extra": "Understanding neck joints is crucial for diagnosing and treating various spinal conditions.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "Explain the types of joints found between lower 6 cervical vertebrae.",
#     "hint": "Include joints between vertebral bodies, vertebral arches, and processes.",
#     "answer": "The joints between lower 6 cervical vertebrae include joints between the vertebral bodies, vertebral arches, and vertebral articular processes.",
#     "extra": "Detailed knowledge of cervical joints aids in understanding neck movement and stability.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "What are secondary cartilaginous joints between the vertebral bodies?",
#     "hint": "These joints involve articular surfaces covered by hyaline cartilage.",
#     "answer": "Secondary cartilaginous joints between vertebral bodies involve articulations between adjacent vertebrae covered by hyaline cartilage and an intervertebral disc.",
#     "extra": "Secondary cartilaginous joints play a crucial role in spinal flexibility and shock absorption.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Describe the structure and composition of an intervertebral disc.",
#     "hint": "Include the layers forming the disc and the central part.",
#     "answer": "An intervertebral disc consists of an outer part formed by a series of fibrocartilaginous laminae called annulus fibrosus and an inner part made of jelly-like material called nucleus pulposus.",
#     "extra": "Intervertebral discs provide cushioning between vertebrae and contribute to spinal flexibility.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What is the role of the anterior longitudinal ligament in the neck region?",
#     "hint": "Think about its position and function in supporting the vertebrae.",
#     "answer": "The anterior longitudinal ligament extends anterior to the anterior arch of the atlas and bodies of the remaining cervical vertebrae, providing strong support and stability.",
#     "extra": "The anterior longitudinal ligament helps maintain the alignment of cervical vertebrae and supports the spinal column.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Explain the function of the joints between the 1st and 2nd cervical vertebrae.",
#     "hint": "Consider the type of movement permitted by these joints.",
#     "answer": "The joints between the 1st and 2nd cervical vertebrae allow rotation of the head.",
#     "extra": "Understanding the specific movements facilitated by different cervical joints is essential for normal neck function.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "What distinguishes the typical cervical joints from other cervical vertebrae joints?",
#     "hint": "Consider the location and structure of these joints.",
#     "answer": "The typical cervical joints are the joints between lower 6 cervical vertebrae, including joints between the vertebral bodies, arches, and articular processes.",
#     "extra": "Typical cervical joints have specific characteristics that differentiate them from other cervical vertebrae joints in the spine.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "How do the lower cervical joints in the neck region differ in function compared to other vertebral joints?",
#     "hint": "Think about the range of motion allowed by these joints.",
#     "answer": "The joints between the lower 6 cervical vertebrae permit flexion, extension, and lateral bending but limited rotation compared to other vertebral joints.",
#     "extra": "Understanding the functional differences in cervical joints assists in diagnosing and treating neck-related conditions.",
#     "difficulty_score": "4"
#   }
# ][
#   {
#     "question": "What structures strengthen the cervical pleura to prevent the root of the neck from puffing up and down during respiration?",
#     "hint": "Think about the membrane that supports the cervical pleura.",
#     "answer": "The suprapleural membrane, also known as Sibson's fascia, strengthens the cervical pleura.",
#     "extra": "The suprapleural membrane plays a crucial role in stabilizing the cervical pleura to prevent movement during respiration.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Which structures are found in the anterior relation of the root of the neck?",
#     "hint": "Consider the arteries and muscles located in the front area of the neck.",
#     "answer": "Subclavian artery and Scalenus anterior are located in the anterior relation of the root of the neck.",
#     "extra": "Understanding the anatomical relations helps in identifying structures in the neck area.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What structures are located in the lateral relation of the root of the neck?",
#     "hint": "Think about the brachial plexus components in the lateral neck area.",
#     "answer": "Scalenus medius and Lower trunk of brachial plexus are situated in the lateral relation of the root of the neck.",
#     "extra": "Knowledge of the lateral structures in the neck region aids in understanding nerve and vessel distributions.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What important nerve runs in the tracheoesophageal groove at the medial relation of the root of the neck?",
#     "hint": "Consider the nerve related to the tracheoesophageal groove.",
#     "answer": "The recurrent laryngeal nerve is present in the tracheoesophageal groove at the medial relation of the root of the neck.",
#     "extra": "The recurrent laryngeal nerve plays a vital role in innervating muscles related to the larynx.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "Which lymph trunks converge at the root of the neck, draining lymph from the head and neck region?",
#     "hint": "Think about the lymphatic drainage paths from the head and neck.",
#     "answer": "The left and right lymph trunks converge at the root of the neck to drain lymph from the head and neck region.",
#     "extra": "Understanding lymphatic drainage patterns is crucial for clinical implications and immune response knowledge.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Describe the course of the right jugular trunk and its drainage areas.",
#     "hint": "Focus on the region drained by the jugular trunk.",
#     "answer": "The right jugular trunk drains lymph from the right half of the head and neck.",
#     "extra": "Detailed knowledge of lymph trunks helps in understanding the flow of lymphatic fluids in the head and neck region.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "Which muscle forms the middle layer in the anterior abdominal wall?",
#     "hint": "Consider the arrangement of the flat muscles in the abdomen.",
#     "answer": "The internal oblique muscle forms the middle layer in the anterior abdominal wall.",
#     "extra": "Understanding the layering of muscles aids in recognizing their functions in abdominal support.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Where does the external oblique muscle originate from?",
#     "hint": "Think about the attachment points of the external oblique muscle.",
#     "answer": "The external oblique muscle arises from the lower eight ribs.",
#     "extra": "Knowledge of muscle origins provides insight into their actions and related structures.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What is the insertion point of the external oblique muscle on the iliac crest?",
#     "hint": "Consider the direction of fiber movement towards the iliac crest.",
#     "answer": "The external oblique muscle inserts onto the outer lip of the anterior two-thirds of the iliac crest.",
#     "extra": "Understanding muscle insertions helps in grasping the action and function of the muscle in the abdominal wall.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Describe the aponeurosis of the external oblique muscle in relation to the linea alba.",
#     "hint": "Focus on the relation between the aponeurosis and the midline structure of the abdomen.",
#     "answer": "The aponeurosis of the external oblique muscle fuses with other muscle aponeuroses to form the linea alba.",
#     "extra": "The fusion of aponeuroses in the midline provides support and structural integrity to the abdominal wall.",
#     "difficulty_score": "7"
#   }
# ][
# {
# "question": "What is the primary cause of angina pectoris?",
# "hint": "It involves an imbalance between oxygen requirement and supply.",
# "answer": "The primary cause is an imbalance between the oxygen requirement of the heart and the oxygen supplied to it via the coronary vessels.",
# "extra": "The imbalance leads to myocardial ischemia and chest pain.",
# "difficulty_score": "3"
# },
# {
# "question": "What term is defined as chest pain caused by the accumulation of metabolites resulting from myocardial ischemia?",
# "hint": "It is the reason behind chest discomfort in angina pectoris.",
# "answer": "Angina pectoris denotes chest pain caused by the accumulation of metabolites resulting from myocardial ischemia.",
# "extra": "It is a common condition involving tissue ischemia.",
# "difficulty_score": "4"
# },
# {
# "question": "What is the mainstay of therapy for immediate relief of angina pectoris?",
# "hint": "It is a type of vasodilator.",
# "answer": "The organic nitrates, such as nitroglycerin.",
# "extra": "They help in providing immediate relief from angina symptoms.",
# "difficulty_score": "4"
# },
# {
# "question": "What is the most common condition involving tissue ischemia where vasodilator drugs are used?",
# "hint": "It is a common cardiovascular disease.",
# "answer": "Angina pectoris.",
# "extra": "It causes chest pain due to ischemia.",
# "difficulty_score": "4"
# },
# {
# "question": "What is variant angina also known as?",
# "hint": "It is a term synonymously used for a certain type of angina.",
# "answer": "Prinzmetal angina.",
# "extra": "It is caused by reversible coronary vasospasm.",
# "difficulty_score": "5"
# },
# {
# "question": "How is the diagnosis of angina pectoris usually made?",
# "hint": "It involves a specific method based on symptoms and stress testing.",
# "answer": "Diagnosis is usually made on the basis of the history and stress testing.",
# "extra": "A history of chest discomfort during exercise is crucial for diagnosis.",
# "difficulty_score": "6"
# },
# {
# "question": "What is the imbalance that leads to the occurrence of effort angina?",
# "hint": "It is associated with insufficient blood flow during increased oxygen demand.",
# "answer": "The imbalance between myocardial oxygen requirement and coronary blood flow.",
# "extra": "In effort angina, the imbalance occurs mainly during physical exertion.",
# "difficulty_score": "7"
# },
# {
# "question": "What is the general term for the accumulation of metabolites in the myocardium caused by inadequate blood flow?",
# "hint": "It involves an accumulation of acidic byproducts.",
# "answer": "Ischemia.",
# "extra": "Myocardial ischemia leads to the accumulation of acidic metabolites.",
# "difficulty_score": "6"
# },
# {
# "question": "Why does ischemia result in pain in the context of angina pectoris?",
# "hint": "It involves a specific factor related to blood flow.",
# "answer": "Coronary flow reserve is impaired, leading to ischemia and pain.",
# "extra": "Endothelial dysfunction can contribute to inadequate vasodilation and blood flow.",
# "difficulty_score": "8"
# },
# {
# "question": "What are two types of angina based on the underlying mechanism of oxygen deficiency?",
# "hint": "One type involves fixed obstruction and the other involves vasospasm.",
# "answer": "Effort angina and variant angina.",
# "extra": "Effort angina is related to atheromatous obstruction, while variant angina involves vasospasm.",
# "difficulty_score": "9"
# }
# ][
#   {
#     "question": "What are the three parts of the subclavian artery divided by?",
#     "hint": "Think about the anatomical structure that separates the different sections of the subclavian artery.",
#     "answer": "The three parts of the subclavian artery are divided by the scalenus anterior muscle.",
#     "extra": "The subclavian artery is divided into three parts by the scalenus anterior muscle on each side.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "Where does the first part of the subclavian artery extend from and to?",
#     "hint": "Consider the specific anatomical landmarks mentioned in the context.",
#     "answer": "The first part of the subclavian artery extends from the origin to the medial border of the scalenus anterior.",
#     "extra": "The first part of the subclavian artery extends from its origin to the medial border of the scalenus anterior muscle.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "What are the anatomical relations of the first part of the subclavian artery?",
#     "hint": "Think about the structures mentioned in the context that are in proximity to the first part of the subclavian artery.",
#     "answer": "The anatomical relations of the first part of the subclavian artery include the common carotid artery, internal jugular vein, vagus nerve, vertebral vein, phrenic nerve, sternocleidomastoid, sternothyroid, and sternohyoid muscles.",
#     "extra": "The first part of the subclavian artery is related to various important structures such as the vagus nerve and phrenic nerve.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "Where does the second part of the subclavian artery lie?",
#     "hint": "Consider the anatomical location described in relation to the scalenus anterior muscle.",
#     "answer": "The second part of the subclavian artery lies behind the scalenus anterior muscle.",
#     "extra": "The second part of the subclavian artery is located posterior to the scalenus anterior muscle.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Describe the termination point of the subclavian artery.",
#     "hint": "Consider where the subclavian artery transitions into another arterial vessel.",
#     "answer": "The subclavian artery terminates at the outer border of the first rib where it continues as the axillary artery.",
#     "extra": "The subclavian artery transitions into the axillary artery at the outer border of the first rib.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What is the origin of the right subclavian artery?",
#     "hint": "Think about where the right subclavian artery arises from compared to the left subclavian artery.",
#     "answer": "The right subclavian artery arises from the brachiocephalic trunk.",
#     "extra": "The right subclavian artery originates from the brachiocephalic trunk instead of directly from the arch of aorta like the left subclavian artery.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Which muscle separates the first and the second part of the subclavian artery?",
#     "hint": "Consider the muscle that is in between the different sections of the subclavian artery.",
#     "answer": "The scalenus anterior muscle separates the first and second parts of the subclavian artery.",
#     "extra": "The scalenus anterior muscle acts as a boundary between the first and second parts of the subclavian artery.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "Name one of the arteries that is related to the second part of the subclavian artery.",
#     "hint": "Think about the arteries mentioned in the context that are in proximity to the second part of the subclavian artery.",
#     "answer": "The suprascapular artery is related to the second part of the subclavian artery.",
#     "extra": "The suprascapular artery is one of the arteries associated with the second part of the subclavian artery.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "What structures are in close relation to the third part of the subclavian artery?",
#     "hint": "Consider the structures mentioned in the context that are associated with the third part of the subclavian artery.",
#     "answer": "The lower trunk of the brachial plexus and the phrenic nerve are closely related to the third part of the subclavian artery.",
#     "extra": "The lower trunk of the brachial plexus and the phrenic nerve are anatomically related to the third part of the subclavian artery.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "Differentiate the origin of the left and right subclavian arteries.",
#     "hint": "Consider where each subclavian artery directly arises from.",
#     "answer": "The right subclavian artery arises from the brachiocephalic trunk, while the left subclavian artery arises directly from the arch of aorta.",
#     "extra": "The origins of the right and left subclavian arteries are distinct, with the right originating from the brachiocephalic trunk and the left arising directly from the arch of aorta.",
#     "difficulty_score": "9"
#   }
# ]```json
# [
#   {
#     "question": "What antiviral compounds provide effective therapy for varicella?",
#     "hint": "These compounds include acyclovir, valacyclovir, famciclovir, and foscarnet.",
#     "answer": "Acyclovir, valacyclovir, famciclovir, and foscarnet provide effective therapy for varicella.",
#     "extra": "Acyclovir can prevent systemic disease in immunosuppressed patients and halt progression of herpes zoster in adults.",
#     "difficulty_score": "2"
#   },
#   {
#     "question": "What is the primary target cell for Epstein-Barr Virus (EBV)?",
#     "hint": "The target cell is related to the lymphocyte system.",
#     "answer": "The major target cell for EBV is the B lymphocyte.",
#     "extra": "When human B lymphocytes are infected with EBV, cell lines can be established, indicating cell immortalization.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "What percentage of individuals develop a mild rash after receiving the varicella vaccine?",
#     "hint": "It is a low percentage, related to a very specific reaction.",
#     "answer": "About 5% of individuals develop a mild vaccine-associated rash 1 month after immunization.",
#     "extra": "The varicella vaccine is highly effective in preventing severe disease.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Which cells are responsible for the latent infections of Herpes Simplex Viruses (HSV)?",
#     "hint": "These are a type of cells where the viruses hide and reactivate.",
#     "answer": "HSV establishes latent infections in nerve cells.",
#     "extra": "Recurrences of HSV infections are common due to the ability of the virus to reactivate from nerve cells.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "What is the primary difference between HSV-1 and HSV-2?",
#     "hint": "It is related to their transmission routes.",
#     "answer": "HSV-1 is spread by contact, usually involving infected saliva, while HSV-2 is transmitted sexually or from a maternal genital infection to a newborn.",
#     "extra": "Both HSV types can cause a range of diseases, with transmission routes becoming less distinct.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What is the purpose of Varicella-zoster immune globulin (VariZIG)?",
#     "hint": "It is used for a specific post-exposure prophylaxis.",
#     "answer": "VariZIG is available for post-exposure prophylaxis of high-risk patients who lack serologic evidence of immunity.",
#     "extra": "Standard immune globulin is ineffective due to low titers of varicella antibodies.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Why is acyclovir considered effective in preventing systemic disease in varicella-infected immunosuppressed patients?",
#     "hint": "It is related to the mechanism of action of acyclovir.",
#     "answer": "Acyclovir can prevent systemic disease by inhibiting viral replication.",
#     "extra": "Acyclovir halts the progression of herpes zoster but does not prevent postherpetic neuralgia.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "What are the primary herpesvirus infections caused by Epstein-Barr Virus (EBV)?",
#     "hint": "These are specific diseases linked to EBV infection.",
#     "answer": "EBV is associated with acute infectious mononucleosis and various lymphomas.",
#     "extra": "EBV is also linked to nasopharyngeal carcinoma, Burkitt lymphoma, and other lymphoproliferative disorders.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What is the recommended schedule for varicella vaccination in children?",
#     "hint": "It involves the number of doses for optimal protection.",
#     "answer": "In 2006, two doses of the varicella vaccine were recommended for children.",
#     "extra": "The two-dose schedule is over 98% effective in preventing varicella disease.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "How does the zoster vaccine differ from the varicella vaccine?",
#     "hint": "It is related to the potency and target population of the vaccines.",
#     "answer": "The zoster vaccine is a higher potency version of the varicella vaccine, recommended for older adults.",
#     "extra": "The zoster vaccine reduces the frequency and severity of outbreaks in older adults.",
#     "difficulty_score": "7"
#   }
# ]
# ```[
#   {
#     "question": "What type of blood cell is usually increased in patients with pneumonia?",
#     "hint": "Think about the cells responsible for fighting infections.",
#     "answer": "Leukocytes with increased PMN cells.",
#     "extra": "Chest radiography shows segmental or lobar infiltrates in pneumonia patients.",
#     "difficulty_score": "2"
#   },
#   {
#     "question": "Why is thoracentesis done in patients with pneumonia?",
#     "hint": "Consider the purpose of obtaining fluid from the pleural space.",
#     "answer": "To obtain fluid for cell counts and culture and for therapeutic purposes.",
#     "extra": "Empyema is a common reason for performing thoracentesis in pneumonia patients.",
#     "difficulty_score": "3"
#   },
#   {
#     "question": "What is the significance of sputum examination in pneumonia diagnosis?",
#     "hint": "Think about the presence of specific types of cells and staining techniques.",
#     "answer": "Sputum examination can help determine the cause of pneumonia.",
#     "extra": "Gram staining and microscopic examination of sputum are essential diagnostic tools.",
#     "difficulty_score": "4"
#   },
#   {
#     "question": "Why are blood cultures done in patients admitted to the hospital with acute pneumonia?",
#     "hint": "Consider the aim of identifying potential pathogens circulating in the bloodstream.",
#     "answer": "To detect circulating antigens of specific organisms causing pneumonia.",
#     "extra": "Positive blood cultures are crucial for confirming the etiology of pneumonia.",
#     "difficulty_score": "5"
#   },
#   {
#     "question": "How does rust-colored sputum relate to the type of pneumonia?",
#     "hint": "Think about the specific pathogens associated with this type of sputum.",
#     "answer": "Rust-colored sputum suggests alveolar involvement and is associated with pneumococcal pneumonia.",
#     "extra": "Different types of sputum color can provide clues to the etiology of pneumonia.",
#     "difficulty_score": "6"
#   },
#   {
#     "question": "What is the clinical significance of bronchoscopy in pneumonia diagnosis?",
#     "hint": "Consider the role of obtaining samples for diagnostic studies.",
#     "answer": "Bronchoscopy is used to obtain material for diagnostic studies in severely ill pneumonia patients.",
#     "extra": "Quantitative bacterial culture performed on bronchoalveolar lavage is useful for bacterial pneumonia diagnosis.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "Why are multiplex nucleic acid amplification methods used in pneumonia diagnosis?",
#     "hint": "Think about the benefits of detecting viral pneumonia and atypical pathogens.",
#     "answer": "To assist in the diagnosis of viral pneumonia and atypical pathogens causing pneumonia.",
#     "extra": "These methods are valuable in identifying specific viral pathogens causing pneumonia.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What is the role of Gram staining in sputum examination for pneumonia?",
#     "hint": "Consider how staining techniques can aid in identifying microbial pathogens.",
#     "answer": "Gram staining helps differentiate various microbial pathogens present in sputum samples.",
#     "extra": "Identifying Gram-positive or Gram-negative bacteria is crucial for determining the cause of pneumonia.",
#     "difficulty_score": "7"
#   },
#   {
#     "question": "Why is bronchoalveolar lavage preferred for obtaining specimens in pneumonia diagnosis?",
#     "hint": "Think about the method used for collecting samples from the lungs.",
#     "answer": "BAL is useful for establishing the etiology of bacterial pneumonia in patients not treated with antibiotics.",
#     "extra": "Bronchoscopy with BAL can also detect nonbacterial pathogens such as filamentous molds.",
#     "difficulty_score": "8"
#   },
#   {
#     "question": "What type of bacterial quantity in BAL samples is considered clinically significant for bacterial pneumonia diagnosis?",
#     "hint": "Consider the cutoff limit for identifying specific bacterial pathogens.",
#     "answer": "Using 104 colony-forming units (CFU)/mL of a specific pathogen per sample as the cutoff for clinical significance.",
#     "extra": "Quantitative culture on BAL samples aids in determining the etiology of bacterial pneumonia.",
#     "difficulty_score": "9"
#   }
# ]1. What is the length of the cervical part of the trachea and where does it extend from and to?
# 2. HINT: The cervical part of the trachea is about 7 cm in length and has specific anatomical boundaries.
# 3. ANSWER: The cervical part of the trachea is about 7 cm in length, extending from the lower border of the cricoid cartilage to the upper border of the manubrium sterni.
# 4. ADDITIONAL INFORMATION: Understanding the length and location of the cervical part of the trachea is essential for proper anatomical knowledge.
# 5. DIFFICULTY SCORE: 3
#
# QUESTION:
# 2. Which arteries mainly supply the cervical part of the trachea, and where do the veins from the trachea drain into?
# 3. HINT: The arterial supply comes from specific branches and the veins drain into a major vein.
# 4. ANSWER: The arterial supply of the cervical part of the trachea is mainly from branches of the inferior thyroid arteries. The veins from the trachea drain into the left brachiocephalic vein.
# 5. ADDITIONAL INFORMATION: Knowledge of the blood supply and drainage of the trachea is crucial for understanding its vascular anatomy.
# 6. DIFFICULTY SCORE: 4
#
# QUESTION:
# 3. Describe the nerves that supply the cervical part of the trachea and their functions.
# 4. HINT: The nerve supply involves both sympathetic and parasympathetic fibers with specific functions.
# 5. ANSWER: The cervical part of the trachea is supplied by sympathetic and parasympathetic fibers. The parasympathetic fibers are derived from the vagus through the recurrent laryngeal nerve, contributing to sensory, motor, and secretomotor functions. The sympathetic fibers are derived from the middle cervical sympathetic ganglion and have vasomotor functions.
# 6. ADDITIONAL INFORMATION: Understanding the nerve supply to the trachea is essential for grasping its physiological functions.
# 7. DIFFICULTY SCORE: 5
#
# QUESTION:
# 4. Explain the procedure and anatomical considerations involved in performing a tracheostomy.
# 5. HINT: Tracheostomy involves a specific surgical procedure and has different types based on anatomical landmarks.
# 6. ANSWER: Tracheostomy is a life-saving surgical procedure performed in cases of laryngeal obstruction. It involves making a vertical incision in the region of the 3rd and 4th or 2nd and 3rd tracheal rings, which is then converted into a circular opening for inserting a tracheostomy tube. The procedure can be performed above (high tracheostomy) or below (low tracheostomy) the isthmus of the thyroid gland, with the latter being riskier in children.
# 7. ADDITIONAL INFORMATION: Anatomical considerations are crucial in performing tracheostomy safely and effectively.
# 8. DIFFICULTY SCORE: 7
#
# QUESTION:
# 5. How is the esophagus related to the trachea anatomically?
# 6. HINT: The esophagus is related to the trachea in specific regions based on their anatomical position.
# 7. ANSWER: The esophagus is located behind the trachea, with the trachea positioned anteriorly to the esophagus in the cervical region. Both structures have important relations in the neck and thorax.
# 8. ADDITIONAL INFORMATION: Understanding the anatomical relationship between the esophagus and trachea is important for clinical correlations and surgical procedures.
# 9. DIFFICULTY SCORE: 3
#
# QUESTION:
# 6. What are the key hormones secreted by the thyroid gland, and what functions do they serve?
# 7. HINT: The thyroid gland secretes specific hormones that play crucial roles in the body.
# 8. ANSWER: The thyroid gland secretes hormones such as triiodothyronine (T3), thyroxine (T4), and calcitonin. These hormones regulate the basal metabolic rate, contribute to growth, and are involved in calcium metabolism in the body.
# 9. ADDITIONAL INFORMATION: Understanding the functions of thyroid hormones is essential for comprehending endocrine physiology.
# 10. DIFFICULTY SCORE: 4
#
# QUESTION:
# 7. Where is the thyroid gland located in the body, and what is its unique feature regarding blood flow?
# 8. HINT: The thyroid gland's location and special characteristic related to blood flow should be considered.
# 9. ANSWER: The thyroid gland is located in the lower part of the front and side of the neck, opposite to specific vertebrae. It has a very rich blood flow compared to other organs in the body.
# 10. ADDITIONAL INFORMATION: Knowing the unique location and blood flow characteristics of the thyroid gland helps in understanding its physiological significance.
# 11. DIFFICULTY SCORE: 5
#
# QUESTION:
# 8. Describe the parts and features of the thyroid gland based on its structure.
# 9. HINT: The thyroid gland has specific structural components that form its overall shape.
# 10. ANSWER: The thyroid gland is H-shaped, consisting of vertical right and left lateral lobes connected by a horizontal isthmus across the midline. Occasionally, a pyramidal lobe may project upwards from the isthmus, typically to the left of the midline.
# 11. ADDITIONAL INFORMATION: Understanding the structural anatomy of the thyroid gland is crucial for clinical evaluations and surgical interventions.
# 12. DIFFICULTY SCORE: 6
#
# QUESTION:
# 9. How does the thyroid gland depend on the external environment for the synthesis of its hormones?
# 10. HINT: The thyroid gland requires a specific external factor for the production of its hormones.
# 11. ANSWER: The thyroid gland depends on the external environment for iodine, which is essential for the synthesis of its hormones like T3 and T4.
# 12. ADDITIONAL INFORMATION: Knowledge of the role of iodine in thyroid hormone synthesis is important for understanding endocrine physiology.
# 13. DIFFICULTY SCORE: 7
#
# QUESTION:
# 10. Why is the thyroid gland accessible for physical examination, and how does it differ in hormone release compared to other glands?
# 11. HINT: The thyroid gland's unique features make it accessible for examination and storage of hormones.
# 12. ANSWER: The thyroid gland is easily accessible for physical examination due to its superficial location. Unlike other endocrine glands, it stores its hormones and releases them into the bloodstream as needed, rather than immediately after formation.
# 13. ADDITIONAL INFORMATION: Understanding the unique characteristics of the thyroid gland aids in clinical assessments and treatment strategies for endocrine disorders.
# 14. DIFFICULTY SCORE: 8

# %%
questions_list[9]
# Out:
# "1. What is the length of the cervical part of the trachea and where does it extend from and to?\n2. HINT: The cervical part of the trachea is about 7 cm in length and has specific anatomical boundaries.\n3. ANSWER: The cervical part of the trachea is about 7 cm in length, extending from the lower border of the cricoid cartilage to the upper border of the manubrium sterni.\n4. ADDITIONAL INFORMATION: Understanding the length and location of the cervical part of the trachea is essential for proper anatomical knowledge.\n5. DIFFICULTY SCORE: 3\n\nQUESTION:\n2. Which arteries mainly supply the cervical part of the trachea, and where do the veins from the trachea drain into?\n3. HINT: The arterial supply comes from specific branches and the veins drain into a major vein.\n4. ANSWER: The arterial supply of the cervical part of the trachea is mainly from branches of the inferior thyroid arteries. The veins from the trachea drain into the left brachiocephalic vein.\n5. ADDITIONAL INFORMATION: Knowledge of the blood supply and drainage of the trachea is crucial for understanding its vascular anatomy.\n6. DIFFICULTY SCORE: 4\n\nQUESTION: \n3. Describe the nerves that supply the cervical part of the trachea and their functions.\n4. HINT: The nerve supply involves both sympathetic and parasympathetic fibers with specific functions.\n5. ANSWER: The cervical part of the trachea is supplied by sympathetic and parasympathetic fibers. The parasympathetic fibers are derived from the vagus through the recurrent laryngeal nerve, contributing to sensory, motor, and secretomotor functions. The sympathetic fibers are derived from the middle cervical sympathetic ganglion and have vasomotor functions.\n6. ADDITIONAL INFORMATION: Understanding the nerve supply to the trachea is essential for grasping its physiological functions.\n7. DIFFICULTY SCORE: 5\n\nQUESTION: \n4. Explain the procedure and anatomical considerations involved in performing a tracheostomy.\n5. HINT: Tracheostomy involves a specific surgical procedure and has different types based on anatomical landmarks.\n6. ANSWER: Tracheostomy is a life-saving surgical procedure performed in cases of laryngeal obstruction. It involves making a vertical incision in the region of the 3rd and 4th or 2nd and 3rd tracheal rings, which is then converted into a circular opening for inserting a tracheostomy tube. The procedure can be performed above (high tracheostomy) or below (low tracheostomy) the isthmus of the thyroid gland, with the latter being riskier in children.\n7. ADDITIONAL INFORMATION: Anatomical considerations are crucial in performing tracheostomy safely and effectively.\n8. DIFFICULTY SCORE: 7\n\nQUESTION: \n5. How is the esophagus related to the trachea anatomically?\n6. HINT: The esophagus is related to the trachea in specific regions based on their anatomical position.\n7. ANSWER: The esophagus is located behind the trachea, with the trachea positioned anteriorly to the esophagus in the cervical region. Both structures have important relations in the neck and thorax.\n8. ADDITIONAL INFORMATION: Understanding the anatomical relationship between the esophagus and trachea is important for clinical correlations and surgical procedures.\n9. DIFFICULTY SCORE: 3\n\nQUESTION:\n6. What are the key hormones secreted by the thyroid gland, and what functions do they serve?\n7. HINT: The thyroid gland secretes specific hormones that play crucial roles in the body.\n8. ANSWER: The thyroid gland secretes hormones such as triiodothyronine (T3), thyroxine (T4), and calcitonin. These hormones regulate the basal metabolic rate, contribute to growth, and are involved in calcium metabolism in the body.\n9. ADDITIONAL INFORMATION: Understanding the functions of thyroid hormones is essential for comprehending endocrine physiology.\n10. DIFFICULTY SCORE: 4\n\nQUESTION: \n7. Where is the thyroid gland located in the body, and what is its unique feature regarding blood flow?\n8. HINT: The thyroid gland's locat ...

# %%
import csv
import io

text = '''Question,Hint,Answer,Additional Information,Difficulty Score
"What is the length of the cervical part of the trachea and where does it extend from and to?","The cervical part of the trachea is about 7 cm in length and has specific anatomical boundaries.","The cervical part of the trachea is about 7 cm in length, extending from the lower border of the cricoid cartilage to the upper border of the manubrium sterni.","Understanding the length and location of the cervical part of the trachea is essential for proper anatomical knowledge.",3
"Which arteries mainly supply the cervical part of the trachea, and where do the veins from the trachea drain into?","The arterial supply comes from specific branches and the veins drain into a major vein.","The arterial supply of the cervical part of the trachea is mainly from branches of the inferior thyroid arteries. The veins from the trachea drain into the left brachiocephalic vein.","Knowledge of the blood supply and drainage of the trachea is crucial for understanding its vascular anatomy.",4
"Describe the nerves that supply the cervical part of the trachea and their functions.","The nerve supply involves both sympathetic and parasympathetic fibers with specific functions.","The cervical part of the trachea is supplied by sympathetic and parasympathetic fibers. The parasympathetic fibers are derived from the vagus through the recurrent laryngeal nerve, contributing to sensory, motor, and secretomotor functions. The sympathetic fibers are derived from the middle cervical sympathetic ganglion and have vasomotor functions.","Understanding the nerve supply to the trachea is essential for grasping its physiological functions.",5
"Explain the procedure and anatomical considerations involved in performing a tracheostomy.","Tracheostomy involves a specific surgical procedure and has different types based on anatomical landmarks.","Tracheostomy is a life-saving surgical procedure performed in cases of laryngeal obstruction. It involves making a vertical incision in the region of the 3rd and 4th or 2nd and 3rd tracheal rings, which is then converted into a circular opening for inserting a tracheostomy tube. The procedure can be performed above (high tracheostomy) or below (low tracheostomy) the isthmus of the thyroid gland, with the latter being riskier in children.","Anatomical considerations are crucial in performing tracheostomy safely and effectively.",7
"How is the esophagus related to the trachea anatomically?","The esophagus is related to the trachea in specific regions based on their anatomical position.","The esophagus is located behind the trachea, with the trachea positioned anteriorly to the esophagus in the cervical region. Both structures have important relations in the neck and thorax.","Understanding the anatomical relationship between the esophagus and trachea is important for clinical correlations and surgical procedures.",3
"What are the key hormones secreted by the thyroid gland, and what functions do they serve?","The thyroid gland secretes specific hormones that play crucial roles in the body.","The thyroid gland secretes hormones such as triiodothyronine (T3), thyroxine (T4), and calcitonin. These hormones regulate the basal metabolic rate, contribute to growth, and are involved in calcium metabolism in the body.","Understanding the functions of thyroid hormones is essential for comprehending endocrine physiology.",4
"Where is the thyroid gland located in the body, and what is its unique feature regarding blood flow?","The thyroid gland's location and special characteristic related to blood flow should be considered.","The thyroid gland is located in the lower part of the front and side of the neck, opposite to specific vertebrae. It has a very rich blood flow compared to other organs in the body.","Knowing the unique location and blood flow characteristics of the thyroid gland helps in understanding its physiological significance.",5
"Describe the parts and features of the thyroid gland based on its structure.","The thyroid gland has specific structural components that form its overall shape.","The thyroid gland is H-shaped, consisting of vertical right and left lateral lobes connected by a horizontal isthmus across the midline. Occasionally, a pyramidal lobe may project upwards from the isthmus, typically to the left of the midline.","Understanding the structural anatomy of the thyroid gland is crucial for clinical evaluations and surgical interventions.",6
"How does the thyroid gland depend on the external environment for the synthesis of its hormones?","The thyroid gland requires a specific external factor for the production of its hormones.","The thyroid gland depends on the external environment for iodine, which is essential for the synthesis of its hormones like T3 and T4.","Knowledge of the role of iodine in thyroid hormone synthesis is important for understanding endocrine physiology.",7
"Why is the thyroid gland accessible for physical examination, and how does it differ in hormone release compared to other glands?","The thyroid gland's unique features make it accessible for examination and storage of hormones.","The thyroid gland is easily accessible for physical examination due to its superficial location. Unlike other endocrine glands, it stores its hormones and releases them into the bloodstream as needed, rather than immediately after formation.","Understanding the unique characteristics of the thyroid gland aids in clinical assessments and treatment strategies for endocrine disorders.",8'''

# Use StringIO to simulate a file object
csv_file = io.StringIO(text)

# Write to CSV
with open('anatomy_questions.csv', 'w', newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csv_file)
    writer = csv.writer(csvfile)

    for row in reader:
        writer.writerow(row)

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
questions_df_add = pd.read_csv('anatomy_questions.csv')
questions_df_add['prof'] = topic_list[9]['prof']
questions_df_add['subject'] = topic_list[9]['subject']
questions_df_add['card'] = topic_list[9]['card']
questions_df_add['topic'] = topic_list[9]['topic']
questions_df_add['subtopic'] = topic_list[9]['subtopic']
questions_df_add
# Out:
#                                             Question  \
# 0  What is the length of the cervical part of the...
# 1  Which arteries mainly supply the cervical part...
# 2  Describe the nerves that supply the cervical p...
# 3  Explain the procedure and anatomical considera...
# 4  How is the esophagus related to the trachea an...
# 5  What are the key hormones secreted by the thyr...
# 6  Where is the thyroid gland located in the body...
# 7  Describe the parts and features of the thyroid...
# 8  How does the thyroid gland depend on the exter...
# 9  Why is the thyroid gland accessible for physic...
#
#                                                 Hint  \
# 0  The cervical part of the trachea is about 7 cm...
# 1  The arterial supply comes from specific branch...
# 2  The nerve supply involves both sympathetic and...
# 3  Tracheostomy involves a specific surgical proc...
# 4  The esophagus is related to the trachea in spe...
# 5  The thyroid gland secretes specific hormones t...
# 6  The thyroid gland's location and special chara...
# 7  The thyroid gland has specific structural comp...
# 8  The thyroid gland requires a specific external...
# 9  The thyroid gland's unique features make it ac...
#
#                                               Answer  \
# 0  The cervical part of the trachea is about 7 cm...
# 1  The arterial supply of the cervical part of th...
# 2  The cervical part of the trachea is supplied b...
# 3  Tracheostomy is a life-saving surgical procedu...
# 4  The esophagus is located behind the trachea, w...
# 5  The thyroid gland secretes hormones such as tr...
# 6  The thyroid gland is located in the lower part...
# 7  The thyroid gland is H-shaped, consisting of v...
# 8  The thyroid gland depends on the external envi...
# 9  The thyroid gland is easily accessible for phy...
#
#                               Additional Information  Difficulty Score   prof  \
# 0  Understanding the length and location of the c...                 3  First
# 1  Knowledge of the blood supply and drainage of ...                 4  First
# 2  Understanding the nerve supply to the trachea ...                 5  First
# 3  Anatomical considerations are crucial in perfo...                 7  First
# 4  Understanding the anatomical relationship betw...                 3  First
# 5  Understanding the functions of thyroid hormone...                 4  First
# 6  Knowing the unique location and blood flow cha...                 5  First
# 7  Understanding the structural anatomy of the th...                 6  First
# 8  Knowledge of the role of iodine in thyroid hor...                 7  First
# 9  Understanding the unique characteristics of th...                 8  First
#
#    subject    card                                     topic  \
# 0  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 1  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 2  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 3  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 4  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 5  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 6  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 7  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 8  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 9  Anatomy  Thorax  Lung (part-2 with development) + trachea
#
#                                    subtopic
# 0  Lung (part-2 with development) + trachea
# 1  Lung (part-2 with development) + trachea
# 2  Lung (part-2 with development) + trachea
# 3  Lung (part-2 with development) + trachea
# 4  Lung (part-2 with development) + trachea
# 5  Lung (part-2 with development) + trachea
# 6  Lung (part-2 with development) + trachea
# 7  Lung (part-2 with development) + trachea
# 8  Lung (part-2 with development) + trachea
# 9  Lung (part-2 with development) + trachea

# %%
questions_df_add.rename(columns={'Answer': 'correct_answer'}, inplace=True)
questions_df_add.rename(columns={'Hint': 'hint'}, inplace=True)
questions_df_add.rename(columns={'Question': 'question'}, inplace=True)
questions_df_add.rename(columns={'Difficulty Score': 'difficulty_score'}, inplace=True)
questions_df_add.rename(columns={'Additional Information': 'extra'}, inplace=True)
questions_df_add
# Out:
#                                             question  \
# 0  What is the length of the cervical part of the...
# 1  Which arteries mainly supply the cervical part...
# 2  Describe the nerves that supply the cervical p...
# 3  Explain the procedure and anatomical considera...
# 4  How is the esophagus related to the trachea an...
# 5  What are the key hormones secreted by the thyr...
# 6  Where is the thyroid gland located in the body...
# 7  Describe the parts and features of the thyroid...
# 8  How does the thyroid gland depend on the exter...
# 9  Why is the thyroid gland accessible for physic...
#
#                                                 hint  \
# 0  The cervical part of the trachea is about 7 cm...
# 1  The arterial supply comes from specific branch...
# 2  The nerve supply involves both sympathetic and...
# 3  Tracheostomy involves a specific surgical proc...
# 4  The esophagus is related to the trachea in spe...
# 5  The thyroid gland secretes specific hormones t...
# 6  The thyroid gland's location and special chara...
# 7  The thyroid gland has specific structural comp...
# 8  The thyroid gland requires a specific external...
# 9  The thyroid gland's unique features make it ac...
#
#                                       correct_answer  \
# 0  The cervical part of the trachea is about 7 cm...
# 1  The arterial supply of the cervical part of th...
# 2  The cervical part of the trachea is supplied b...
# 3  Tracheostomy is a life-saving surgical procedu...
# 4  The esophagus is located behind the trachea, w...
# 5  The thyroid gland secretes hormones such as tr...
# 6  The thyroid gland is located in the lower part...
# 7  The thyroid gland is H-shaped, consisting of v...
# 8  The thyroid gland depends on the external envi...
# 9  The thyroid gland is easily accessible for phy...
#
#                                                extra  difficulty_score   prof  \
# 0  Understanding the length and location of the c...                 3  First
# 1  Knowledge of the blood supply and drainage of ...                 4  First
# 2  Understanding the nerve supply to the trachea ...                 5  First
# 3  Anatomical considerations are crucial in perfo...                 7  First
# 4  Understanding the anatomical relationship betw...                 3  First
# 5  Understanding the functions of thyroid hormone...                 4  First
# 6  Knowing the unique location and blood flow cha...                 5  First
# 7  Understanding the structural anatomy of the th...                 6  First
# 8  Knowledge of the role of iodine in thyroid hor...                 7  First
# 9  Understanding the unique characteristics of th...                 8  First
#
#    subject    card                                     topic  \
# 0  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 1  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 2  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 3  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 4  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 5  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 6  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 7  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 8  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 9  Anatomy  Thorax  Lung (part-2 with development) + trachea
#
#                                    subtopic
# 0  Lung (part-2 with development) + trachea
# 1  Lung (part-2 with development) + trachea
# 2  Lung (part-2 with development) + trachea
# 3  Lung (part-2 with development) + trachea
# 4  Lung (part-2 with development) + trachea
# 5  Lung (part-2 with development) + trachea
# 6  Lung (part-2 with development) + trachea
# 7  Lung (part-2 with development) + trachea
# 8  Lung (part-2 with development) + trachea
# 9  Lung (part-2 with development) + trachea

# %%
import re
import pandas as pd
def string_to_dataframe(input_text):
  # Regular expression pattern to match JSON objects
  pattern = r'"question":\s*"([^"]*)",\s*"hint":\s*"([^"]*)",\s*"answer":\s*"([^"]*)",\s*"extra":\s*"([^"]*)",\s*"difficulty_score":\s*"([^"]*)"'

  # Extract all the matches using the regular expression
  matches = re.findall(pattern, input_text)

  # Create a pandas DataFrame from the extracted data
  df = pd.DataFrame(matches, columns=["question", "hint", "answer", "extra", "difficulty_score"])

  return df

# %%
question_df = string_to_dataframe(all_questions)
question_df
# Out:
#                                              question  \
# 0                What type of joint is the hip joint?
# 1   Which structures articulate to form the hip jo...
# 2         What is the main function of the hip joint?
# 3   Describe the articular surfaces of the hip joint.
# 4   Why is the range of movement in the hip joint ...
# ..                                                ...
# 85  What is the clinical significance of bronchosc...
# 86  Why are multiplex nucleic acid amplification m...
# 87  What is the role of Gram staining in sputum ex...
# 88  Why is bronchoalveolar lavage preferred for ob...
# 89  What type of bacterial quantity in BAL samples...
#
#                                                  hint  \
# 0   Think about the structure and function of the ...
# 1       Consider the bones involved in the hip joint.
# 2   Think about the role of the hip joint in the b...
# 3   Consider the specific features of the head of ...
# 4   Think about the role of the hip joint in weigh...
# ..                                                ...
# 85  Consider the role of obtaining samples for dia...
# 86  Think about the benefits of detecting viral pn...
# 87  Consider how staining techniques can aid in id...
# 88  Think about the method used for collecting sam...
# 89  Consider the cutoff limit for identifying spec...
#
#                                                answer  \
# 0   The hip joint is a ball and socket type of syn...
# 1   The head of the femur articulates with the ace...
# 2   The main functions of the hip joint are to sup...
# 3   The head of the femur forms more than half of ...
# 4   The range of movement in the hip joint is rest...
# ..                                                ...
# 85  Bronchoscopy is used to obtain material for di...
# 86  To assist in the diagnosis of viral pneumonia ...
# 87  Gram staining helps differentiate various micr...
# 88  BAL is useful for establishing the etiology of...
# 89  Using 104 colony-forming units (CFU)/mL of a s...
#
#                                                 extra difficulty_score
# 0   The hip joint is the largest ball and socket t...                3
# 1   The acetabulum of the hip bone and the head of...                4
# 2   The hip joint permits similar movements as the...                5
# 3   The depth of the acetabulum is increased by th...                6
# 4   The hip joint permits similar movements as the...                7
# ..                                                ...              ...
# 85  Quantitative bacterial culture performed on br...                7
# 86  These methods are valuable in identifying spec...                8
# 87  Identifying Gram-positive or Gram-negative bac...                7
# 88  Bronchoscopy with BAL can also detect nonbacte...                8
# 89  Quantitative culture on BAL samples aids in de...                9
#
# [90 rows x 5 columns]

# %%
questioned_topics = topic_list[:10]

# %%
questioned_topics
# Out:
# [{'_id': ObjectId('668e1dae34c6b43f3955e40d'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Sternum with joints',
#   'subtopic': 'Sternum with joints'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e40e'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Typical rib with joints',
#   'subtopic': 'Typical rib with joints'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e40f'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Atypical ribs (1st, 2nd, 11th, 12th)',
#   'subtopic': 'Atypical ribs (1st, 2nd, 11th, 12th)'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e410'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Thoracic vertebrae with joints',
#   'subtopic': 'Thoracic vertebrae with joints'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e411'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Thoracic wall, intercostal space, thoracic inlet',
#   'subtopic': 'Thoracic wall, intercostal space, thoracic inlet'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e412'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Heart with pericardium (part-1)',
#   'subtopic': 'Heart with pericardium (part-1)'},
#  {'_id': ObjectId('668e1dae34c6b43f3955e413'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Heart (part-2)',
#   'subtopic': 'Heart (part-2)'},
#  {'_id': ObjectId('668e1daf34c6b43f3955e414'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Development of CVS',
#   'subtopic': 'Development of CVS'},
#  {'_id': ObjectId('668e1daf34c6b43f3955e415'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Lung with pleura (part-1)',
#   'subtopic': 'Lung with pleura (part-1)'},
#  {'_id': ObjectId('668e1daf34c6b43f3955e416'),
#   'prof': 'First',
#   'subject': 'Anatomy',
#   'card': 'Thorax',
#   'topic': 'Lung (part-2 with development) + trachea',
#   'subtopic': 'Lung (part-2 with development) + trachea'}]

# %%
import pandas as pd

questions_per_topic = 10

question_df['prof'] = None
question_df['subject'] = None
question_df['card'] = None
question_df['topic'] = None
question_df['subtopic'] = None


for i, topic in enumerate(questioned_topics):
    start_idx = i * questions_per_topic
    end_idx = start_idx + questions_per_topic

    for j in range(start_idx, end_idx):

        if j >= len(question_df):
            break

        question_df.at[j, 'prof'] = topic['prof']
        question_df.at[j, 'subject'] = topic['subject']
        question_df.at[j, 'card'] = topic['card']
        question_df.at[j, 'topic'] = topic['topic']
        question_df.at[j, 'subtopic'] = topic['subtopic']

# %%
question_df
# Out:
#                                              question  \
# 0                What type of joint is the hip joint?
# 1   Which structures articulate to form the hip jo...
# 2         What is the main function of the hip joint?
# 3   Describe the articular surfaces of the hip joint.
# 4   Why is the range of movement in the hip joint ...
# ..                                                ...
# 85  What is the clinical significance of bronchosc...
# 86  Why are multiplex nucleic acid amplification m...
# 87  What is the role of Gram staining in sputum ex...
# 88  Why is bronchoalveolar lavage preferred for ob...
# 89  What type of bacterial quantity in BAL samples...
#
#                                                  hint  \
# 0   Think about the structure and function of the ...
# 1       Consider the bones involved in the hip joint.
# 2   Think about the role of the hip joint in the b...
# 3   Consider the specific features of the head of ...
# 4   Think about the role of the hip joint in weigh...
# ..                                                ...
# 85  Consider the role of obtaining samples for dia...
# 86  Think about the benefits of detecting viral pn...
# 87  Consider how staining techniques can aid in id...
# 88  Think about the method used for collecting sam...
# 89  Consider the cutoff limit for identifying spec...
#
#                                                answer  \
# 0   The hip joint is a ball and socket type of syn...
# 1   The head of the femur articulates with the ace...
# 2   The main functions of the hip joint are to sup...
# 3   The head of the femur forms more than half of ...
# 4   The range of movement in the hip joint is rest...
# ..                                                ...
# 85  Bronchoscopy is used to obtain material for di...
# 86  To assist in the diagnosis of viral pneumonia ...
# 87  Gram staining helps differentiate various micr...
# 88  BAL is useful for establishing the etiology of...
# 89  Using 104 colony-forming units (CFU)/mL of a s...
#
#                                                 extra difficulty_score   prof  \
# 0   The hip joint is the largest ball and socket t...                3  First
# 1   The acetabulum of the hip bone and the head of...                4  First
# 2   The hip joint permits similar movements as the...                5  First
# 3   The depth of the acetabulum is increased by th...                6  First
# 4   The hip joint permits similar movements as the...                7  First
# ..                                                ...              ...    ...
# 85  Quantitative bacterial culture performed on br...                7  First
# 86  These methods are valuable in identifying spec...                8  First
# 87  Identifying Gram-positive or Gram-negative bac...                7  First
# 88  Bronchoscopy with BAL can also detect nonbacte...                8  First
# 89  Quantitative culture on BAL samples aids in de...                9  First
#
#     subject    card                      topic                   subtopic
# 0   Anatomy  Thorax        Sternum with joints        Sternum with joints
# 1   Anatomy  Thorax        Sternum with joints        Sternum with joints
# 2   Anatomy  Thorax        Sternum with joints        Sternum with joints
# 3   Anatomy  Thorax        Sternum with joints        Sternum with joints
# 4   Anatomy  Thorax        Sternum with joints        Sternum with joints
# ..      ...     ...                        ...                        ...
# 85  Anatomy  Thorax  Lung with pleura (part-1)  Lung with pleura (part-1)
# 86  Anatomy  Thorax  Lung with pleura (part-1)  Lung with pleura (part-1)
# 87  Anatomy  Thorax  Lung with pleura (part-1)  Lung with pleura (part-1)
# 88  Anatomy  Thorax  Lung with pleura (part-1)  Lung with pleura (part-1)
# 89  Anatomy  Thorax  Lung with pleura (part-1)  Lung with pleura (part-1)
#
# [90 rows x 10 columns]

# %%
question_df.columns.equals(questions_df_add.columns)
# Out:
# False

# %%
question_df.rename(columns={'answer': 'correct_answer'}, inplace=True)

# %%
question_df.columns.equals(questions_df_add.columns)
# Out:
# True

# %%
question_df = pd.concat([question_df, questions_df_add], ignore_index=True)
question_df
# Out:
#                                              question  \
# 0                What type of joint is the hip joint?
# 1   Which structures articulate to form the hip jo...
# 2         What is the main function of the hip joint?
# 3   Describe the articular surfaces of the hip joint.
# 4   Why is the range of movement in the hip joint ...
# ..                                                ...
# 95  What are the key hormones secreted by the thyr...
# 96  Where is the thyroid gland located in the body...
# 97  Describe the parts and features of the thyroid...
# 98  How does the thyroid gland depend on the exter...
# 99  Why is the thyroid gland accessible for physic...
#
#                                                  hint  \
# 0   Think about the structure and function of the ...
# 1       Consider the bones involved in the hip joint.
# 2   Think about the role of the hip joint in the b...
# 3   Consider the specific features of the head of ...
# 4   Think about the role of the hip joint in weigh...
# ..                                                ...
# 95  The thyroid gland secretes specific hormones t...
# 96  The thyroid gland's location and special chara...
# 97  The thyroid gland has specific structural comp...
# 98  The thyroid gland requires a specific external...
# 99  The thyroid gland's unique features make it ac...
#
#                                        correct_answer  \
# 0   The hip joint is a ball and socket type of syn...
# 1   The head of the femur articulates with the ace...
# 2   The main functions of the hip joint are to sup...
# 3   The head of the femur forms more than half of ...
# 4   The range of movement in the hip joint is rest...
# ..                                                ...
# 95  The thyroid gland secretes hormones such as tr...
# 96  The thyroid gland is located in the lower part...
# 97  The thyroid gland is H-shaped, consisting of v...
# 98  The thyroid gland depends on the external envi...
# 99  The thyroid gland is easily accessible for phy...
#
#                                                 extra difficulty_score   prof  \
# 0   The hip joint is the largest ball and socket t...                3  First
# 1   The acetabulum of the hip bone and the head of...                4  First
# 2   The hip joint permits similar movements as the...                5  First
# 3   The depth of the acetabulum is increased by th...                6  First
# 4   The hip joint permits similar movements as the...                7  First
# ..                                                ...              ...    ...
# 95  Understanding the functions of thyroid hormone...                4  First
# 96  Knowing the unique location and blood flow cha...                5  First
# 97  Understanding the structural anatomy of the th...                6  First
# 98  Knowledge of the role of iodine in thyroid hor...                7  First
# 99  Understanding the unique characteristics of th...                8  First
#
#     subject    card                                     topic  \
# 0   Anatomy  Thorax                       Sternum with joints
# 1   Anatomy  Thorax                       Sternum with joints
# 2   Anatomy  Thorax                       Sternum with joints
# 3   Anatomy  Thorax                       Sternum with joints
# 4   Anatomy  Thorax                       Sternum with joints
# ..      ...     ...                                       ...
# 95  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 96  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 97  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 98  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 99  Anatomy  Thorax  Lung (part-2 with development) + trachea
#
#                                     subtopic
# 0                        Sternum with joints
# 1                        Sternum with joints
# 2                        Sternum with joints
# 3                        Sternum with joints
# 4                        Sternum with joints
# ..                                       ...
# 95  Lung (part-2 with development) + trachea
# 96  Lung (part-2 with development) + trachea
# 97  Lung (part-2 with development) + trachea
# 98  Lung (part-2 with development) + trachea
# 99  Lung (part-2 with development) + trachea
#
# [100 rows x 10 columns]

# %%
question_df['version'] = '3'

# %%
questions_data = question_df.to_dict(orient='records')
len(questions_data)
# Out:
# 100

# %%
db.viva_question_collection.insert_many(questions_data)
# Out:
# InsertManyResult([ObjectId('66ee87ac09c4ce39583826ee'), ObjectId('66ee87ac09c4ce39583826ef'), ObjectId('66ee87ac09c4ce39583826f0'), ObjectId('66ee87ac09c4ce39583826f1'), ObjectId('66ee87ac09c4ce39583826f2'), ObjectId('66ee87ac09c4ce39583826f3'), ObjectId('66ee87ac09c4ce39583826f4'), ObjectId('66ee87ac09c4ce39583826f5'), ObjectId('66ee87ac09c4ce39583826f6'), ObjectId('66ee87ac09c4ce39583826f7'), ObjectId('66ee87ac09c4ce39583826f8'), ObjectId('66ee87ac09c4ce39583826f9'), ObjectId('66ee87ac09c4ce39583826fa'), ObjectId('66ee87ac09c4ce39583826fb'), ObjectId('66ee87ac09c4ce39583826fc'), ObjectId('66ee87ac09c4ce39583826fd'), ObjectId('66ee87ac09c4ce39583826fe'), ObjectId('66ee87ac09c4ce39583826ff'), ObjectId('66ee87ac09c4ce3958382700'), ObjectId('66ee87ac09c4ce3958382701'), ObjectId('66ee87ac09c4ce3958382702'), ObjectId('66ee87ac09c4ce3958382703'), ObjectId('66ee87ac09c4ce3958382704'), ObjectId('66ee87ac09c4ce3958382705'), ObjectId('66ee87ac09c4ce3958382706'), ObjectId('66ee87ac09c4ce3958382707'), ObjectId('66ee87ac09c4ce3958382708'), ObjectId('66ee87ac09c4ce3958382709'), ObjectId('66ee87ac09c4ce395838270a'), ObjectId('66ee87ac09c4ce395838270b'), ObjectId('66ee87ac09c4ce395838270c'), ObjectId('66ee87ac09c4ce395838270d'), ObjectId('66ee87ac09c4ce395838270e'), ObjectId('66ee87ac09c4ce395838270f'), ObjectId('66ee87ac09c4ce3958382710'), ObjectId('66ee87ac09c4ce3958382711'), ObjectId('66ee87ac09c4ce3958382712'), ObjectId('66ee87ac09c4ce3958382713'), ObjectId('66ee87ac09c4ce3958382714'), ObjectId('66ee87ac09c4ce3958382715'), ObjectId('66ee87ac09c4ce3958382716'), ObjectId('66ee87ac09c4ce3958382717'), ObjectId('66ee87ac09c4ce3958382718'), ObjectId('66ee87ac09c4ce3958382719'), ObjectId('66ee87ac09c4ce395838271a'), ObjectId('66ee87ac09c4ce395838271b'), ObjectId('66ee87ac09c4ce395838271c'), ObjectId('66ee87ac09c4ce395838271d'), ObjectId('66ee87ac09c4ce395838271e'), ObjectId('66ee87ac09c4ce395838271f'), ObjectId('66ee87ac09c4ce3958382720'), ObjectId('66ee87ac09c4ce3958382721'), ObjectId('66ee87ac09c4ce3958382722'), ObjectId('66ee87ac09c4ce3958382723'), ObjectId('66ee87ac09c4ce3958382724'), ObjectId('66ee87ac09c4ce3958382725'), ObjectId('66ee87ac09c4ce3958382726'), ObjectId('66ee87ac09c4ce3958382727'), ObjectId('66ee87ac09c4ce3958382728'), ObjectId('66ee87ac09c4ce3958382729'), ObjectId('66ee87ac09c4ce395838272a'), ObjectId('66ee87ac09c4ce395838272b'), ObjectId('66ee87ac09c4ce395838272c'), ObjectId('66ee87ac09c4ce395838272d'), ObjectId('66ee87ac09c4ce395838272e'), ObjectId('66ee87ac09c4ce395838272f'), ObjectId('66ee87ac09c4ce3958382730'), ObjectId('66ee87ac09c4ce3958382731'), ObjectId('66ee87ac09c4ce3958382732'), ObjectId('66ee87ac09c4ce3958382733'), ObjectId('66ee87ac09c4ce3958382734'), ObjectId('66ee87ac09c4ce3958382735'), ObjectId('66ee87ac09c4ce3958382736'), ObjectId('66ee87ac09c4ce3958382737'), ObjectId('66ee87ac09c4ce3958382738'), ObjectId('66ee87ac09c4ce3958382739'), ObjectId('66ee87ac09c4ce395838273a'), ObjectId('66ee87ac09c4ce395838273b'), ObjectId('66ee87ac09c4ce395838273c'), ObjectId('66ee87ac09c4ce395838273d'), ObjectId('66ee87ac09c4ce395838273e'), ObjectId('66ee87ac09c4ce395838273f'), ObjectId('66ee87ac09c4ce3958382740'), ObjectId('66ee87ac09c4ce3958382741'), ObjectId('66ee87ac09c4ce3958382742'), ObjectId('66ee87ac09c4ce3958382743'), ObjectId('66ee87ac09c4ce3958382744'), ObjectId('66ee87ac09c4ce3958382745'), ObjectId('66ee87ac09c4ce3958382746'), ObjectId('66ee87ac09c4ce3958382747'), ObjectId('66ee87ac09c4ce3958382748'), ObjectId('66ee87ac09c4ce3958382749'), ObjectId('66ee87ac09c4ce395838274a'), ObjectId('66ee87ac09c4ce395838274b'), ObjectId('66ee87ac09c4ce395838274c'), ObjectId('66ee87ac09c4ce395838274d'), ObjectId('66ee87ac09c4ce395838274e'), ObjectId('66ee87ac09c4ce395838274f'), ObjectId('66ee87ac09c4ce3958382750'), ObjectId('66ee87ac09c4ce3958382751')], acknowledged=True)

# %%
query = {
    'version': '3',
    'difficulty_score': { '$exists': True, '$ne': None }
}
questions = db.viva_question_collection.find(query)
questions

# %%
questions_df = pd.DataFrame(list(questions))
questions_df
# Out:
#                          _id  \
# 0   66ee87ac09c4ce39583826ee
# 1   66ee87ac09c4ce39583826ef
# 2   66ee87ac09c4ce39583826f0
# 3   66ee87ac09c4ce39583826f1
# 4   66ee87ac09c4ce39583826f2
# ..                       ...
# 95  66ee87ac09c4ce395838274d
# 96  66ee87ac09c4ce395838274e
# 97  66ee87ac09c4ce395838274f
# 98  66ee87ac09c4ce3958382750
# 99  66ee87ac09c4ce3958382751
#
#                                              question  \
# 0                What type of joint is the hip joint?
# 1   Which structures articulate to form the hip jo...
# 2         What is the main function of the hip joint?
# 3   Describe the articular surfaces of the hip joint.
# 4   Why is the range of movement in the hip joint ...
# ..                                                ...
# 95  What are the key hormones secreted by the thyr...
# 96  Where is the thyroid gland located in the body...
# 97  Describe the parts and features of the thyroid...
# 98  How does the thyroid gland depend on the exter...
# 99  Why is the thyroid gland accessible for physic...
#
#                                                  hint  \
# 0   Think about the structure and function of the ...
# 1       Consider the bones involved in the hip joint.
# 2   Think about the role of the hip joint in the b...
# 3   Consider the specific features of the head of ...
# 4   Think about the role of the hip joint in weigh...
# ..                                                ...
# 95  The thyroid gland secretes specific hormones t...
# 96  The thyroid gland's location and special chara...
# 97  The thyroid gland has specific structural comp...
# 98  The thyroid gland requires a specific external...
# 99  The thyroid gland's unique features make it ac...
#
#                                        correct_answer  \
# 0   The hip joint is a ball and socket type of syn...
# 1   The head of the femur articulates with the ace...
# 2   The main functions of the hip joint are to sup...
# 3   The head of the femur forms more than half of ...
# 4   The range of movement in the hip joint is rest...
# ..                                                ...
# 95  The thyroid gland secretes hormones such as tr...
# 96  The thyroid gland is located in the lower part...
# 97  The thyroid gland is H-shaped, consisting of v...
# 98  The thyroid gland depends on the external envi...
# 99  The thyroid gland is easily accessible for phy...
#
#                                                 extra difficulty_score   prof  \
# 0   The hip joint is the largest ball and socket t...                3  First
# 1   The acetabulum of the hip bone and the head of...                4  First
# 2   The hip joint permits similar movements as the...                5  First
# 3   The depth of the acetabulum is increased by th...                6  First
# 4   The hip joint permits similar movements as the...                7  First
# ..                                                ...              ...    ...
# 95  Understanding the functions of thyroid hormone...                4  First
# 96  Knowing the unique location and blood flow cha...                5  First
# 97  Understanding the structural anatomy of the th...                6  First
# 98  Knowledge of the role of iodine in thyroid hor...                7  First
# 99  Understanding the unique characteristics of th...                8  First
#
#     subject    card                                     topic  \
# 0   Anatomy  Thorax                       Sternum with joints
# 1   Anatomy  Thorax                       Sternum with joints
# 2   Anatomy  Thorax                       Sternum with joints
# 3   Anatomy  Thorax                       Sternum with joints
# 4   Anatomy  Thorax                       Sternum with joints
# ..      ...     ...                                       ...
# 95  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 96  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 97  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 98  Anatomy  Thorax  Lung (part-2 with development) + trachea
# 99  Anatomy  Thorax  Lung (part-2 with development) + trachea
#
#                                     subtopic version
# 0                        Sternum with joints       3
# 1                        Sternum with joints       3
# 2                        Sternum with joints       3
# 3                        Sternum with joints       3
# 4                        Sternum with joints       3
# ..                                       ...     ...
# 95  Lung (part-2 with development) + trachea       3
# 96  Lung (part-2 with development) + trachea       3
# 97  Lung (part-2 with development) + trachea       3
# 98  Lung (part-2 with development) + trachea       3
# 99  Lung (part-2 with development) + trachea       3
#
# [100 rows x 12 columns]

# %%
csv_file_path = 'questions_with_difficulty_score_v2.csv'  # Replace with your desired file path
questions_df.to_csv(csv_file_path, index=False)

print(f"Data successfully written to {csv_file_path}")
# Out:
# Data successfully written to questions_with_difficulty_score_v2.csv

# %%
docs = []
question_jsons = []
for question in questions_list:
        question_text = f"[{question}]"
        new_question_jsons = extract_json(question_text)
        question_jsons.append(new_question_jsons)

# %%
for question_json, topic in zip(question_jsons, topic_list):
    try:
       questions = question_json[0]['Questions']
       print(f"Topic_name: {topic['topic']}")
       print(f"Questions:{questions}")
       documents = convert_json_to_documents(topic, questions)
       docs.append(documents)
    except json.JSONDecodeError:
        print(f"Invalid JSON: {question}")
    except (KeyError, TypeError) as e:
        print(f"Error processing question: {question}")
        print(f"Exception: {e}")
# Out:
# Topic_name: Autopsy
# Questions:[{'Question': 'What are the special sense organs located in the head?', 'Hint': 'Special sense organs for vision, hearing, equilibrium, smell, and taste', 'Answer': 'The special sense organs located in the head are eyes for vision, ears for hearing and equilibrium, nose for smell, and tongue for taste.', 'Extra': None}, {'Question': 'How is the head structurally divided and what do the cranium and face contain?', 'Hint': 'Structural division into cranium and face; cranium contains brain, face contains openings for eyes, nose, and mouth', 'Answer': 'Structurally, the head is divided into cranium and face. The cranium contains the brain, while the face possesses openings for eyes, nose, and mouth.', 'Extra': None}, {'Question': 'Explain the anatomical changes related to the sense of smell during evolution.', 'Hint': 'Pronograde canines, orthograde monkeys, plantigrade man; how the sense of smell became accessory', 'Answer': 'During evolution, the sense of smell became an accessory sense in animals like orthograde monkeys and plantigrade man compared to pronograde canines, leading to changes in facial structure.', 'Extra': None}, {'Question': 'What is the relationship between the size of jaws and the size of cranium in different species?', 'Hint': 'Inversely proportional relationship between jaw size and cranium size; examples with pronograde canines, orthograde monkeys, plantigrade man', 'Answer': 'The size of jaws is inversely proportional to the size of the cranium. Pronograde canines have larger jaws, orthograde monkeys have smaller jaws, and plantigrade man has the smallest jaws.', 'Extra': None}, {'Question': 'How has the position of the face relative to the cranium changed during evolution?', 'Hint': 'Position of face in front of cranium in dog, below and in front in monkey, below anterior part in man; change in position through evolution', 'Answer': 'During evolution, the position of the face changed from being in front of the cranium in dogs, to below and in front in monkeys, and below the anterior part of the cranium in man.', 'Extra': None}]
# Topic_name: Classification &amp; description of different type of weapons
# Questions:[{'Question': 'What are the two parts of the head based on structural and developmental division?', 'Hint': 'Structurally and developmentally divided parts', 'Answer': 'The cranium and face.', 'Extra': 'The cranium contains the brain, and the face possesses openings of eyes, nose, and mouth.'}, {'Question': 'What anatomical feature distinguishes pronograde canines like dogs from orthograde monkeys and plantigrade man?', 'Hint': 'Anatomical feature based on sensibilities', 'Answer': 'Pronograde canines like dogs have larger jaws, while orthograde monkeys have smaller jaws, and plantigrade man has the smallest jaws.', 'Extra': 'This distinction is a result of changes in eating habits and the importance of the sense of smell.'}, {'Question': 'How has the position of the face evolved in relation to the cranium in different animal species?', 'Hint': 'Evolution of face position', 'Answer': 'In dogs, the face is located in front of the cranium, in monkeys, it is below and in front, and in man, it is below the anterior part of the cranium.', 'Extra': 'The size of jaws is inversely proportional to the size of the cranium in these species.'}, {'Question': 'Why are eyes placed in a more frontal plane in humans?', 'Hint': 'Reason for frontal eye placement', 'Answer': 'To enable stereoscopic vision.', 'Extra': 'Stereoscopic vision helps with depth perception and better binocular vision.'}, {'Question': 'What structural adjustment in humans allows freedom of mobility to the tongue for articulate speech?', 'Hint': 'Structural adjustment for speech', 'Answer': 'Broadening of alveolar arches and a forward-chinned position.', 'Extra': 'These adjustments help in clear articulation and pronunciation of speech sounds.'}]

# %%
for doc in docs:
  print(doc)
# Out:
# [{'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Autopsy', 'subTopic': 'Autopsy', 'question': 'What are the special sense organs located in the head?', 'version': '2', 'hint': 'Special sense organs for vision, hearing, equilibrium, smell, and taste', 'correct_answer': 'The special sense organs located in the head are eyes for vision, ears for hearing and equilibrium, nose for smell, and tongue for taste.', 'extra': None}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Autopsy', 'subTopic': 'Autopsy', 'question': 'How is the head structurally divided and what do the cranium and face contain?', 'version': '2', 'hint': 'Structural division into cranium and face; cranium contains brain, face contains openings for eyes, nose, and mouth', 'correct_answer': 'Structurally, the head is divided into cranium and face. The cranium contains the brain, while the face possesses openings for eyes, nose, and mouth.', 'extra': None}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Autopsy', 'subTopic': 'Autopsy', 'question': 'Explain the anatomical changes related to the sense of smell during evolution.', 'version': '2', 'hint': 'Pronograde canines, orthograde monkeys, plantigrade man; how the sense of smell became accessory', 'correct_answer': 'During evolution, the sense of smell became an accessory sense in animals like orthograde monkeys and plantigrade man compared to pronograde canines, leading to changes in facial structure.', 'extra': None}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Autopsy', 'subTopic': 'Autopsy', 'question': 'What is the relationship between the size of jaws and the size of cranium in different species?', 'version': '2', 'hint': 'Inversely proportional relationship between jaw size and cranium size; examples with pronograde canines, orthograde monkeys, plantigrade man', 'correct_answer': 'The size of jaws is inversely proportional to the size of the cranium. Pronograde canines have larger jaws, orthograde monkeys have smaller jaws, and plantigrade man has the smallest jaws.', 'extra': None}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Autopsy', 'subTopic': 'Autopsy', 'question': 'How has the position of the face relative to the cranium changed during evolution?', 'version': '2', 'hint': 'Position of face in front of cranium in dog, below and in front in monkey, below anterior part in man; change in position through evolution', 'correct_answer': 'During evolution, the position of the face changed from being in front of the cranium in dogs, to below and in front in monkeys, and below the anterior part of the cranium in man.', 'extra': None}]
# [{'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Classification &amp; description of different type of weapons', 'subTopic': 'Classification &amp; description of different type of weapons', 'question': 'What are the two parts of the head based on structural and developmental division?', 'version': '2', 'hint': 'Structurally and developmentally divided parts', 'correct_answer': 'The cranium and face.', 'extra': 'The cranium contains the brain, and the face possesses openings of eyes, nose, and mouth.'}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Classification &amp; description of different type of weapons', 'subTopic': 'Classification &amp; description of different type of weapons', 'question': 'What anatomical feature distinguishes pronograde canines like dogs from orthograde monkeys and plantigrade man?', 'version': '2', 'hint': 'Anatomical feature based on sensibilities', 'correct_answer': 'Pronograde canines like dogs have larger jaws, while orthograde monkeys have smaller jaws, and plantigrade man has the smallest jaws.', 'extra': 'This distinction is a result of changes in eating habits and the importance of the sense of smell.'}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Classification &amp; description of different type of weapons', 'subTopic': 'Classification &amp; description of different type of weapons', 'question': 'How has the position of the face evolved in relation to the cranium in different animal species?', 'version': '2', 'hint': 'Evolution of face position', 'correct_answer': 'In dogs, the face is located in front of the cranium, in monkeys, it is below and in front, and in man, it is below the anterior part of the cranium.', 'extra': 'The size of jaws is inversely proportional to the size of the cranium in these species.'}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Classification &amp; description of different type of weapons', 'subTopic': 'Classification &amp; description of different type of weapons', 'question': 'Why are eyes placed in a more frontal plane in humans?', 'version': '2', 'hint': 'Reason for frontal eye placement', 'correct_answer': 'To enable stereoscopic vision.', 'extra': 'Stereoscopic vision helps with depth perception and better binocular vision.'}, {'prof': 'Second', 'subject': 'Forensic Medicine', 'card': 'Term-1 ', 'topic': 'Classification &amp; description of different type of weapons', 'subTopic': 'Classification &amp; description of different type of weapons', 'question': 'What structural adjustment in humans allows freedom of mobility to the tongue for articulate speech?', 'version': '2', 'hint': 'Structural adjustment for speech', 'correct_answer': 'Broadening of alveolar arches and a forward-chinned position.', 'extra': 'These adjustments help in clear articulation and pronunciation of speech sounds.'}]

# %%
from tqdm import tqdm

for doc in tqdm(docs, desc="Inserting Documents"):
  if(len(doc)> 0):
    results = db.viva_question_collection.insert_many(doc)

print(f"Inserted {len(results.inserted_ids)} documents")
# Out:
# Inserting Documents: 100%|██████████| 2/2 [00:00<00:00, 35.69it/s]
# Inserted 5 documents

# %% [markdown]
# ##Get Questions from MongoDB

# %%
question_collection = db['viva_question_collection']

# %%
def filter_questions_mongo(prof_number, subject, topic_name, num_questions=10):
  query = {
        'prof': prof_number,
        'subject': subject,
        'topic': topic_name
  }
    # Perform the search and iterate over the results
  results_cursor = question_collection.find(query).limit(num_questions)
  results = list(results_cursor)
  return results

# %%
# Get user input
prof_number =  'Second'
subject =  'Forensic Medicine'
topic = "Thermal injury"
# Get and show the questions
print(topic)
questions = filter_questions_mongo(prof_number, subject, topic, num_questions=4)
i = 0
for i, question in enumerate(questions):
        print(f'{i+1}: {question["question"]}')
# Out:
# Thermal injury
# 1: Define Crepitus and its significance in relation to this patient's condition?
# 2: What are the common causative agents of gas gangrene and how do they gain entry into the body?
# 3: What factors contribute to the development of gas gangrene in this patient?
# 4: How does gas gangrene manifest clinically?

# %% [markdown]
# ##Answer Evaluation and Sqlite

# %%
import sqlite3
conn = sqlite3.connect('answer_evaluation.db')

# %%
c = conn.cursor()

# %%
c.execute("""
    CREATE TABLE IF NOT EXISTS answer_evaluation(
        user_id TEXT,
        question TEXT,
        correct_answer TEXT,
        student_answer TEXT,
        model_evaluation TEXT,
        created_at TEXT
    )
""")

# %%
import string
import random
import datetime
# initializing size of string
N = 17

for question in questions:
  print(question['question'])
  hint  = input("Want a hint (y/n):")
  if(hint =='y'):
    print(question['hint'])
  answer = input("Answer:")
  actual_answer = question['correct_answer']
  #extra_information = question['Extra'] if 'Extra' in question else "No extra info to add"
  prompt = get_answer_prompt(actual_answer, question['question'], answer)
  model_evaluation = model.generate_content(prompt).text
  print(model_evaluation)
  #Structure the data to store into sqlitedb
  res = ''.join(random.choices(string.ascii_uppercase +
                             string.digits, k=N))

  print("The generated random string : " + str(res))
  document = {
        'user_id' : str(res),
        'question': question['question'],
        'correct_answer': actual_answer,
        'student_answer': answer,
        'model_evaluation': model_evaluation,
        'created_at': str(datetime.datetime.now())
    }

  print("---------------------------")
  print(document)
  # Insert rows into SqliteDB
  c.execute('INSERT INTO answer_evaluation VALUES (?, ?, ?, ?, ?, ?)',
                      (document['user_id'], document['question'], document['correct_answer'], document['student_answer'], document['model_evaluation'], document['created_at']))
  conn.commit()
# Out:
# Define Crepitus and its significance in relation to this patient's condition?
# Want a hint (y/n):y
# Crepitus is a medical term used to describe a crackling or grating sensation felt or heard during palpation or movement.
# Answer:lol
# The student's answer is not correct. The student has not provided a definition of crepitus nor has he/she explained its significance in relation to the patient's condition. The student's answer is factually incorrect and does not demonstrate an understanding of the concept of crepitus.  The correct answer to this question is: Crepitus is a crackling or grating sensation felt during palpation or movement. In the context of gas gangrene, crepitus is a sign of the presence of gas in the tissue, which is a hallmark of the infection.
# The generated random string : JO4FEJ5OIUT48MD3D
# ---------------------------
# {'user_id': 'JO4FEJ5OIUT48MD3D', 'question': "Define Crepitus and its significance in relation to this patient's condition?", 'correct_answer': 'Crepitus is a crackling or grating sensation felt during palpation or movement. In the context of gas gangrene, crepitus is a sign of the presence of gas in the tissue, which is a hallmark of the infection.', 'student_answer': 'lol', 'model_evaluation': "The student's answer is not correct. The student has not provided a definition of crepitus nor has he/she explained its significance in relation to the patient's condition. The student's answer is factually incorrect and does not demonstrate an understanding of the concept of crepitus.  The correct answer to this question is: Crepitus is a crackling or grating sensation felt during palpation or movement. In the context of gas gangrene, crepitus is a sign of the presence of gas in the tissue, which is a hallmark of the infection.", 'created_at': '2024-08-20 06:04:52.906908'}
# What are the common causative agents of gas gangrene and how do they gain entry into the body?
# Want a hint (y/n):y
# Clostridium perfringens and other Clostridium species are the most common causative agents of gas gangrene.
# Answer:non
# The answer provided, "non," is incorrect. The correct answer should describe the causative agents of gas gangrene, such as Clostridium perfringens, and their entry into the body through traumatic wounds. The student's answer lacks specific information and does not address the question adequately.
# The generated random string : QSB9QFQFWI3WZ7SDE
# ---------------------------
# {'user_id': 'QSB9QFQFWI3WZ7SDE', 'question': 'What are the common causative agents of gas gangrene and how do they gain entry into the body?', 'correct_answer': 'Gas gangrene is commonly caused by Clostridium perfringens, or occasionally by other Clostridium species, such as C. septicum and C. histolyticum. These bacteria are found in the environment and can enter the body through traumatic wounds.', 'student_answer': 'non', 'model_evaluation': 'The answer provided, "non," is incorrect. The correct answer should describe the causative agents of gas gangrene, such as Clostridium perfringens, and their entry into the body through traumatic wounds. The student\'s answer lacks specific information and does not address the question adequately.', 'created_at': '2024-08-20 06:05:01.606779'}
# What factors contribute to the development of gas gangrene in this patient?
# Want a hint (y/n):y
# The presence of necrotic tissue and foreign body material creates an anaerobic environment.
# Answer:nop
# Your answer is incorrect. You have simply stated "nop" which is not a valid answer to the question. The correct answer explains the factors that contribute to the development of gas gangrene, including the presence of necrotic tissue and foreign body material in the traumatic wound, which create an anaerobic environment suitable for the growth of Clostridium bacteria. Please provide a more detailed and accurate answer in the future.
# The generated random string : QGLJKTV0MIYF9DQCH
# ---------------------------
# {'user_id': 'QGLJKTV0MIYF9DQCH', 'question': 'What factors contribute to the development of gas gangrene in this patient?', 'correct_answer': 'Gas gangrene develops when there is a combination of factors that create an anaerobic environment suitable for the growth of Clostridium bacteria. In this patient, the presence of necrotic tissue and foreign body material in the traumatic wound provided the ideal conditions for the infection to develop.', 'student_answer': 'nop', 'model_evaluation': 'Your answer is incorrect. You have simply stated "nop" which is not a valid answer to the question. The correct answer explains the factors that contribute to the development of gas gangrene, including the presence of necrotic tissue and foreign body material in the traumatic wound, which create an anaerobic environment suitable for the growth of Clostridium bacteria. Please provide a more detailed and accurate answer in the future.', 'created_at': '2024-08-20 06:05:09.758598'}
# How does gas gangrene manifest clinically?
# Want a hint (y/n):y
# Rapid onset of pain, swelling, and discoloration of the affected area.
# Answer:pop
# The student's answer, "pop," is incorrect. Gas gangrene is a serious bacterial infection that affects the muscles and other tissues. It is caused by bacteria that produce gas, which can cause the affected area to swell and become discoloured. The correct answer should have mentioned the acute onset of severe pain, swelling, discoloration, and the presence of crepitus, which are all characteristic clinical manifestations of gas gangrene.
# The generated random string : M2CIVK7GAA7E5BRXT
# ---------------------------
# {'user_id': 'M2CIVK7GAA7E5BRXT', 'question': 'How does gas gangrene manifest clinically?', 'correct_answer': 'Gas gangrene typically manifests with an acute onset of severe pain, swelling, and discoloration of the affected area. The skin may appear pale or dusky, and blisters or bullae may develop. Crepitus may also be present, indicating the presence of gas in the tissues.', 'student_answer': 'pop', 'model_evaluation': 'The student\'s answer, "pop," is incorrect. Gas gangrene is a serious bacterial infection that affects the muscles and other tissues. It is caused by bacteria that produce gas, which can cause the affected area to swell and become discoloured. The correct answer should have mentioned the acute onset of severe pain, swelling, discoloration, and the presence of crepitus, which are all characteristic clinical manifestations of gas gangrene.', 'created_at': '2024-08-20 06:05:17.711426'}

# %%
from tabulate import tabulate
c.execute("""
    SELECT rowid, * FROM answer_evaluation
""")
items = c.fetchall()
headers = ["rowid", "user_id","question", "correct_answer", "student_answer", "model_evaluation","created_at"]
table_data = [(item[0], item[1], item[2], item[3], item[4], item[5], item[6]) for item in items]
print(tabulate(table_data, headers=headers, tablefmt="grid"))
# Out:
# +---------+-------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+
# |   rowid | user_id           | question                                                                                       | correct_answer                                                                                                                                                                                                                                                                                                   | student_answer   | model_evaluation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | created_at                 |
# +=========+===================+================================================================================================+==================================================================================================================================================================================================================================================================================================================+==================+========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+============================+
# |       1 | JO4FEJ5OIUT48MD3D | Define Crepitus and its significance in relation to this patient's condition?                  | Crepitus is a crackling or grating sensation felt during palpation or movement. In the context of gas gangrene, crepitus is a sign of the presence of gas in the tissue, which is a hallmark of the infection.                                                                                                   | lol              | The student's answer is not correct. The student has not provided a definition of crepitus nor has he/she explained its significance in relation to the patient's condition. The student's answer is factually incorrect and does not demonstrate an understanding of the concept of crepitus.  The correct answer to this question is: Crepitus is a crackling or grating sensation felt during palpation or movement. In the context of gas gangrene, crepitus is a sign of the presence of gas in the tissue, which is a hallmark of the infection. | 2024-08-20 06:04:52.906908 |
# +---------+-------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+
# |       2 | QSB9QFQFWI3WZ7SDE | What are the common causative agents of gas gangrene and how do they gain entry into the body? | Gas gangrene is commonly caused by Clostridium perfringens, or occasionally by other Clostridium species, such as C. septicum and C. histolyticum. These bacteria are found in the environment and can enter the body through traumatic wounds.                                                                  | non              | The answer provided, "non," is incorrect. The correct answer should describe the causative agents of gas gangrene, such as Clostridium perfringens, and their entry into the body through traumatic wounds. The student's answer lacks specific information and does not address the question adequately.                                                                                                                                                                                                                                              | 2024-08-20 06:05:01.606779 |
# +---------+-------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+
# |       3 | QGLJKTV0MIYF9DQCH | What factors contribute to the development of gas gangrene in this patient?                    | Gas gangrene develops when there is a combination of factors that create an anaerobic environment suitable for the growth of Clostridium bacteria. In this patient, the presence of necrotic tissue and foreign body material in the traumatic wound provided the ideal conditions for the infection to develop. | nop              | Your answer is incorrect. You have simply stated "nop" which is not a valid answer to the question. The correct answer explains the factors that contribute to the development of gas gangrene, including the presence of necrotic tissue and foreign body material in the traumatic wound, which create an anaerobic environment suitable for the growth of Clostridium bacteria. Please provide a more detailed and accurate answer in the future.                                                                                                   | 2024-08-20 06:05:09.758598 |
# +---------+-------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+
# |       4 | M2CIVK7GAA7E5BRXT | How does gas gangrene manifest clinically?                                                     | Gas gangrene typically manifests with an acute onset of severe pain, swelling, and discoloration of the affected area. The skin may appear pale or dusky, and blisters or bullae may develop. Crepitus may also be present, indicating the presence of gas in the tissues.                                       | pop              | The student's answer, "pop," is incorrect. Gas gangrene is a serious bacterial infection that affects the muscles and other tissues. It is caused by bacteria that produce gas, which can cause the affected area to swell and become discoloured. The correct answer should have mentioned the acute onset of severe pain, swelling, discoloration, and the presence of crepitus, which are all characteristic clinical manifestations of gas gangrene.                                                                                               | 2024-08-20 06:05:17.711426 |
# +---------+-------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+

# %%
conn.close()
