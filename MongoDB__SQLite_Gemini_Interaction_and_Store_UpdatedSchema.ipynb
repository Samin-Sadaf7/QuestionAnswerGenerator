# %% [markdown]
# <a href="https://colab.research.google.com/github/Samin-Sadaf7/QuestionAnswerGenerator/blob/main/MongoDB__SQLite_Gemini_Interaction_and_Store_UpdatedSchema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Package Installation

# %%
# !pip install --quiet pandas pymongo sentence_transformers transformers accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 55.9 MB/s eta 0:00:00

# %%
# !pip uninstall typer -y
# !pip install --force-reinstall spacy weasel
# Out:
# Found existing installation: typer 0.12.3
# Uninstalling typer-0.12.3:
#   Successfully uninstalled typer-0.12.3
# Collecting spacy
#   Downloading spacy-3.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 19.0 MB/s eta 0:00:00
# Collecting weasel
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.1 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.0 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 kB 7.8 MB/s eta 0:00:00
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.4/922.4 kB 15.9 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.0/493.0 kB 19.1 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.1 MB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.1 MB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.2 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.8.0-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 34.0 MB/s eta 0:00:00
# Collecting jinja2 (from spacy)
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 14.7 MB/s eta 0:00:00
# Collecting setuptools (from spacy)
#   Downloading setuptools-70.2.0-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 37.5 MB/s eta 0:00:00
# Collecting packaging>=20.0 (from spacy)
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.4 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 16.7 MB/s eta 0:00:00
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 34.9 MB/s eta 0:00:00
# Collecting confection<0.2.0,>=0.0.4 (from weasel)
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel)
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 5.3 MB/s eta 0:00:00
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel)
#   Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.4 MB/s eta 0:00:00
# Collecting typing_extensions>4 (from cloudpathlib<1.0.0,>=0.7.0->weasel)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 29.5 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.20.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 74.4 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 14.7 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.1 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 13.5 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 18.4 MB/s eta 0:00:00
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel)
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 8.6 MB/s eta 0:00:00
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 94.1 MB/s eta 0:00:00
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 70.0 MB/s eta 0:00:00
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 590.8 kB/s eta 0:00:00
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 22.1 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.9 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 11.0 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.3 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing_extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, pygments, packaging, numpy, murmurhash, mdurl, MarkupSafe, idna, click, charset-normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, marisa-trie, jinja2, cloudpathlib, blis, rich, pydantic, language-data, typer, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.8
#     Uninstalling cymem-2.0.8:
#       Successfully uninstalled cymem-2.0.8
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: spacy-loggers
#     Found existing installation: spacy-loggers 1.0.5
#     Uninstalling spacy-loggers-1.0.5:
#       Successfully uninstalled spacy-loggers-1.0.5
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.12
#     Uninstalling spacy-legacy-3.0.12:
#       Successfully uninstalled spacy-legacy-3.0.12
#   Attempting uninstall: shellingham
#     Found existing installation: shellingham 1.5.4
#     Uninstalling shellingham-1.5.4:
#       Successfully uninstalled shellingham-1.5.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.16.1
#     Uninstalling Pygments-2.16.1:
#       Successfully uninstalled Pygments-2.16.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.10
#     Uninstalling murmurhash-1.0.10:
#       Successfully uninstalled murmurhash-1.0.10
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.10
#     Uninstalling catalogue-2.0.10:
#       Successfully uninstalled catalogue-2.0.10
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
#       Successfully uninstalled srsly-2.4.8
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.0.4
#     Uninstalling smart-open-7.0.4:
#       Successfully uninstalled smart-open-7.0.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.18.4
#     Uninstalling pydantic_core-2.18.4:
#       Successfully uninstalled pydantic_core-2.18.4
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.9
#     Uninstalling preshed-3.0.9:
#       Successfully uninstalled preshed-3.0.9
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: marisa-trie
#     Found existing installation: marisa-trie 1.2.0
#     Uninstalling marisa-trie-1.2.0:
#       Successfully uninstalled marisa-trie-1.2.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: cloudpathlib
#     Found existing installation: cloudpathlib 0.18.1
#     Uninstalling cloudpathlib-0.18.1:
#       Successfully uninstalled cloudpathlib-0.18.1
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.11
#     Uninstalling blis-0.7.11:
#       Successfully uninstalled blis-0.7.11
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.4
#     Uninstalling pydantic-2.7.4:
#       Successfully uninstalled pydantic-2.7.4
#   Attempting uninstall: language-data
#     Found existing installation: language_data 1.2.0
#     Uninstalling language_data-1.2.0:
#       Successfully uninstalled language_data-1.2.0
#   Attempting uninstall: langcodes
#     Found existing installation: langcodes 3.4.0
#     Uninstalling langcodes-3.4.0:
#       Successfully uninstalled langcodes-3.4.0
#   Attempting uninstall: confection
#     Found existing installation: confection 0.1.5
#     Uninstalling confection-0.1.5:
#       Successfully uninstalled confection-0.1.5
#   Attempting uninstall: weasel
#     Found existing installation: weasel 0.4.1
#     Uninstalling weasel-0.4.1:
#       Successfully uninstalled weasel-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.5
#     Uninstalling thinc-8.2.5:
#       Successfully uninstalled thinc-8.2.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.5
#     Uninstalling spacy-3.7.5:
#       Successfully uninstalled spacy-3.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# tensorflow 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2024.6.2 charset-normalizer-3.3.2 click-8.1.7 cloudpathlib-0.18.1 confection-0.1.5 cymem-2.0.8 idna-3.7 jinja2-3.1.4 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 numpy-1.26.4 packaging-24.1 preshed-3.0.9 pydantic-2.8.0 pydantic-core-2.20.0 pygments-2.18.0 requests-2.32.3 rich-13.7.1 setuptools-70.2.0 shellingham-1.5.4 smart-open-7.0.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 tqdm-4.66.4 typer-0.12.3 typing_extensions-4.12.2 urllib3-2.2.2 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0

# %%
# !pip install --force-reinstall --no-deps typer==0.9.0
# !pip install fastapi-cli
# !pip install langchain-community sentence-transformers pypdf2 pypdf chromadb
# !pip install google-generativeai
# Out:
# Collecting typer==0.9.0
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.3
#     Uninstalling typer-0.12.3:
#       Successfully uninstalled typer-0.12.3
# Successfully installed typer-0.9.0
# Requirement already satisfied: fastapi-cli in /usr/local/lib/python3.10/dist-packages (0.0.4)
# Collecting typer>=0.12.3 (from fastapi-cli)
#   Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (4.12.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli) (0.1.2)
# Installing collected packages: typer
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed typer-0.12.3
# Collecting langchain-community
#   Using cached langchain_community-0.2.6-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Collecting pypdf2
#   Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Collecting pypdf
#   Using cached pypdf-4.2.0-py3-none-any.whl (290 kB)
# Collecting chromadb
#   Using cached chromadb-0.5.3-py3-none-any.whl (559 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.6 (from langchain-community)
#   Using cached langchain-0.2.6-py3-none-any.whl (975 kB)
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain-community)
#   Using cached langchain_core-0.2.10-py3-none-any.whl (332 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Using cached langsmith-0.1.83-py3-none-any.whl (127 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.4.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.8.0)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Using cached chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Using cached uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.5.0-py2.py3-none-any.whl (41 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 16.5 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 7.4 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.3)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.8 MB/s eta 0:00:00
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.5 MB/s eta 0:00:00
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 17.9 MB/s eta 0:00:00
# Collecting httpx>=0.27.0 (from chromadb)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi>=0.95.2->chromadb)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi>=0.95.2->chromadb)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.5 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi>=0.95.2->chromadb)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.27.0->chromadb)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.27.0->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.6->langchain-community)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.10->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=7.1,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 6.1 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 15.6 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (70.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 34.8 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 51.1 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.2 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=1ca7bac44e0577151fbc08bb9a281b1bc1450d294a4f074b6cd2664ce0fd920b
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, ujson, python-multipart, python-dotenv, pypdf2, pypdf, overrides, orjson, opentelemetry-util-http, opentelemetry-proto, mypy-extensions, marshmallow, jsonpointer, importlib-metadata, humanfriendly, httptools, h11, email_validator, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, typing-inspect, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, jsonpatch, httpcore, coloredlogs, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, langsmith, kubernetes, httpx, dataclasses-json, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langchain-core, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, fastapi, langchain, chromadb, langchain-community
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.0.0
#     Uninstalling importlib_metadata-8.0.0:
#       Successfully uninstalled importlib_metadata-8.0.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.3 chroma-hnswlib-0.7.3 chromadb-0.5.3 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.14 email_validator-2.2.0 fastapi-0.111.0 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 importlib-metadata-7.1.0 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-30.1.0 langchain-0.2.6 langchain-community-0.2.6 langchain-core-0.2.10 langchain-text-splitters-0.2.2 langsmith-0.1.83 marshmallow-3.21.3 mmh3-4.1.0 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.18.1 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 orjson-3.10.5 overrides-7.7.0 posthog-3.5.0 pypdf-4.2.0 pypdf2-3.0.1 pypika-0.48.9 python-dotenv-1.0.1 python-multipart-0.0.9 starlette-0.37.2 typing-inspect-0.9.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.11.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.84.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.63.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.1.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.20.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.6.2)

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.10/dist-packages (4.8.0)
# WARNING: pymongo 4.8.0 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo[srv]) (2.6.1)

# %% [markdown]
# #Import Packages

# %%
import pandas as pd

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
import os
import textwrap

# %%
from sentence_transformers import SentenceTransformer
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# #Embedding

# %%
embedding_model = SentenceTransformer("thenlper/gte-large")
# Out:
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
def get_embedding(text:str)->list[float]:
  if not text.strip():
    print("Attemted to do embedding on an empty text")
    return []
  embedding = embedding_model.encode(text)
  return embedding.tolist()

# %% [markdown]
# #Mongo Set up

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://samin:sadaf@cluster0.jjvxsrh.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# #Database Initialization

# %%
db = client['RAG_application']

# %%
book_collection = db['Medical_Books_RAG']

# %% [markdown]
# #PDF Spliting

# %%
def split_pdf(file_path, chunk_size, chunk_overlap):
    loader = PyPDFLoader(file_path)
    pages = loader.load_and_split()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    docs = text_splitter.split_documents(pages)
    return docs

# %% [markdown]
# #Vector Search

# %%
def vector_search(user_query, collection):

  query_embedding = get_embedding(user_query)
  print(query_embedding)

  if query_embedding is None:
    return "Invalid Query Embedding"

  pipeline = [
      {
        "$vectorSearch":{
            "index" : "vector_index",
            "queryVector": query_embedding,
            "path":"embedding",
            "numCandidates": 80,
            "limit" : 10,
        }
      },
      {
        "$project" :{
             "page_content": 1,
             "score" :{"$meta" : "vectorSearchScore"},
        }
      }
  ]
  result = collection.aggregate(pipeline)
  return list(result)

# %%
def get_search_result(user_query, collection):
  get_knowledge = vector_search(user_query, collection)

  search_result = ""

  for result in get_knowledge:
    search_result += f"{result.get('page_content','N/A')}\n"
  return search_result

# %% [markdown]
# #Prompt Generation

# %%
def get_prompt_TrueFalse(query, context):
  context = context.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""You are assisting a medical student in preparing for an exam. Your task is to generate true false questions based on the given Single Best answer, SQA question and True False Question using\
   medical terminology. You need to avoid making Single Best answer questions even if you get those questions. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate True/False Question and you are given the Question Format.\
   Make sure to generate questions in full sentence. Your task is to generate true false quesions in the given format. \
   The questions should be true of false. The format of question is first mention a topic and follow it with 5-6 sentences, the sentences can be true or false. \
TOPIC: '{query}'
CONTEXT: '{context}'
True/False QUESTIONS Format:
  Topic: T1
  Sentences:
  1. S1
  2. S2
  3. S3
  4. S4
  5. S5
  M1: True
  M2: False
  M3: True
  M4: False
  M5: True
""").format(query=query, context=context)
  return prompt

# %%
def get_prompt_SBA(query, context):
  context = context.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""You are assisting a medical student in preparing for an exam. Your task is to generate multiple choice questions based on the given MCQ, Multiple Choice Question, Single Best answer, SQA question and True False Question using\
   medical terminology. You need to avoid making True False questions even if you get those questions. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate Multiple Choice Question and you are given the Question Format.\
   Make sure to generate questions in full sentence. Your task is to generate Single Based quesions or Multiple Choice Questions in the given format. \
In the topic, you will multiple topics in comma seperated format. For example: Topic: T1, T2. You need to generate question for each topic. \
TOPIC: '{query}'
CONTEXT: '{context}'
MCQ QUESTIONS Format:
  Question: Q1
  options: A1, A2, A3, A4
  Answer: A1
  Question: Q2
  options: A1, A2, A3, A4
  Answer: A2
You can create as many mcq questions as you like.
""").format(query=query, context=context)
  return prompt

# %%
def get_prompt_viva(query, context):
    context = context.replace("'", "").replace('"', "").replace('\n', "")
    prompt = (
        f"""You are assisting a medical student in preparing for an exam. Your task is to generate a viva question based on the given MCQ, Multiple Choice Question, Single Best answer, SQA question and True-False Question using \
medical terminology. Ensure your responses are comprehensive and friendly, reflecting a conversational tone. Your only focus is to generate Viva Question and you are given the Question Format. \
Make sure to generate questions in full sentence. Your task is to create the viva question. \
Question should be answerable in 1-2 sentences. You have 3 tasks here: \
1. You should generate only 10 questions. \
2. You should provide corresponding hints for those questions. \
3. You should also provide answers for those questions. Answers should be around 2-3 sentences. \
5. Output should be a perfect json object with proper format.Do not anything extra.
The output should be a JSON object in the following format:
{{
    "Topic": "T1",
    "Questions": [
        {{
            "Question": "Q1?",
            "Hint": "H1",
            "Answer": "A1"
        }}
    ]
}}
Question Format:
T1 will be replaced by Topic Name. Q1 will be replaced by actual question created from the context. H1 will be replaced by the relevant hint to answer the question. A1 will be replaced by the actual answer to the question. \
You need to generate actual questions in this format using the following context. Number of questions will be 10. \
TOPIC: '{query}'
CONTEXT: '{context}'"""
    )
    return prompt

# %%
def get_answer_prompt(actual_answer, question, answer):
  actual_answer = actual_answer.replace("'", "").replace('"', "").replace('\n', "")
  prompt = ("""`You are assisting a medical student in preparing for an exam. The student has answered a QUESTION and want to check if the ANSWER is correct\
  As an assistant your job is to examine the ANSWER and provide a feedback. You are given the QUESTION and the student's ANSWER to that QUESTION. Also, the Actual Answer of that question is given.\
  Now evaluate the student's answer and compare it with the correct answer given below. Give a detailed feedback in first person. BE STRICT about the evaluation and criticise the given answer properly. Generate normal text. No need to make the text bold.If the answer is incorrect\
  also provide the correct answer.\
  Your second task is to give points to the student's answer in integer. You will mark it out of 10. Lowest point can only be 1. \
  The output format should be a json object. \
  The output should be a JSON object in the following format:
  {{
    "Model Feedback": " "
    "Points": p
  }}
  In Model Feedback, you will give the strict remarks about the answer. \
  Be careful. The value of p should be: 1<= p <= 10 \
  QUESTION: '{question}'
  Correct Answer: '{actual_answer}'
  STUDENT'S ANSWER: '{answer}'
    """).format(actual_answer=actual_answer, question=question, answer=answer)
  return prompt

# %% [markdown]
# #Set Up Gemini Model

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GeminiKey')

# %%
import google.generativeai as genai
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel(model_name='gemini-pro')

# %% [markdown]
# #Set Up PDF

# %%
pdf_path = '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf'

# %% [markdown]
# #Split the docs

# %%
docs =split_pdf(pdf_path, chunk_size=3000, chunk_overlap=50)

# %% [markdown]
# #Get Search Result

# %%
def get_search_result(user_query, collection):
  get_knowledge = vector_search(user_query, collection)

  search_result = ""

  for result in get_knowledge:
    search_result += f"{result.get('page_content','N/A')}\n"
  return search_result

# %% [markdown]
# #Make the docs into a panda dataframe

# %%
# Prepare data for DataFrame
data = []
for doc in docs:
    data.append({
        'page_content': doc.page_content,
        'source': doc.metadata['source'],
        'page': doc.metadata['page']
    })

# Create DataFrame
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['page_content', 'source', 'page'], dtype='object')

# %% [markdown]
# #Embedding page content

# %%
df['embedding'] = df['page_content'].apply(get_embedding)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-2260ba0f389f> in <cell line: 1>()
# ----> 1 df['embedding'] = df['page_content'].apply(get_embedding)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
#    1075                 values = obj.astype(object)._values
# -> 1076                 mapped = lib.map_infer(
#    1077                     values,
#    1078                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-38-a0cdf3c3b5de> in get_embedding(text)
#       3     print("Attemted to do embedding on an empty text")
#       4     return []
# ----> 5   embedding = embedding_model.encode(text)
#       6   return embedding.tolist()
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     515
#     516             with torch.no_grad():
# --> 517                 out_features = self.forward(features)
#     518                 if self.device.type == "hpu":
#     519                     out_features = copy.deepcopy(out_features)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features)
#     116             trans_features["token_type_ids"] = features["token_type_ids"]
#     117
# --> 118         output_states = self.auto_model(**trans_features, return_dict=False)
#     119         output_tokens = output_states[0]
#     120
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1136
# -> 1137         encoder_outputs = self.encoder(
#    1138             embedding_output,
#    1139             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     688                 )
#     689             else:
# --> 690                 layer_outputs = layer_module(
#     691                     hidden_states,
#     692                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     578         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     579         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 580         self_attention_outputs = self.attention(
#     581             hidden_states,
#     582             attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     508         output_attentions: Optional[bool] = False,
#     509     ) -> Tuple[torch.Tensor]:
# --> 510         self_outputs = self.self(
#     511             hidden_states,
#     512             attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     405             key_layer, value_layer = past_key_value
#     406         else:
# --> 407             key_layer = self.transpose_for_scores(self.key(current_states))
#     408             value_layer = self.transpose_for_scores(self.value(current_states))
#     409             if past_key_value is not None and not is_cross_attention:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
document = df.to_dict('records')

# %%
document
# Out:
# [{'page_content': '**please note: half of the questions you provide should be true/false; the other half should be in a \nSingle best answer (SBA) format. The questions should have minimum 4 options (for SBA), 5 opti ons (for \ntrue/false) \nName of Subject: Physiology \nName of Card: Cardiovascular System \nName of Topic: Cardiac Muscle : Physiological Anatomy and propertie s  \nSerial \nNo Question With Options Answer Explanation \n1 Properties of Cardiac Muscles- \na. Rhythmicity \nb. Excitability \nc. Prolong Refractory Period \nd.Adaptation \ne. Summation a.T   \nb.T \nc. T   \nd.F \ne. F Rhythmicity,excitability and \nprolong refractory period is \nthe properties of cardiac \nmuscle cells but adaptation \nand summation are \nproperties of nerve fibers \n2. Cardiac muscle cells- \na. non striated \nb. prolong refractory period \nc. can regenerate \nd. follows all or none law \ne. connected via gap junctions a. F \nb. T \nc. F \nd. T \ne. T Cardiac muscle cells are \nstriated and has prolong \nrefractory period that ’s why \nit doesn ’t get fatigued. \nCardiac muscle cells are \npermanent and can ’t \nregenerate and connected \nvia gap junctions through \nintercalated discs and also \nfollows all or none law \n3. What happens in the plateau phase of cardiac \nmuscle cells? \na. influx of Sodium \nb. efflux of sodium \nc. calcium influx through slow calcium channels \nd. Potassium influx C . \ncalcium \ninflux \nthrough \nslow \ncalcium \nchannels Plateau occurs because \ncalcium influx occurs through \nthe slow but prolonged \nopening opening of voltage \ngated calcium channels \n4. Why don ’t cardiac muscle  get fatigued? \na. has plateau \nb. functional syncytium \nc. follows all or none law \nd. because of contractility a. has \nplateau Plateau ensures prolonged \nrefractory period so heart \ngets time for recovery and \nensures enough nutrition \nand oxygen supply \n5.  In case of cardiac failure the more the blood \naccumulates in the ventricle the stronger the heart \npumps. Which property of the heart comes at play \nhere ? \na. Contractility \nb. All or none law \nc. Frank Sterling Law \nd. Prolonged refractory period c. Frank \nSterling \nLaw Frank sterling law ensures \nequal stroke volume of \nventricles .As the heart fails \nthe blood accumulates in the \nheart and EDV is increased . \nSo length of the muscle \nfibers increase and force  of \ncontraction increases \naccording to the law and',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 0},
#  {'page_content': 'helps battle the heart failure. \n6.  \n \n \n \n \n \n \n \n \n \n In case of refractory period- \na. cardiac muscle can ’t be re-excited in this period \nb. two types \nc. cardiac muscle can ’t be stimulated even in \nrelative refractory period \nd. ensures time for cardiac muscle to recover \ne. absolute refractory period of ventricular muscle \nis 0.05 seconds a.T \nb.T \nc.F \nd.T \ne.F During refractory period \ncardiac muscles can ’t be re-\nexcited . It is divided in two \ntypes- Absolute and relative. \nDuring relative refractory \nperiod cardiac muscles are \nstimulated if the signal is \nstrong enough.Absolute \nrefractory period of \nventricular muscle is 0.25-\n0.30 seconds  \n7. Electrolytes responsible for generation of cardiac \nimpulse- \na. Sodium \nb. Calcium \nc. Chlorine \nd. Potassium \ne. Magnesium a. T \nb. T \nc. F \nd. T \ne. F Influx of Sodium causes the \ndepolarization. Plateau is \ncaused by Calcium influx \nthrough the slow calcium \nchannels and late rapid \nrepolarization occurs due to \nefflux of potassium and \nclosure of calcium channels.  \n \nName of Topic:   Junctional Tissues of the Heart : Generation & Conduction of Cardi ac Impulse \nSerial \nNo Question With Options Answer Explanation \n1 Sinoatrial nodal cells are- \na.innervated by vagus \nb. found in right atria \nc. naturally leaky to calcium ions \nd. require external impulse for their stimulation \ne.connected to AV nodes by purkinje fibers a.T \nb.T \nc. F \nd. F \ne. F \n Sinoatrial nodal cells are \ninnervated by vagus nerve \nfor their parasympathetic \nstimulation. SA node is \nsituated in right atria and are \nnaturally leaky to Sodium \nions and are connected to AV \nnodes by internodal \npathways \n  \n2. SA node is called the pacemaker because of which \nproperty? \na. largest among the nodes \nb. longest plateau  \nc. rate of impulse is higher \nd. connected to AV nodes by 3 internodal \npathways \ne. located in the right atrium c. rate of \nimpulse \nis higher SA node has the highest rate \nof impulse which is about 70-\n80/min . That ’s why it is \ncalled the pacemaker of \nheart \n3. About pacemaker potential- \na.after each impulse declines to the firing level \nb. Calcium influx through L channels cause this \nc. Purkinje fibers have this property \nd. it enables the cell to discharge spontaneously a. T \nb. F \nc. T \nd. T \ne. F Pacemaker potential is that \nafter each impulse it declines \nto the firing level and \ntriggers the next impulse. \nCalcium impulse through the',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 1},
#  {'page_content': 'e. Calcium influx through the T channels causes \ndepolarization T channel causes the \nmembrane potential to rise \nand calcium potential \nthrough L channel causes \ndepolarization. For this \nproperty it can discharge \nsignal spontaneously. SA \nnode , AV node and other \njunctional tissues of the \nheart has this property \n4.  Which advantage is gained by AV nodal delay ? \na.atria to empty their blood into the ventricles \nb. refractory period becomes prolonged \nc. generate electric impulse spontaneously \nd. pacemaker potential is established a.atria to \nempty \ntheir \nblood \ninto the \nventricles \n AV nodal delay allows the \nheart necessary time for the \natria to empty their blood \ninto the ventricles before the \nventricular contraction \nbegins \n5. AV nodal delay is caused by- \na. smaller size of the tissues \nb. large number of gap junctions \nc.increased resistance to conduction of excitatory \nions \nd. prolonged refractory period of AV nodes \ne. leakiness to Sodium ions a. T \nb. F \nc. T \nd. T \ne. F AV nodal delay is caused by \nthe smaller size of the fibers \nand few amount of gap \njunctions present in the \nnodes which causes the \nincreased resistance to \nconductance of ions. Due to \nprolonged refractory period \nof fibers the delay is \nprolonged again . It is about \n0.09 seconds \n6.  Strong stimulation of vagus can stop stop heart for \ncertain period of time but then an ectopic \npacemaker is developed somewhere which causes \nventricular contraction at a musch slower rate . \nThis condition is called ? \na. Vasovagal Syncope \nb. Ventricular arrhythmia \nc. Atrial Fibrillation \nd. Vagal Escape d. vagal \nescape Strong stimulation of vagus \ncan stop the contraction of \nthe heart by completely \ninhibiting the transmission of \ncardiac impulse through the \nAV nodes. The ventricles \nstop beating for about 5-20 \nseconds but then an ectopic \npacemaker develops in the \npurkinje fibers or AV bundle \nand causes ventricular \ncontraction at a slower rate \nthan the SA nodes. It is called \nvagal escape or ventricular \nescape.  \n \nName of Topic: Cardiac Cycle – Changes during different pha se \nSerial \nNo Question With Options Answer Explanation',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 2},
#  {'page_content': '1. When heart rate is 80 beats/min the cardiac cycle \ntime is – \na. 0.75 seconds \nb. 0.80 seconds \nc. 0.70 seconds \nd. 0.90 seconds a.0.75 \nseconds Cardiac cycle time =  \n60 seconds/heart rate \nSo, if heart rate is 80 bpm \nthen cardiac cycle time is \n60/80 = 0.75 seconds \n2.  Ventricular diastole comprises of the following \nphases- \na. Isometric relaxation phase  \nb. Isometric contraction phase \nc. First Rapid filling phase  \nd. Diastasis \ne. Last rapid filling phase a. T \nb. F \nc. T \nd. T \ne. T Vantricular diastole \ncomprises of – \n# protodiastolic phase \n# Isometric Relaxation phase \n# First rapid filling phase  \n#Diastasis or slow filling \nphase \n# Last rapid feeling phase \n \n3.  Ventricular muscles relaxes as a closed cavity and \nno blood exchange occurs. This condition is seen in \nwhich phase ? \na. Isometric contraction phase \nb. Isometric relaxation phase \nc. Protodiastolic phase \nd. Diastasis phase b. \nIsometric \nrelaxation \nphase In isometric relaxation phase \nventricular muscles relaxes \nas a closed cavity and no \nblood comes inside the \ncavity . That ’s why no change \nof pressure and isometric \ncondition is maintained. In \nisometric contraction phase \nventricular muscles contract \nas a closed cavity.  \n4.  Physiological changes that take place during \ncardiac cyle? \na. Intra Atrial pressure change \nb. Production of apex beat \nc. Production of ronchi \nd. Appearance of ECG waves \ne. Production of pulsations a. T \nb. T \nc. F \nd. T \ne. F During cardiac cycle ,atrial \nand ventricular pressure & \nvolume change occurs. Pulse \nand apex beat is produced. \nElectrical change occurs and \ncan be seen via ECG waves. \nPulsation is abnormal visible \nblood vessel  movement in \nany part of body and ronchi \nis prolonged expiratory \nbreath sound heard via \nstethoscope \n5.  Duration of atrial systole is – \na. 0.05 seconds \nb. 0.7 seconds \nc. 0.1 second \nd. 0.5 seconds c. 0.1 \nseconds The duration of atrial systole \nis 0.1 second  which is \ndivided in to dynamic and \nadynamic phase both 0.05 \nseconds oin duration.  \n6.  Volume changes in ventricles during cardiac cycle- \na. isometric contraction period- no change \nb. ejection period- increase \nc. protodiastolic period- rapid rise \nd. diastasis- slow rise  a. T \nb. F \nc. F \nd. T \ne. F Isometric contraction – no \nchange \nEjection period- volume falls \nProtodiastolic period- slight \nfall',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 3},
#  {'page_content': 'e. isometric relaxation – slight fall Isometric relaxation- no \nchange in volume \nFirst rapid filling- rapid rise \nDiastasis- slow rise \nLast rapid filling – volume \nincreases \n \nName of Topic: Heart Sound – Types and Characteristics \nSerial \nNo Question With Options Answer Explanation \n1. Which sound can ’t be heard through stethoscope? \na. 1st heart sound \nb. 2nd heart sound \nc. 3rd Heart sound \nd. 4th heart sound d. 4th \nheart \nsound 1st and 2nd heart sound canbe \nheard through stethoscope \nduring each cardiac cycle. 3rd \nheart sound can be heard in \nmany young individuals. 4th \nsound can ’t be heard \nthrough stethoscope. All \nheart sounds can be \nrecorded by \nphonocardiogram \n2.  Characteristics of 1st heart sound-  \na. low pitched \nb. best heard over mitral region \nc. indicates closure of semilunar valves \nd. coincides with apex beat \ne. like the word DUB a. T \nb. T  \nc. F \nd. T \ne. F 1st heart sound is low pitched \nand best heard over left 5th \nand 6th intercostals space \nmedial to mid clavicular line . \nIt indicates closure of AV \nvalves and coincides with the \napex beat. Sounds like the \nword LUB \n3.  DUB sound indicates closure of which valves ? \na. Aortic \nb. Pulmonary \nc. Mitral \nd. Tricuspid \ne. a+b e. a+b DUB sound is 2nd heart sound \nwhich indicates closure of \nsemilunar valves ( both \naortic and pulmonary) of the \nheart. \n4. Which heart sound indicates the end of systole and \nbeginning of diastole? \na. 1st heart sound \nb. 2nd heart sound \nc. 3rd Heart sound \nd. 4th heart sound b. 2nd \nheart \nsound \n 1st heart sound indicates the \nclinical onset of ventricular \nsystole. 2nd heart sound \nindicates the end of systole \nand beginning of diastole.3rd \nheart sound indicates the \nventricular filling. \n5.  Systolic murmur can be heard in – \na. Aortic stenosis \nb. Pulmonary stenosis \nc. Aortic regurgitation \nd. Mitral stenosis \ne. Mitral regurgitation a. T \nb. T \nc. F \nd. F \ne. F Systolic murmur can be \nheard- \nAortic stenosis \nPulmonary stenosis \nMitral regurgitation \nTricuspid regurgitation',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 4},
#  {'page_content': '6. 2nd heart sound- \na. short duration \nb. low pitched \nc.indicates closure of semilunar valves \nd. best heard in aortic and pulmonary area \ne. coincides with apex beat a. T \nb. F \nc. T \nd. T \ne. F 2nd heart sound is high \npitched , loud and short \nduration. It indicates closure \nof semilunar valves,like the \nword DUB. The sound comes \nafter apex beat and carotid \npulse. The sound is heard \nbest over aortic and \npulmonary areas. \n \nName of Topic: ECG –Principles, characteristics and Interpretations \nSerial \nNo Question With Options Answer Explanation \n1 QRS complex indicates which event? \na. Atrial depolarization \nb. Ventricular repolarization \nc.  Ventricular depolarization \nd. Conduction through AV node c.  Ventricular \ndepolarization \n QRS complex indicates \nventricular depolarization \nand atrial repolarization \n2. WPW syndrome patient shows abnormality in \nwhich interval? \na. QRS Complex \nb. PR Interval \nc. QT Interval \nd. ST Interval b. PR Interval \n In WPW (Wolf Parkinson \nSyndrome) patient shows \nshorter PR Interval (<0.12 \nsecond)  \n3.  When RR interval is 30 mm in ECG tracing. What \nwill be the heart rate? \na. 100 beats/min \nb. 30 beats/min \nc. 50 beats/min \nd. 10 beats/min c. 50 \nbeats/min \n Heart rate= 1500/ number \nof small squares(mm) \nbetween RR interval \nSo, 1500/30=50 beats/min \n4.  A patient came in ER with potassium levels of 6 \nmmol/L. What will be the ECG changes in the \npatient? \na. tall peaked T waves \nb. widening of QRS complex \nc. U wave appearance \nd. Flattened T wave \ne. loss of P waves a. T \nb. T \nc. F \nd. F \ne. T Patient with hyperkalemia \nshows tall peaked T wave, \nwide QRS Complex and loss \nof P wave \n5.  Following information can be interpreted by \nreading ECG- \na. Arrhythmia \nb. myocardial Infarction \nc. hypertrophy of ventricles \nd. normal heart rate \ne. electrolyte imbalance a. T \nb. T \nc. T \nd. T \ne. T Normal heart rate can be \ncounted using ECG. Also \nabnormal rhythm \n(arrhythmia), heartblock , \nhypertrophy due to \nhypertension, electrolyte \nimbalance , conduction \ndefect can be interpreted \nusing ECG',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 5},
#  {'page_content': '6. Following ECG waves indicate upward deflection \nin ECG- \na. P wave \nb. Q Wave \nc. R wave \nd. S Wave \ne. T Wave a. T \nb. F \nc. T \nd. F \ne. T P wave , R wave and T wave \nshow upward deflection in \nECG. Q and S Wave shows a \ndownward deflection in \nECG.  \n \nName of Topic: Classification of Blood Vessels and microcircula tion \nSerial \nNo Question With Options Answer Explanation \n1. Followings are windkessel vessel- \na. arterioles \nb.veinules \nc. aorta \nd. veins \ne. Arch of aorta \n a. F \nb. F \nc. T \nd. F  \ne. T Aorta and arch of aorta are \nwindkessel/distribution \nvessel. Arteries and \narterioles are resistance \nvessels as they are muscular \nand provide resistance. Veins \nare capacitance vessels are \nthey are usually the site of \nperipheral pooling \n2. Capillaries are what type of vessel? \na. Resistance vessel \nb. Sphincter Vessel \nc. Exchange vessel \nd. Shunt Vessel c. \nExchange \nvessel Capillaries are called \nexchange vessels because \nthey are the site of exchange \nof gases,nutrients, vitamin \nand waste products. \n3. Following hormones are vasodilators- \na. Angiotensin 2 \nb. Vasopressin \nc. Histamaine \nd. Substance P \ne. Epinephrine in skeletal muscle and liver a. F \nb. F \nc. T \nd. T \ne. T Vasodilator hormones- \n*Epinephrine in skeletal \nmuscle and liver \n* Histamine \n* Substance P \n* ANP \n* VIP \n* CGRP- alpha \n4. Components of microcirculation- \na. Metarterioles \nb. Precapillary sphincter region \nc. Capillaries \nd. veins \ne. veinules a. T \nb. T \nc.T \nd. F \ne. T Microcirculation consists of \nfollowing vessels-  \nMetarterioles \n Precapillary sphincter region \n Capillaries \n Finest veinules \n5.  Which one falls under the category of capacitance \nvessel? \na. Arteries \nb. Aorta \nc. Veins \nd. Capillaries C. Veins Veins are capacitance vessel \nbecause they are the site of \nperipheral pooling of blood. \nMore than 60% of blood in \nthe circulatory system is in \nthe veins',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 6},
#  {'page_content': 'Name of Topic: Relationship among Pressure , flow and resistance \nSerial \nNo Question With Options Answer Explanation \n1. The overall blood flow in the total circulation of \nan adult person at rest is about- \na. 1000ml/min \nb. 2000 ml/min \nc. 3000 ml/min \nd. 5000 ml/min d. 5000 \nml/min The overall blood flow in the \ntotal circulation of an adult \nperson at rest is about 5000 \nml/min \n2. What is the relationship between effective \nperfusion pressure and blood flow? \na. directly proportional \nb. inversely related \nc. twice the blood flow \nd. third power of blood flow a. directly \nproportional Blood flow= Effective \nperfusion pressure/ \nResistance. So , blood flow \nand effective  perfusion \npressure is directly \nproportional \n3.  If the perfusion pressure is 100 mm Hg and blood \nflow is 100 L/min , what will be the resistance of \nthe vessel? \na. 1 \nb. 2 \nc. 0.5 \nd. 100 a. 1 Blood flow= Effective \nperfusion pressure/ \nResistance. So, Resistnce= \nEffective perfusion \npressure/blood flow. So , \nresistance is 1 unit . \n4.  Factors inversely related to rate of blood flow- \na. effective perfusion pressure \nb. Radius of the vessel \nc. Resistance in the blood vessel \nd. viscosity of the blood \ne. velocity of blood flow a. F \nb. F \nc. T \nd. T \ne. F Factors inversely related to \nrate of blood flow- \n# Resistance in the blood \nvessel \n# Viscosity of the blood \n# length of the vessel \n5.  Reynolds number  -  \na. low number indicate turbulent flow \nb. higher the value greater the turbulence \nc. inversely related to the density of fluid \nd. proportional to the velocity of the flow \ne. inversely related to the diameter of the tube a. F \nb. T \nc. T \nd. T \ne. F Reynolds number is directly \nproportional to the density \nof the fluid, velocity of flow \nand diameter of the tube, \ninversely related to the \nviscosity of the fluid. Low \nnumber indicates laminar \nflow and higher the number \ngreater the turbulence \n \nName of Topic: Local & Humoral control of Blood Flow \nSerial \nNo Question With Options Answer Explanation \n1 Blood flow through the tissue increases in \nfollowing conditions-  \na. high altitude \nb. polio \nc. pneumonia \nd. CO poisoning a. T \nb. F \nc. T \nd. T \ne. T Whenever the availability of \noxygen decreases blood flow \nthrough the tissue increases. \nSo, there is increased bood \nflow in high altitude , \npneumonia, CO poisoning',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 7},
#  {'page_content': 'e. Cyanide poisoning  and cyanide poisoning \n2.  Reactive hyperemia is an example of which type \nof control of local blood flow? \na. Metabolic control \nb. Myogenic control \nc. Acute control \nd. Oxygen control a. \nMetabolic \ncontrol Reactive hyperemia and \nactive hyperemia is an \nexample of metabolic \ncontrol of local blood flow \n3.  Following substance have vasodilating properties \nin relation to humoral blood flow-  \na. Bradykinin \nb. Norepinephrine \nc. Vasopressin \nd. Histamine \ne. Endothelin -I a. T \nb. F \nc. F \nd. T \ne. F Bradykinin, histamine and \nepinephrine in skeletal \nmuscle and liver ha s \nvasodilating properties in \nrelation to humoral control \nof blood flow. \n4.  An increase in Potassium ion concentration has \nwhich effect in vascular control? \na. Vasoconstricting \nb. vasodilating \nc. No change \nd. No endothelial effect b. \nvasodilating Potassium , Magnesium, \nHydrogen , Acetate, Citrate \nand Carbon dioxide has \nvasodilating properties in \nrelation to blood flow \n5.  Following are the theories for the regulation of \nlocal blood flow- \na. Vasodilator theory \nb. Myogenic theory \nc. Oxygen Lack theo ry \nd. Adenosine Theory \ne. Metabolic Theory a. T \nb. F \nc. T \nd. F \ne. F There are two basic theories \nfor the regulation of local \nblood flow. They are \n1)vasodilator theory and \n2)oxygen lack theory \n \nName of Topic: Exchange of fluid through the capillary membrane \nSerial \nNo Question With Options Answer Explanation \n1. Forces tending to move fluid outward- \na. Capillary pressure  \nb. Negative Interstitial free fluid pressure \nc. Plasma colloid osmotic pressure \nd. Interstitial fluid colloid osmotic pressure \ne. Hydrostatic pressure a. T \nb. T \nc. F \nd. T \ne. F Capillary pressure , negative \ninterstitial free fluid pressure \nand interstitial fluid colloid \nosmotic pressure tend to \nmove fluid outward and \ncause increase of fluid in \ninterstitial space. \n2.  Decrease of which factor among the followings \nmight cause edema ? \na. Capillary pressure \nb. interstitial free fluid pressure \nc. Colloidal osmotic pressure \nd. Net reabsorption pressure c. \nColloidal \nosmotic \npressure \n Colloidal  osmotic pressure \nprevents the transudation of \nfluid out of the capillaries \ninto the tissue space. If it \ndecreases then more fluid \ngoes out the capillaries and \nmight cause edema.  \n3.  Majority of the plasma colloidal osmotic pressure \nis caused by- a. \ndissolved The value of Plasma colloidal \nosmotic pressure is about 28',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 8},
#  {'page_content': 'a. dissolved protein \nb. osmotic pressure of ions \nc. dissolved lipids \nd. pressure induced by blood corpuscles protein \n mm Hg. 19mm of it is caused \nby dissolved plasma protein \nand 9 mm is due to osmotic \npressure of ions.  \n4.  Diffusion through the capillary membrane depends \non the following factors- \na. Lipid solubility \nb. water solubility \nc. molecular size \nd. Concentration difference \ne. Capillary hydrostatic pressure a. T \nb. T \nc. T \nd. T \ne. F Diffusion through the \ncapillary membrane depends \nupon various factors. Lipid \nsoluble substance directly \ndiffuse through the \nmembrane. Non lipid soluble \nsubstance diffuse through \nintercellular pores. \nConcentration difference and \nmolecular size maintains \nwhich ions will pass the \nmembrane pores.  \n5.  Following factors increase the lymph flow- \na. Elevated capillary hydrostatic pressure \nb. elevated plasma colloidal osmotic pressure \nc. Increased interstitial fluid colloid osmotic \npressure \nd. increased permeability of the capillaries \ne. Decreased plasma colloid osmotic pressure a. T \nb. F \nc. T \nd. T \ne. T The factors which increases \ninterstitial fluid pressure also \nincreases lymph flow. That ’s \nwhy increased capillary \nhydrostatic pressure, \ndecreased plasma colloidal \nosmotic pressure and \nincreased permeability and \ninterstitial plasma colloid \nosmotic pressure increases \nthe interstitial pressure and \nlymph flow. \n \nName of Topic: SV, EDV, ESV, EF- Definition and Factors \nSerial \nNo Question With Options Answer Explanation \n1. A healthy men of average size is found to have a \nresting end diastolic volume of 200 ml and a \nresting Stroke volume of 100 ml. What will be the \nejection fraction? \na. 25% \nb. 35% \nc. 50% \nd. 75%  C. 50% Ejection fraction= stroke \nvolume/ end diastolic \nvolume \nSo, 100*100/200 % = 50% \nSo, Ejection fraction is about \n50 % \n2.  Factors affecting stroke volume- \na. venous return \nb. heart rate \nc. Total blood volume \nd. Effective filling pressure \ne. Force of contraction a. T \nb. T \nc. F \nd. F \ne. T Factors affecting stroke \nvolume- \n# Venous return \n# Heart Rate \n# Force of contraction \n#Total Peripheral resistance \n3.  Total peripheral resistance is related to Stroke a. inversely If the total peripheral',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 9},
#  {'page_content': 'volume in following relationship – \na. Inversely proportional \nb. proportional  \nc.  2 times the power of stroke volume \nd. No relationship proportional resistance is increased the \nstroke volume decreases as \nthe increasing amount of \nresistance decreases the \namount of blood pumped \nout of heart \n4.  Factors affecting End systolic volume- \na. Pressure load \nb. Total peripheral resistance \nc. Filling time \nd. effective filling pressure \ne. Force of contraction a. T \nb. F \nc. F \nd. F \ne. T Factors affecting end \nsystolic volume-  \n#Pressure load \n# Force of contracrtion \n5.  The degree to which the myocardium stretch \nbefore it contracts is known as – \na. Stroke Volume \nb. Afterload \nc. End diastolic volume \nd. Preload d. Preload The degree to which the \nmyocardium stretch before \nit contracts is known as \npreload. It is directly \nproportional to the stroke \nvolume and cardiac output.  \n \nName of Topic: Cardiac Output \nSerial \nNo Question With Options Answer Explanation \n1. What is the equation for measuring cardiac \noutput? \na. CO= Stroke volume* Heart rate \nb. CO= Stroke volume/heart rate \nc. CO = Stroke Volume /End Diastolic Volume \nd. CO= Heart Rate * Total peripheral resistance a. CO= \nStroke \nvolume* \nHeart rate \n The amount of blood that is \nejected by each ventrivle \nper minute is called Cardiac \nOutput.  \nCO= Stroke Volume * Heart \nRate \nNormal CO is 5-6 L/min in \nmale  \n2.  Relation between Total peripheral resistance and \nCardiac output is – \na. proportional  \nb. Inversely proportional \nc. Three times the power of Cardiac output \nd. no relation b. Inversely \nproportional \n Total peripheral resistance \ndecreases venous return \nwhich in turn decreases the \nEDV and Stroke volume and \nultimately decreases the \noutput of heart.  \n3. Factors influencing cardiac output- \na. Increases with age \nb. less in female \nc. decreases with surface area \nd. Increased temperature decreases CO \ne. Increases in expiration a. T \nb. T \nc. F \nd. F \ne. F CO increases with age , male \ngender, high temperature, \nsurface area,eating \n,exercises ,digestion \n,excitement ,anger etc. \nDecreases in expiration and \nno changes with sleep.  \n4.  During exercise a man consumes 1.8L of Oxygen \nper minute . His arterial Oxygen content is 190 \nml/L. Oxygen content of venous blood is 138 \nml/L. What will be the cardiac output ? b. 34.6 \nL/min \n Cardiac output according to \nthe Fick ’s principle is \nproportional to the oxygen \nconsumption by the body',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 10},
#  {'page_content': 'a. 30 L/min \nb. 34.6 L/min \nc. 45 L/min \nd. 25 L/min and inversely related to the \ndifference between arterial \nand venous level of oxygen. \nSo, CO will be = 1800 / (190-\n138)= 34.6 L/min \n5. Factors influencing Cardiac Index – \na. Heart Rate \nb. Age \nc. Stroke Volume \nd. Force of Contraction \ne. Body Surface area a. T \nb. F \nc. T \nd. F \ne. T Cardiac Index is influenced \nby-  \n# Heart Rate \n# Stroke Volume \n# Body surface area  \n \nName of Topic: Venous Return \nSerial \nNo Question With Options Answer Explanation \n1.  What is the relation between venous return and \ncardiac output ? \na. Proportional \nb. Inversely Proportional \nc. No relation \nd. Equal d. Equal The amount of blood that \ncomes from the periphery to \nthe heart is equal to the \namount of blood that is \npumped out. So Venous \nreturn is equal to Cardiac \noutput.  \n2.  Factors influencing venous return – \na. Right atrial pressure \nb. Resistance to blood flow \nc. Temperature \nd. Gravity \ne. Nervous system a. T \nb. T \nc. F \nd. T \ne. T Right atrial pressure, \nresistance to blood flow , \nmean sytemic filling pressure \n, muscular activity, gravity. \nNervous system all have \neffects on venous return  \n3.  Relationship between gravity and venous return-  \na. no significant change in supine position \nb. gravity have effect during erect posture \nc. VR from the part of the body above the heart \nincreases \nd. VR from the part of body below the heart \nincreases \ne. gravity has no effect a. T \nb. T \nc. T \nd. F \ne. F Gravity effects venous return \nduring erect posture and the \nVR from the part above the \nheart increases  whereas VR \nfrom the part below the \nheart decreases.  \n4.  Sympathetic stimulation of heart- \na. Vasoconstriction occurs \nb. Vasodilation occurs \nc. Decreases Venous return \nd. Increases Venous return \ne. increases cardiac output a. T \nb. F \nc. F \nd. T \ne. T Sympathetic stimulation of \nheart causes \nvasoconstriction and \nincreases Venous return and \nas a result increases the \ncardiac output \n5.  What will happen to the venous return of a person \nwith increased right atrial pressure ? \na. decrease of venous return \nb. No change  \nc. increase in venous return a. \ndecrease \nof \nvenous \nreturn Increase in right atrial \npressure exerts a backward \nforce in the vein to impede \nflow of blood in the vein and \ndecreases the venous return',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 11},
#  {'page_content': 'd. varies from person to person  \n \nName of Topic: Peripheral Resistance \nSerial \nNo Question With Options Answer Explanation \n1. When the mean arterial pressure is 90 mm Hg \nand the blood flow is 90 ml/s , what will be the \ntotal peripheral resistance ? \na. 8100 PRU \nb. 1 PRU \nc. 10 PRU \nd. 100 PRU b. 1 PRU \n Total Peripheral resistance = \nBlood pressure / blood flow \nSo, total peripheral \nresistance in the above case \nwill be 90/90= 1 PRU \n2.  R units or PRU is the unit of which factor? \na. Stroke Volume \nb. Heart rate \nc. Total peripheral resistance \nd. Reynolds number c. Total \nperipheral \nresistance \n PRU or R unit is the unit of \ntotal peripheral resiatnce.  \nTotal Peripheral resistance = \nBlood pressure / blood flow \n \n3.  Factors affecting peripheral resistance- \na. radius of blood vessel \nb. Force of contraction \nc. Pressure gradient \nd. Viscosity of blood \ne. effective perfusion pressure a. T \nb. F \nc. T \nd. T \ne. F Factors affecting peripheral \nresistance is-  \n\uf0b7 Radius of vessel \n\uf0b7 Pressure gradient \n\uf0b7 Viscosity of blood \n\uf0b7 Sympathetic \nstimulation \n4.  How radius of blood vessel is related to \nperipheral resistance ? \na. proportional \nb. inversely proportional \nc. No relationship \nd. three times the power of radius b.  inversely \nproportional The lesser the radius the \nmore will be the resistance. \nSo , radius of blood vessel is \ninversely related to \nperipheral resistance. \n5.  According to poiseuille ’s law following factors \nare related to blood flow- \na. viscosity of blood  \nb. diameter of the tube \nc. peripheral resistance \nd. pressure gradient \ne. length of the tube a. T \nb. T \nc. F \nd. T \ne. T According to poiseuille ’s law \nBlood flow is proportional to \nthe Pressure gradient , four \ntimes the power of radius \nand inversely proportional to \nthe viscosity and length of \nthe tube.  \n \n \nName of Topic: Heart Rate \nSerial \nNo Question With Options Answer Explanation \n1.  What is the average range of adult heart rate ? \na. 70- 80 \nb. 60- 80 c. 60-\n100 60-100 is the average range \nof adult heart rate.',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 12},
#  {'page_content': 'c. 60-100  \nd. 80-120 \n2. Factors increasing heart rate- \na. Parasympathetic stimulation \nb. Increase in Temperature \nc. Raised intracranial pressure \nd. Increase in age \ne. During Inspiration a. F \nb. T \nc. T \nd. F \ne. T Sympathetic stimulation \nincreases heart rate. \nIncrease in temperature , \nintracranial pressure , during \ninspiration ,after food , \nanger, excitement these \nfactors increase  heart rate .  \n3.  Reflexes of heart rate-  \na. Stimulation of Baroreceptor- increases \nb. Inhibition of baroreceptor- decreases \nc. Chemoreceptor- decreases \nd. Bainbridge- increases \ne. Cushing relex- Increases a. F \nb. F \nc. T \nd. T \ne. F Baroreceptor reflex-  \n# Stimulation- decreases HR \n#Inhibition –Increases HR \nChemoreceptor- Decreases  \nBainbridge – Increases HR \nCushing – Decreases HR \n4.  Following substances are the stimulant of \nchemoreceptor- \na. Increase in oxygen \nb. Increase in Carbon Dioxide \nc. Increase in Hydrogen \nd. Decrease in Oxygen \ne. Increase in Bicarbonate a. F \nb. T \nc. T \nd. T \ne. F Decrease in Oxygen , \nIncrease in Carbon Dioxide \nand Hydrogen concentration \nin the chemoreceptor \nstimulates the receptor and \ndecreases heart rate by \nstimulating the vagus nerve. \n5.  What is the range of heart rate in children ? \na. 70- 80 \nb. 60- 80 \nc. 60-100  \nd. 80-120 d. 80-\n120 60-100 is the range of HR in \nadult. 80-120 is the range of \nheart rate in children.  \n \nName of Topic: Radial Pulse \nSerial \nNo Question With Options Answer Explanation \n1. Normal arterial pulse – \na. Radial Pulse \nb. Iliac pulse \nc. Popliteal pulse \nd. Pulsus deficit \ne. Arteria dorsalis pedis pulse a. T \nb. F \nc. T \nd. F \ne. T Normal arterial pulse- \n1. Radial pulse \n2. Brachial pulse \n3. Axillary pulse \n4. Carotid pulse \n5. Femoral pulse \n6. Popliteal pulse \n7. Posterior tibial pulse \n8. Arteria dorsalis pedis \npulse \n2.  Example of abnormal pulse- \na. Water hammer pulse \nb. Catacrotic pulse \nc. Anacrotic pulse \nd. Dicrotic pulse \ne. Pulsus Alternans a. T \nb. F \nc. T  \nd. T \ne. T Abnormal pulses are- \n1. Anacrotic pulse \n2. Pulsus Alternans \n3. Pulsus Bisferiens \n4. Collapsing/Water hammer \npulse',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 13},
#  {'page_content': '5. Pulsus paradoxus \n6. Dicrotic pulse \n7. Pulsus deficit \n3.  Characteristics to be noted during examination of \npulse- \na. Rate  \nb. Rhythm \nc. Character \nd. Blood Pressure \ne. Condition of the overlying skin a. T \nb. T \nc. T \nd. F \ne. F Characters to be noted \nduring examination of pulse \nare- \nRate , rhythm , volume, \nCharacter, Condition of the \nvessel wall, Radio radial \nsymmetry and radio femoral \ndelay \n4.  Delay  between the radial and femoral pulse \nindicates-  \na. Low cardiac output \nb. Peripheral hemorrhage \nc. Coarctation of the aorta \nd. Vasculitis c. \nCoarctation \nof the \naorta When there is coarctation of \naorta there is slight delay in \nreaching the lower \nextremities. So, radial and \nfemoral pulse are not felt at \nthe same time and delay is \nfelt between the two.  \n5.  What is the function of ring finger during \nexamining radial puls e? \na. Adjust pressure \nb. Feel the appearance and disappearance \nc. stop retrograde ulnar flow \nd. fix the hand c. stop \nretrograde \nulnar flow \n Radial pulse is felt by placing \n3 fingers. Their functions \nare- \nIndex finger : Adjust \npressure \nMiddle finger: Feel the \nappearance and \ndisappearance of pulse \nRing finger : stop retrograde \nulnar flow \n \nName of Topic: Blood pressure \nSerial \nNo Question With Options Answer Explanation \n1.  If a person has a systolic pressure of 130 mm Hg \nand Diastolic pressure of 70 mm Hg , what will be \nthe mean pressure ? \na. 50 mm Hg \nb. 70 mm Hg \nc. 86.6 mm Hg \nd. 90 mm Hg d. 90 mm \nHg \n Mean pressure = Diastolic \npressure = 1/3 of pulse \npressure  \nPulse pressure = Systolic- \ndiastolic \nSo , pulse pressure is 60 mm \nHg and the mean pressure is \n70+ 1/3 of 60 = 90 mm Hg \n \n2.  Information gained by systolic pressure –  \na. extent of work done by the heart \nb. constant load  against which the heart works \nc. cardiac output \nd. degree of pressure which the arterial wall has \nto withstand a. T \nb. F \nc. F \nd. T \ne. T Systolic pressure indicates –  \n1. Extent of the work done \nby the heart \n2. degree of pressure which \nthe arterial wall has to \nwithstand',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 14},
#  {'page_content': 'e. force with which the heart is working 3. force with which the heart \nis working \n4. Increases during exercise , \nexcitement , meal etc \n \n3.  Factors regulating blood pressure –  \na. Increased CO : Increased BP \nb. Increased  TPR : Decreased BP \nc. Increased Blood volume : Decreased BP \nd. Increases with increased age \ne. Exercise increases Bp a. T \nb. F \nc. F \nd. T \ne. T Blood Pressure increases \nwith increased CO, Total \nPeripheral resistance, \nPumping action of heart , \nexercise,emotion \n,excitement , digestion of \nfood. Blood pressure is \nslightly less in female.  \n4.  Following organs and mechanisms play role in \nrapid control of blood pressure-  \na. Baroreceptor feedback \nb. Chemoreceptor mechanism \nc. Kidney \nd. maintenance of body fluid volume \ne. CNS Ischemic mechanism a. T \nb. T \nc. F \nd. F \ne. T Baroreceptor , \nchemoreceptor and CNS \nIschemic mechanism help in \nrapid control of Blood \npressure . Kidney and body \nfluid homeostasis maintain \nlong term control of blood \npressure.  \n5. Which one is not an intermediate term regulation \nof blood pressure ? \na. Renin Angiotensin Vasoconstrictor mechanism \nb. Stress relaxation of the vasculature \nc. Capillary fluid shift mechanism \nd. Renin Angiotensin Aldosterone Mechanism d. Renin \nAngiotensin \nAldosterone \nMechanism Intermediate term \nregulation of blood \npressure-  \na. Renin Angiotensin \nVasoconstrictor mechanism \nb. Stress relaxation of the \nvasculature \nc. Capillary fluid shift \nmechanism \n6.  Where are the chemoreceptors located ? \na. Carotid bodies \nb. Aortic bodies \nc. Arch of Aorta \nd. a+b d. a+b Chemoreceptors are located \nin the carotid and aortic \nbodies \n \nName of Topic: Shock \nSerial \nNo Question With Options Answer Explanation \n1.  A patient came into the ER with cardiac failure \nand hypotension ,cold clammy skin and \noligouria. What type of shock will be diagnosed ? \na. Hypovolemic shock \nb. Obstructive shock \nc. Distributive shock \nd. Cardiogenic shock d. \nCardiogenic \nshock Myocardial infarction , \ncongestive cardiac failure , \narrhythmia might cause \ncardiogenic shock. Cold \nclammy skin , hypotension , \noligouria ,anuria these are \nthe symptoms of shock. \n2.  compensatory reactions of shock – a. T Vasoconstriction ,',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 15},
#  {'page_content': 'a. Vasoconstriction \nb. Tachycardia \nc. Decreased blood pressure \nd. Increased heart rate \ne. Increase secretion of glucocorticoids b. T \nc. F \nd. T \ne. T tachycardia , Tachypnea, \nRestlessness , Increased \nsecretion of erythropoietin , \nglucocorticoids, aldosterone, \nepinephrine,norepinephrine, \nvasopressin all are \ncompensatory mechasims of \nshock.  \n3.  CVS changes in shock-  \na. Decreased heart rate \nb. Increased blood pressure \nc. Increased peripheral resistance \nd. Increased blood flow to urine \ne. increased cardiac output a. F \nb. F \nc. T \nd. F \ne. F During shock , BP , CO , \nblood flow to kidney \neverything decreases. Heart \nrate , peripheral resistance \nincreases and \nvasoconstriction occurs.  \n4.  Which one is not a stage of shock ? \na. Progressive stage \nb. nonprogressive stage \nc. stage of organ failure \nd. Irreversible stage c. stage of \norgan failure \n Shock has 3 stages-  \n1. Progressive stage \n2. non progressive stage \n3. irreversible stage \n5.  The factors that recovers a person from \nnonprogressive stage of shock-  \na. Baroreceptor reflex \nb. CNS Ischemic response \nc. Increased Angiotensin II \nd. Increased ADH Secretion \ne. Reverse stress relaxation a. T \nb. T \nc. T \nd. T \ne. T Baro receptor , CNS ischemic \nreflex , reverse stress \nrelaxation these negative \nfeedback mechanism and \nalso increased secretion of \nRenin , Angiotensin II , ADH , \nEpinephrin and Norepinehrin \nall help in recovering a \nperson from shock.  \n6. Causes of neurogenic shock-  \na. Deep general anesthesia \nb. Spinal Anesthesia \nc. Heart Failure \nd. Massive hemorrhage \ne. Brain damage a. T \nb. T \nc. F \nd. F \ne. T Causes of neurogenic shock \nare-  \n1. Deep general anesthesia \n2. Spinal Anesthesia \n3. Brain damage \n7.  High raised temperature can be seen in which \nshock ? \na. Cardiogenic shock \nb. Obstructive shock \nc. Septic shock \nd. Neurogenic shock c. Septic \nShock There is bacterial infection \nwidely disseminated to many \nareas of the body that ’s why \nthere is increased \ntemperature and fever as a \nimmune response.  \n8.  Which shock is the result of an antigen antibody \nreaction  ? \na. Septic shock \nb. Neurogenic shock \nc. Anaphylactic shock \nd. Circulatory shock c. \nAnaphylactic \nshock \n In anaphylactic shock , \nperson is sensitive to an \nallergen or foreign antigen . \nSo , anytime person comes in \ncontact of that allergen huge \namount of antibody is \nformed and antigen antibody',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 16},
#  {'page_content': 'reaction occurs and massive \nhistamine release occurs. \nHistamine causes massive \nvasodilation and loss of fluid \nand ultimately patient dies of \nshock.  \n \nName of Topic:Tachycardia, bradycardia and heart block \nSerial \nNo Question With Options Answer Explanation \n1.  physiological causes of tachycardia – \na. Anxiety \nb. Fever \nc. Exercise \nd. Emotion \ne. Excitement a. F \nb. F \nc. T \nd. T \ne. T Physiological causes of \ntachycardia- \n#Exercise \n#Emotion \n#Excitement \n2.  Types of atrioventricular block – \na. First degree block \nb. Complete heart block \nc. Right Bundle branch block \nd. Mobitz Type II block \ne. Second Degree block a. T \nb. T \nc. F \nd. F \ne. T AV blocks are – \na. First degree block \nb. Second degree block \n #Mobitz Type I \n # Mobitz Type II \nc. Complete heart block \n3.  A medical student saw an ECG in which the PR \nintervals become progressively longer until one \nQRS complex is dropped. What is the type of \nblock? \na. First Degree \nb. Sinoatrial block \nc. Mobitz Type I  \nd. Mobitz Type II c. \nMobitz \nType I  \n In mobitz Type I or \nWenckebach block the PR \nintervals become \nprogressively longer until \none QRS complex is dropped.  \n4.  Dropped beat is seen in – \na. First Degree \nb. Complete Block \nc. Mobitz Type I  \nd. Mobitz Type II d. \nMobitz \nType II In Mobitz Type II the ECG \nshows two or normal beats \nwith normal PR intervals and \nthen a P wave that is not \nfollowed by a QRS complex.  \n5.  Following conditions might cause Stokes Adams \nSyndrome- \na. Complete heart block \nb. Sinoatrial Block \nc. Mobitz Type II Block \nd. Right Bundle Branch Block \ne. First Degree Block a. T \nb. T \nc. T \nd. F \ne. F Recurrent episodes of \ntemporary loss of \nconsciousness caused by an \ninsufficient flow of blood \nfrom the heart to the vein is \ncalled Stokes Adams \nSyndrome. \nCauses of stokes Adams \nSyndrome- \n1. Complete heart block \n2. Mobitz Type II second \nDegree AV Block',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 17},
#  {'page_content': '3. Sinoatrial Diseases',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 18},
#  {'page_content': '**please note: half of the questions you provide should be true/false; the other half should be in a \nSingle best answer (SBA) format. The questions should have minimum 4 options (for SBA), 5 opti ons (for \ntrue/false) \nName of Subject: Physiology \nName of Card: GIT \nName of Topic: Physiological Anatomy of GIT \nSerial \nNo Question With Options Answer Explanation \n1 How many layers are found in the cross section of \nintestinal wall ? \na. 3  \nb. 4 \nc. 5 \nd. 6 c. 5 There are 5 layers in the \nintestinal wall . From outer to \ninward –  \n1. serosa 2. Longitudinal \nsmooth muscle layer 3. \nCircular smooth muscle layer  \n4. submucosa and 6. mucosa \n2.  Part of gastrointestinal tract- \na. Mouth \nb. Esophagus \nc. Stomach \nd. Duodenum \ne. Anus a. F \nb. F \nc. T \nd. T \ne. T Gastrointestinal tract extends \nfrom the stomach to anus. \nAlimentary yract extends \nfrom the mouth to anus.  \n3.  How many types of electrical waves are seen in the \ngastrointestinal smooth muscle? \na. 1 \nb. 2 \nc. 3 \nd. 4 b. 2 There are 2 types of electrical \nactivity seen in the \ngastrointestinal smooth \nmuscles. They are – \n1. Slow waves \n2. Spikes \n4.  Slow waves are – \na. true action potentials \nb. slow undulating changes in the resting \nmembrane potential \nc. Intensity varies between 5 and 15 milivolts \nd. cause muscle contractions by themselves \ne. excite the appearance of intermittent spike \npotential a. F \nb. T \nc. T \nd. F \ne. T Slow waves are not true \naction potentials rather they \nare slow undulating changes \nin the resting membran e \npotential. The intensity varies \nbetween 5 and 15 milivolts . \nThey do not cause muscle \ncontractions by themselves \nexcept in the stomach and \nexcite the appearance of \nspike potential.  \n5.  Which cells are the electrical pacemaker of the \nsmooth muscle cell ? \na. Myenteric plexus \nb. Auerbach Plexus \nc. Interstitial Cells of Cajal \nd. Neurotransmitter releasing cells c. \nInterstitial \nCells of \nCajal \n The basic electrical rhythm is \ninitiated by the specialized \ncells called the interstitial \ncells of Cajal ,that are \nbelieved to act as the \nelectrical pacemaker of \nsmooth muscle cells.  \n \nName of Topic:Enteric Nervous System',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 19},
# ...
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 808},
#  {'page_content': '12 Drugs act by tyrosine \nkinase mechanism - \nA.Opioids  \nB.insulin  \nC.thyroid hormones  \nD.Growth hormone  \nE.Prolactin  A.F \nB.T \nC.F \nD.T \nE.T \n Tyrosine kinase mechanism - \nProlactin,insulin,GH  \n13 G-protein coupled \nreceptors are- \nA.Muscarinic \nreceptors  \nB.Adrenoceptors  \nC.Steroid receptors  \nD.GABA receptors  \nE.Dopominergic \nreceptors  \n A.T \nB.T \nC.F \nD.F \nE.T \n Steroid receptors – nuclear receptors.  \nGABA receptors –ligand gated ion channel receptors  \n \n14 Types of G -protein \ncoupled receptors \nare- \nA.Gi \nB.Gp \nC.Gq \nD.G0 \nE.Gs \n A.T \nB.F \nC.T \nD.F \nE.T \n  \n15 First messengers are - \nA.Hormones  \nB.drugs  \nC.Ca++ ion  \nD.Neurotransmitters  \nE.cAMP  \n A.T \nB.T \nC.F \nD.T \nE.F \n Ca++,cAMP -2nd messengers  \n16 Highest amount of \nspare receptors are \nseen in - \nA.Nicotinic receptors  \nB.GABA receptors  \nC.Insulin receptors  \nD.Adrenoceptors  \nE.Glutamate \nreceptors  \n C \n  \n17 Partial agonists are - \nA.Nalorphine  \nB.Dopamine  \nC.Pindolol  A.T \nB.F \nC.T \nD.T Dopamine,Salbutamol -pure agonist.',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 809},
#  {'page_content': 'D.Acebutolol  \nE.Salbutamol  \n E.F \n \n18 Example of \npotentiation include - \nA.Aspirine+Paracetam\nol \nB.Levodopa+Carbidop\na \nC.Amlodipine+Atenol\nol \nD.Acetylcholine+Phys\nostigmine  \nE.Metformine+Gliben\nclamide  \n A.F \nB.T \nC.F \nD.T \nE.F \n  \n19 Levodopa induced \ndyskinesia is an \nexample of which \ntype of ADR?  \nA.Augmented  \nB.BIzzare  \nC.Chronic  \nD.Delayed  \nE.withdrawal \nreactions  \n C \n  \n20 Drugs producing \ndependence are - \nA.Morphine  \nB.LSD \nC.Beta blockers  \nD.Diazepam  \nE.Cocaine  \n A.T \nB.T \nC.F \nD.T \nE.T \n Dependence producing drugs are - \nMorphine,lds,diazepam,cocain,alcohol,heroin,pethidine.',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 810},
#  {'page_content': 'Your name:Prottoy Biswas  \n                        Name of the subject: Pharmacology  \nName of Card: …………?  \n                                                                         Name of topic:   \nSerial No  Question  Answer  Explanation  \n01 A. \nB. \nC. \nD. \nE. \n A. \nB. \nC. \nD. \nE. \n  \n02 A. \nB. \nC. \nD. \nE. \n A. \nB. \nC. \nD. \nE. \n  \n03 A. \nB. \nC. \nD. \nE. \n A. \nB. \nC. \nD. \nE. \n  \n04 A. \nB. \nC. \nD. \nE. \n A. \nB. \nC. \nD. \nE. \n  \n A. \nB. \nC. \nD. \nE.',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 811},
#  {'page_content': 'Md Washi Al Mostkaim  \nName of the subject: Pharmacology \nName of the card: Respiratory pharmacology- 08 \n \nName of topic: Drugs used in bronchial asthma; Drugs used to treat \ncough/Antitussives- 08 \nSerial \nNo Question with options  Answer Explanation \n1 What are the short acting β₂ -\nagonists used in the treatment \nof bronchial asthma? \na) Salbutamol \nb) Salmoterol \nc) Albutarol \nd) Bambutarol \ne) Formoterol    a) T \nb) F \nc) T \nd) F \ne) F Salmoterol and formoterol \nare long acting, and \nbambutarol is ultra long \nacting β₂ -agonists \n2 What are the anti-\ninflammatory drugs used in \nthe treatment of bronchial \nasthma? \na) Ipratropium bromide \nb) Montelukast \nc) Omalizumab \nd) Aminophylline \ne) Beclomethasone  a) F \nb) T \nc) T \nd) F \ne) T Ipratropium bromide is an \nanti-muscarinic and \naminophylline is a \nmethylxanthine \nbronchodilators \n3 Montleukast- \na) Is a steroid sparing \nagent \nb) Not effective in \npersistent asthma \nc) Effective in situations \nwhere immediate \nbronchodilation is \nneeded \nd) Once-daily treatment \ne) Provides additional a) T \nb) F \nc) F \nd) T \ne) T Montelukast- \n\uf0b7 Very much effective in \npersistent asthma \n\uf0b7 Not effective in \nsituations where \nimmediate \nbronchodilation is \nneeded',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 812},
#  {'page_content': 'control of symptoms \nduring exercise \n4 What are the peripherally \nacting antitussives? \na) Methanol \nb) Benzoin inhalation \nc) Morphine \nd) Dextromethorphan \ne) Water aerosol \ninhalation a) T \nb) T \nc) F \nd) F \ne) T Morphine and \ndextromethorphan are \ncentrally acting antitussives  \n5 What are the drugs used in \nnebulization? \na) Salbutamol \nb) Terbutaline \nc) Beclomethasone \nd) Budesonide \ne) Salmoterol  a) T \nb) T \nc) F \nd) T \ne) F Drugs used in nebulization- \n\uf0b7 Salbutamol \n\uf0b7 Ipratropium \n\uf0b7 Budesonide \n\uf0b7 Terbutaline  \n6 Which is the most common \nrisk of inhaled \nglucocorticoids? \na) Hoarseness of voice \nb) Dryness of airway \nc) Oropharyngeal \ncandidiasis \nd) Irritation of airway \ne) Osteoporosis c) All of these are risks of \ninhaled glucocorticoids but \noropharyngeal candidiasis is \nthe most common \n7 Churg-Strauss syndrome is an \nadverse effect of which group \nof drugs? \na) Glucocorticoids \nb) Leukotriene inhibitors \nc) Mast cell stabilizers \nd) Anti-muscarinic agents \ne) β₂-agonists b) Churg-Strauss syndrome is a \nsystemic vasculitis \naccompanied by worsening \nasthma, pulmonary \ninfiltration and eosinophilia \n8 Which of the following drugs \ncauses liver toxicity? c) Zileuton causes liver toxicity, \nso it is the least prescribed of',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 813},
#  {'page_content': 'a) Zafirlukast \nb) Montelukast \nc) Zileuton \nd) Omalizumab \ne) Glucocorticoids  leukotriene inhibitors',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 814},
#  {'page_content': 'Md Washi Al Mostkaim  \nName of the subject: Pharmacology \nName of the card: Endocrinology- 27 \n \nName of topic: Drugs for diabetes mellitus- 10 \nSerial \nNo Question with options  Answer  Explanation  \n1 What are the long acting \ninsulin analogues? \na) Insulin Lispro \nb) Natural insulin \nc) Insulin glargine \nd) Crystalline insulin zinc \nsuspension \ne) NPH (Neutral \nProtamine Hagedorn) a) F \nb) F \nc) T \nd) T \ne) F \uf0b7 Insulin Lispro- Ultra short \nacting \n\uf0b7 Natural insulin- Short \nacting \n\uf0b7 NPH- Intermediate acting \n2 What are the adverse effects \nof insulin? \na) Hyperkalemia \nb) Alopecia \nc) Edema \nd) Alopecia \ne) Decreased body weight a) F \nb) T \nc) T \nd) T \ne) F Adverse effects of insulin \nincludes- \n\uf0b7 Hypokalemia \n\uf0b7 Obesity \n3 Insulin sensitizers are- \na) Metformin \nb) Glibenclamide \nc) Pioglitazone \nd) Repaglinide \ne) Nateglinide  a) T \nb) F \nc) T \nd) F \ne) F Glibenclamide, repaglinide \nand nateglinide all are insulin \nsecretagogues \n\uf0b7 Glibenclamide : \nSulfonylurea \n\uf0b7 Repaglinide: Meglitinide \n\uf0b7 Nateglinide: D-\nphenylalanine derivatives \n4 What are the adverse effects \nof metformin? \na) Lactic acidosis \nb) Agranulocytosis \nc) Aplastic & hemolytic \nanemia \nd) Cholestatic jaundice \ne) Acute kidney failure in a) T \nb) F \nc) F \nd) F \ne) T Agranulocytosis , aplastic & \nhemolytic anemia and \ncholestatic jaundice are \nadverse effects of \nsulphonylureas',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 815},
#  {'page_content': 'patients receiving \nradiocontrast agents \n5 Which of the following drugs \nslow the intestinal absorption \nof glucose? \na) Metformin \nb) Acarbose \nc) Miglitol \nd) Phenformin \ne) Glibenclamide a) F \nb) T \nc) T \nd) F \ne) F Acarbose and miglitol are α -\nglucosidase inhibitors. These \nagents principally slow the \nintestinal absorption of \nglucose \n6 Which of the following drugs \ncan be used to treat DM in \npregnancy? \na) Metformin \nb) Insulin \nc) Nateglinide \nd) Glipizide \ne) Repaglinide b) Oral hypoglycemic agents are \nteratogenic, so they are \ncontraindicated in pregnancy \n7 Megaloblastic anemia is an \nadverse effect of which drug? \na) Metformin \nb) Pioglitazone \nc) Miglitol \nd) Sitagliptin \ne) Glibenclamide a) In chronic use of metformin, \ndecreased vitamin B₁₂ \nabsorption leads to \nmegaloblastic anemia  \n8 Which is the only \nsulphonylurea that does not \ncross the placenta? \na) Tolbutamide \nb) Tolazamide \nc) Glipizide \nd) Glibenclamide \ne) Gliclazide  d) Glibenclamide is the only \nsulphonylurea that does not \ncross the placenta \n9 Which of the following drugs \nis used to treat type 2 diabetes \nin obese persons? \na) Glipizide \nb) Metformin \nc) Repaglinide \nd) Pioglitazone b) Metformin is used to treat type \n2 diabetes in obese persons, \nand glipizide or other \nsulphonylureas are used to \ntreat type 1 diabetes in obese \npersons',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 816},
#  {'page_content': 'e) Acarbose  \n10 A boy of 20 years has come \nto you with diabetes mellitus. \nWhat drug is suitable for \nhim? \na) Insulin \nb) Metformin \nc) Sulphonylureas \nd) Pioglitazone \ne) Repaglinide a) This is a case of type 1 or \njuvenile or insulin dependent \ndiabetes mellitus. In this case \nthere is absolute deficiency of \ninsulin. That ’s why my drug of \nchoice is insulin \n \n \nName of topic: Adrenal steroids & adrenocortical antagonists- 05 \nSerial \nNo Question with options  Answer  Explanation  \n1 What are the long acting \nglucocorticoids? \na) Betamethasone \nb) Dexamethasone \nc) Hydrocortisone \nd) Prednisolone \ne) Triamcinolone  a) T \nb) T \nc) F \nd) F \ne) F \uf0b7 Hydrocortisone & \nprednisolone: Short- to-\nmedium acting \n\uf0b7 Triamcinolone: \nIntermediate-acting \n2 What are the high potency \nglucocorticoids? \na) Betamethasone \nb) Dexamethasone \nc) Hydrocortisone \nd) Prednisolone \ne) Triamcinolone a) T \nb) T \nc) F \nd) F \ne) F \uf0b7 Hydrocortisone & \nprednisolone: Low potency \n\uf0b7 Triamcinolone: \nIntermediate potency \n3 Which of the following are \nadverse effects due to long \nterm use of glucocorticoids? \na) Pseudo-tumor cerebri \nb) Hypokalemia with \nglycosuria \nc) Arthralgia \nd) Iatrogenic Cushing ’s \nsyndrome a) F \nb) T \nc) F \nd) T \ne) T Pseudo-tumor cerebri and \narthralgia are due to sudden \nwithdrawal of corticosteroid \ntherapy',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 817},
#  {'page_content': 'e) HTN  \n4 Which of the following drugs \nis glucocorticoid receptor \nantagonist? \na) Ketoconazole \nb) Spironolactone \nc) Aminoglutethimide \nd) Metyrapone \ne) Mifepristone   e) Spironolactone is an \naldosterone antagonist. Rests \nare adrenal steroid synthesis \ninhibitors. \n5 “Dexamethasone suppression \ntest” is used for the diagnosis \nof which condition? \na) Addison ’s disease \nb) Cushing ’s syndrome \nc) Aldosteronism \nd) Congenital adrenal \nhyperplasia \ne) Addisonian crisis  b) “Dexamethasone suppression \ntest” is used for the diagnosis \nof Cushing ’s syndrome \n \n \nName of topic: Gonadal hormones & inhibitors- 05 \nSerial \nNo Question with options  Answer  Explanation  \n1 What are the anti-\nprogesterone drugs? \na) Mifepristone \nb) Tamoxifen \nc) Raloxifen \nd) Danazol \ne) Lilopristone a) T \nb) F \nc) F \nd) T \ne) T  Tamoxifen and raloxifen are \nselective estrogen receptor \nmodulator \n2 What are the barrier methods \nof contraception? \na) Condom \nb) Vaginal ring \nc) Vaginal diaphragm \nd) Copper T \ne) Cervical cap a) T \nb) F \nc) T \nd) F \ne) T Copper T is an intrauterine \ndevice and vaginal ring is a \nhormonal method of \ncontraception \n3 Which of the following d) Administration of mifepristone',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 818},
#  {'page_content': 'drugs is used for the \ntermination of early \npregnancy? \na) Tamoxifen \nb) Clomiphene \nc) Danazol \nd) Mifepristone \ne) Lilopristone to females early in pregnancy \nresults, in most cases (up to \n94%), in abortion of the fetus \ndue to the interference with \nprogesterone and the decline in \nhCG \n4 What is the most common \nproblem in using \nprogestational agents alone \nfor contraception? \na) Withdrawal bleeding \nb) Breakthrough \nbleeding \nc) Acne \nd) Weight gain \ne) Hirsutism  b) Breakthrough bleeding is the \nmost common problem in using \nprogestational agents alone for \ncontraception \n5 Which of the following \ndrugs is used to decrease \nexcessive sexual drive in \nmen? \na) Ketoconazole \nb) Abiraterone \nc) Cyproterone \nd) Sprinolactone \ne) Flutamide  c) \uf0b7 Cyproterone: \nI. To decrease \nexcessive sexual \ndrive in men \nII. Hirsutism in \nwomen \n\uf0b7 Flutamide: \nI. Prostatic \ncarcinoma \nII. Hirsutism in \nwomen \n\uf0b7 Spironolactone: \nI. Hirsutism in \nwomen \n \n \nName of topic: Thyroid hormones & anti-thyroid drugs- 07 \nSerial \nNo Question with options  Answer  Explanation  \n1 What are the thioamides a) F Percholate and thiocyanate are',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 819},
#  {'page_content': 'anti-thyroid drugs? \na) Percholate \nb) Thiocyanate \nc) Carbimazole \nd) Methimazole \ne) Propylthiouracil  b) F \nc) T \nd) T \ne) T  anion inhibitors  \n2 What are the drugs used in \nthe treatment of \nhypothyroidism? \na) 131I \nb) Liotrix  \nc) Levothyroxine  \nd) Pertechnetate  \ne) Liothyronine a) F \nb) T \nc) T \nd) F \ne) T  131I and pertechnetate are drugs \nused in the treatment of \nhyperthyroidism  \n3 Which of the following \nstatements is true about \nliothyronine?  \na) Long half life \nb) Requires once-daily \nadministration \nc) Low cost \nd) Greater difficulty of \nmonitoring \ne) Greater risk of \ncardiotoxicity a) F \nb) F \nc) F \nd) T \ne) T  Liothyronine- \n\uf0b7 Short half like (24 hours) \n\uf0b7 Requires multiple doses \n\uf0b7 High cost \n4 What are the \ncontraindications of 131I? \na) Planned pregnancy \nwithin 6 months \nb) Patients>60 years \nc) Lactation \nd) Recurrence following \nsurgery irrespective of \nage \ne) Active Graves ’ \nophthalmopathy a) T \nb) F \nc) T \nd) F \ne) T  Patients>60 years and active \nGraves ’ ophthalmopathy are \nindications of 131I \n5 What is the most common \nadverse effect of thioamides? \na) Agranulocytosis \nb) Maculopapular b) Maculopapular pruritic rash is \nthe most common adverse \neffect of thioamides, while \nagranulocytosis is the most',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 820},
#  {'page_content': 'pruritic rash \nc) GI distress \nd) Hepatitis \ne) Cholestatic jaundice dangerous complication \n6 Which of the following \ndrugs cause an altered sense \nof taste or smell? \na) Carbimazole \nb) Methimazole \nc) Propylthiouracil \nd) 131I \ne) Amiodarone  b) Methimazole causes damage to \nolfactory mucosa. \n7 Which of the following drug \nis peripheral iodothyronine \ndeiodination inhibitor? \na) Amiodarone \nb) Nitrotyrosine \nc) Lithium salts \nd) Percholate \ne) Carbimazole a) \uf0b7 Nitrotyrosine: Iodotyrosine \ndeiodination inhibitor \n\uf0b7 Lithium salts: Hormone \nrelease inhibitor \n\uf0b7 Percholate: Anion inhibitor \n\uf0b7 Carbimazole: Thioamide',
#   'source': '/content/gdrive/MyDrive/AI_integration_kernel/MediBee/AllTF.pdf',
#   'page': 821}]

# %%
book_collection.insert_many(document)

# %% [markdown]
# #Set Up topics

# %%
topics ={
    1:["Parts of Upper Limb", "Parts of Ulna"],
    2:["Injuries of the Upper Limb", "Winging of Right Scapula"],
    3:["Clavicle", "Anatomical Position and Side Determination of Clavicle"],
    4:["Ossification", "Brachial Plexus"],
    5:["Lymphatics", "Axillary lymph"]
}

# %% [markdown]
# #Set Up Question Schema For MongoDB

# %%
question_schema = {
    'prof': {
        'type': 'int',
        'required': True,
    },
    'item': {
        'type': 'int',
        'required': True,
    },
    'topic': {
        'type': 'string',
        "required": True,
    },
    'question': {
        'type': 'string',
        'min_length': 7,
        'required': True,
    },
    'hint': {
        'type': 'string',
        'min_length': 7,
        'required': True,
    },
    'correct_answer':{
        'type':'string',
        'required': True
    }
}

# %%
question_collection = db['question_collection']

# %%
validator = {'$jsonSchema': {'bsonType': 'object', 'properties': {}}}
required = []

for field_key in question_schema:
    field = question_schema[field_key]
    properties = {'bsonType': field['type']}
    minimum = field.get('minlength')

    if type(minimum) == int:
        properties['minimum'] = minimum

    if field.get('required') is True: required.append(field_key)

    validator['$jsonSchema']['properties'][field_key] = properties

if len(required) > 0:
    validator['$jsonSchema']['required'] = required

# %%
query = [('collMod', question_collection),
         ('validator', validator)]

# %%
from pymongo.errors import CollectionInvalid
from collections import OrderedDict

try:
    db.create_collection(question_collection)
except CollectionInvalid:
    pass

command_result = db.command(OrderedDict(query))

# %% [markdown]
# #Generate Viva Questions, Hint and Answers in bulk

# %%
# Get user input for the item number
itemNumber = input("Enter Syllabus (e.g: item 1): ")

# Check if the item number is valid
if not itemNumber.isdigit() or int(itemNumber) not in topics:
    print("Invalid syllabus item number.")
else:
    itemNumber = int(itemNumber)
    print(', '.join(topics[itemNumber]))

    # Get user input for the topic number
    topicNumber = input("Enter Topic (e.g: topic 1): ")

    # Check if the topic number is valid
    if not topicNumber.isdigit() or int(topicNumber) not in range(len(topics[itemNumber])):
        print("Invalid topic number.")
    else:
        topicNumber = int(topicNumber)
        query = topics[itemNumber][topicNumber]

        # Get the context and prompt
        context = get_search_result(query, book_collection)
        prompt = get_prompt_viva(query=query, context=context)

        # Print input tokens
        print('Input tokens: ', model.count_tokens(prompt))

        # Generate the question and print it
        question = model.generate_content(prompt).text
        print(question, '\n\n')

        # Print output tokens
        print('Output tokens: ', model.count_tokens(question))
# Out:
# Enter Syllabus (e.g: item 1): 1
# parts of upper limb, parts of ulna
# Enter Topic (e.g: topic 1): 0
# [-0.01790490746498108, -0.011766434647142887, -0.005245641339570284, -0.006346830632537603, 0.020574742928147316, 0.0007055028690956533, 0.0014444992411881685, 0.018194040283560753, 0.003707524389028549, 0.021906251087784767, 0.01819639466702938, -0.003038702066987753, 0.014116947539150715, -0.03820246085524559, 0.006633208133280277, 0.02697610668838024, -0.027459517121315002, -0.036991093307733536, -0.0245593823492527, -0.011222580447793007, 0.0029232194647192955, -0.012209158390760422, -0.060342758893966675, -0.02657245099544525, -0.012098945677280426, 0.014551391825079918, 0.016861632466316223, 0.024732623249292374, 0.04672696441411972, 0.06042812019586563, -0.02031027153134346, -0.02423052117228508, 0.024826329201459885, -0.039862990379333496, -0.014791200868785381, -0.025070328265428543, 0.03467494621872902, -0.024285560473799706, -0.0343654602766037, -0.037034109234809875, 0.005111619830131531, -0.005904453340917826, 0.0225185826420784, -0.036403510719537735, -0.012937784194946289, -0.007127909455448389, -0.008967109955847263, -0.03237941488623619, -0.001560874399729073, -0.03456085920333862, 0.018156470730900764, -0.01304585300385952, 0.00953618437051773, -0.01801079511642456, -0.024163302034139633, 0.0023958166129887104, 0.001934603787958622, 0.003165139816701412, -0.025213824585080147, 0.022458437830209732, 0.011537428945302963, -0.0311854500323534, 0.004853326361626387, -0.0720481351017952, 0.025735044851899147, 0.020829182118177414, -0.0049231951124966145, 0.004800290334969759, 0.0022451640106737614, -0.048517681658267975, -0.018723130226135254, -0.008134765550494194, -0.01800733432173729, -0.0272406954318285, 0.0062499581836164, 0.009385158307850361, -0.02579791471362114, 0.011170760728418827, 0.0021462589502334595, -0.0034600584767758846, 0.015011768788099289, 0.05284842103719711, 0.015203998424112797, 0.014798112213611603, -0.049828287214040756, 0.016256310045719147, -0.02717581018805504, 0.04547438770532608, 0.0032134687062352896, -0.022860173135995865, 0.006856783293187618, 0.042606424540281296, 0.005059512797743082, -0.021151715889573097, 0.04245378077030182, 0.027023591101169586, -0.046603698283433914, 0.03668903931975365, -0.0005383458337746561, -0.028823263943195343, 0.043352071195840836, 0.026181893423199654, 0.0012374863727018237, 0.045061055570840836, -0.044033560901880264, -0.012586059048771858, 0.0062360819429159164, 0.0011063008569180965, 0.025182439014315605, -0.02935607172548771, -0.00803879089653492, -0.020465750247240067, -0.00906885601580143, 0.013309945352375507, 0.0012706366833299398, 0.04093777760863304, 0.00423556100577116, 0.0009958475129678845, -0.020527495071291924, 0.05925135686993599, 0.02681947685778141, 0.00211018742993474, 0.05865667760372162, -0.015478142537176609, 0.03438453748822212, -0.024835407733917236, -0.05303662270307541, 0.050927042961120605, -0.023479895666241646, -0.003778692800551653, -0.007309146225452423, -0.026012077927589417, -0.039909232407808304, 0.003898081835359335, -0.045206863433122635, 0.0010924558155238628, -0.04462150111794472, 0.039505600929260254, 0.0051721809431910515, -0.05528295412659645, 0.022320527583360672, 0.023766519501805305, 0.03501755744218826, 0.07016231119632721, 0.012040186673402786, 0.027715779840946198, 0.004249763675034046, 0.00821040477603674, -0.018679946660995483, 0.011006948538124561, -0.020241333171725273, 0.03654831275343895, -0.02389479987323284, 0.024705447256565094, -0.013930737972259521, -0.001686956500634551, -0.006665509659796953, 0.014117206446826458, -0.0024006615858525038, 0.055626221001148224, -0.0037585077807307243, 0.0028736949898302555, 0.0019982389640063047, 0.054969415068626404, 0.00012828563922084868, 0.031375449150800705, -0.028609804809093475, -0.017139365896582603, -0.010849147103726864, -0.03138359636068344, 0.010847356170415878, -0.0002669775567483157, 0.020935334265232086, 0.007222788408398628, -0.022298147901892662, 0.042422372847795486, 0.051574647426605225, 0.0100991390645504, 0.005160297732800245, 0.059498559 ...
# Input tokens:  total_tokens: 3193
#
# {
#     "Topic": "Parts of Upper Limb",
#     "Questions": [
#         {
#             "Question": "What are the components of the pectoral girdle?",
#             "Hint": "What bones make up the shoulder girdle?",
#             "Answer": "The pectoral girdle consists of two bones - the scapula and the clavicle."
#         },
#         {
#             "Question": "Name the bone of the upper arm and the bones of the forearm.",
#             "Hint": "What is the single bone of the arm?",
#             "Answer": "The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna."
#         },
#         {
#             "Question": "How many carpal bones are there and how are they arranged?",
#             "Hint": "What is the composition of the wrist?",
#             "Answer": "The wrist consists of eight carpal bones arranged in two rows, each consisting of four bones."
#         },
#         {
#             "Question": "Name the three main regions of the shoulder region and the bones involved in each.",
#             "Hint": "What are the different parts of the shoulder?",
#             "Answer": "The shoulder region includes: (a) axilla or armpit, (b) scapular region or parts around the scapula (shoulder blade), and (c) pectoral or breast region on the front of the chest. The bones of the shoulder region are the clavicle (collar bone) and the scapula (shoulder blade)."
#         },
#         {
#             "Question": "What is the function of the pectoral girdle?",
#             "Hint": "What is the purpose of the bones that connect the arm to the body?",
#             "Answer": "The primary function of the pectoral girdle is to provide attachment to numerous muscles, which move the arm and forearm."
#         },
#         {
#             "Question": "Where is the ulnar nerve palpable in the elbow region?",
#             "Hint": "Which nerve can be felt behind the medial epicondyle of the humerus?",
#             "Answer": "The ulnar nerve can be rolled by the middle finger in the groove behind the medial epicondyle of the humerus."
#         },
#         {
#             "Question": "Describe the orientation of the preaxial and postaxial borders of the upper limb.",
#             "Hint": "How are the preaxial and postaxial borders oriented in relation to the head?",
#             "Answer": "Each has dorsal and ventral surfaces, and preaxial and postaxial borders. The preaxial border faces towards the head."
#         },
#         {
#             "Question": "What is the deltoid tuberosity and what muscle attaches to it?",
#             "Hint": "Where does the deltoid muscle insert?",
#             "Answer": "The deltoid tuberosity is a characteristic V-shaped tuberosity on the anterolateral surface of the humerus. The deltoid muscle inserts into the deltoid tuberosity."
#         },
#         {
#             "Question": "Name the two fascial septa that divide the arm into compartments.",
#             "Hint": "What structures separate the anterior and posterior compartments of the arm?",
#             "Answer": "Two fascial septa, one on the medial side and one on the lateral side, extend inwards from the fascial sleeve and get attached to the medial and lateral supracondylar ridges of the humerus, respectively."
#         },
#         {
#             "Question": "What is the significance of the greater tubercle of the humerus and which muscles attach to it?",
#             "Hint": "What is the importance of the greater tubercle?",
#             "Answer": "The greater tubercle of the humerus is important because it forms the most lateral bony point of the shoulder region and provides attachment to supraspinatus, infraspinatus, and teres minor muscles."
#         }
#     ]
# }
#
#
# Output tokens:  total_tokens: 828

# %%
question
# Out:
# '{\n    "Topic": "Parts of Upper Limb",\n    "Questions": [\n        {\n            "Question": "What are the components of the pectoral girdle?",\n            "Hint": "What bones make up the shoulder girdle?",\n            "Answer": "The pectoral girdle consists of two bones - the scapula and the clavicle."\n        },\n        {\n            "Question": "Name the bone of the upper arm and the bones of the forearm.",\n            "Hint": "What is the single bone of the arm?",\n            "Answer": "The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna."\n        },\n        {\n            "Question": "How many carpal bones are there and how are they arranged?",\n            "Hint": "What is the composition of the wrist?",\n            "Answer": "The wrist consists of eight carpal bones arranged in two rows, each consisting of four bones."\n        },\n        {\n            "Question": "Name the three main regions of the shoulder region and the bones involved in each.",\n            "Hint": "What are the different parts of the shoulder?",\n            "Answer": "The shoulder region includes: (a) axilla or armpit, (b) scapular region or parts around the scapula (shoulder blade), and (c) pectoral or breast region on the front of the chest. The bones of the shoulder region are the clavicle (collar bone) and the scapula (shoulder blade)."\n        },\n        {\n            "Question": "What is the function of the pectoral girdle?",\n            "Hint": "What is the purpose of the bones that connect the arm to the body?",\n            "Answer": "The primary function of the pectoral girdle is to provide attachment to numerous muscles, which move the arm and forearm."\n        },\n        {\n            "Question": "Where is the ulnar nerve palpable in the elbow region?",\n            "Hint": "Which nerve can be felt behind the medial epicondyle of the humerus?",\n            "Answer": "The ulnar nerve can be rolled by the middle finger in the groove behind the medial epicondyle of the humerus."\n        },\n        {\n            "Question": "Describe the orientation of the preaxial and postaxial borders of the upper limb.",\n            "Hint": "How are the preaxial and postaxial borders oriented in relation to the head?",\n            "Answer": "Each has dorsal and ventral surfaces, and preaxial and postaxial borders. The preaxial border faces towards the head."\n        },\n        {\n            "Question": "What is the deltoid tuberosity and what muscle attaches to it?",\n            "Hint": "Where does the deltoid muscle insert?",\n            "Answer": "The deltoid tuberosity is a characteristic V-shaped tuberosity on the anterolateral surface of the humerus. The deltoid muscle inserts into the deltoid tuberosity."\n        },\n        {\n            "Question": "Name the two fascial septa that divide the arm into compartments.",\n            "Hint": "What structures separate the anterior and posterior compartments of the arm?",\n            "Answer": "Two fascial septa, one on the medial side and one on the lateral side, extend inwards from the fascial sleeve and get attached to the medial and lateral supracondylar ridges of the humerus, respectively."\n        },\n        {\n            "Question": "What is the significance of the greater tubercle of the humerus and which muscles attach to it?",\n            "Hint": "What is the importance of the greater tubercle?",\n            "Answer": "The greater tubercle of the humerus is important because it forms the most lateral bony point of the shoulder region and provides attachment to supraspinatus, infraspinatus, and teres minor muscles."\n        }\n    ]\n}'

# %%
import json
question_text = f"[{question}]"
question_json = json.loads(question_text)

print(json.dumps(question_json, indent=4))
# Out:
# [
#     {
#         "Topic": "Parts of Upper Limb",
#         "Questions": [
#             {
#                 "Question": "What are the components of the pectoral girdle?",
#                 "Hint": "What bones make up the shoulder girdle?",
#                 "Answer": "The pectoral girdle consists of two bones - the scapula and the clavicle."
#             },
#             {
#                 "Question": "Name the bone of the upper arm and the bones of the forearm.",
#                 "Hint": "What is the single bone of the arm?",
#                 "Answer": "The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna."
#             },
#             {
#                 "Question": "How many carpal bones are there and how are they arranged?",
#                 "Hint": "What is the composition of the wrist?",
#                 "Answer": "The wrist consists of eight carpal bones arranged in two rows, each consisting of four bones."
#             },
#             {
#                 "Question": "Name the three main regions of the shoulder region and the bones involved in each.",
#                 "Hint": "What are the different parts of the shoulder?",
#                 "Answer": "The shoulder region includes: (a) axilla or armpit, (b) scapular region or parts around the scapula (shoulder blade), and (c) pectoral or breast region on the front of the chest. The bones of the shoulder region are the clavicle (collar bone) and the scapula (shoulder blade)."
#             },
#             {
#                 "Question": "What is the function of the pectoral girdle?",
#                 "Hint": "What is the purpose of the bones that connect the arm to the body?",
#                 "Answer": "The primary function of the pectoral girdle is to provide attachment to numerous muscles, which move the arm and forearm."
#             },
#             {
#                 "Question": "Where is the ulnar nerve palpable in the elbow region?",
#                 "Hint": "Which nerve can be felt behind the medial epicondyle of the humerus?",
#                 "Answer": "The ulnar nerve can be rolled by the middle finger in the groove behind the medial epicondyle of the humerus."
#             },
#             {
#                 "Question": "Describe the orientation of the preaxial and postaxial borders of the upper limb.",
#                 "Hint": "How are the preaxial and postaxial borders oriented in relation to the head?",
#                 "Answer": "Each has dorsal and ventral surfaces, and preaxial and postaxial borders. The preaxial border faces towards the head."
#             },
#             {
#                 "Question": "What is the deltoid tuberosity and what muscle attaches to it?",
#                 "Hint": "Where does the deltoid muscle insert?",
#                 "Answer": "The deltoid tuberosity is a characteristic V-shaped tuberosity on the anterolateral surface of the humerus. The deltoid muscle inserts into the deltoid tuberosity."
#             },
#             {
#                 "Question": "Name the two fascial septa that divide the arm into compartments.",
#                 "Hint": "What structures separate the anterior and posterior compartments of the arm?",
#                 "Answer": "Two fascial septa, one on the medial side and one on the lateral side, extend inwards from the fascial sleeve and get attached to the medial and lateral supracondylar ridges of the humerus, respectively."
#             },
#             {
#                 "Question": "What is the significance of the greater tubercle of the humerus and which muscles attach to it?",
#                 "Hint": "What is the importance of the greater tubercle?",
#                 "Answer": "The greater tubercle of the humerus is important because it forms the most lateral bony point of the shoulder region and provides attachment to supraspinatus, infraspinatus, and teres minor muscles."
#             }
#         ]
#     }
# ]

# %%
import json

# Function to convert JSON to a list of documents
def convert_json_to_documents(question_json, prof_number, item_number):
    documents = []
    for topic in question_json:
        for question in topic["Questions"]:
            doc = {
                'prof': prof_number,
                'item': item_number,
                'topic': topic['Topic'],
                'question': question['Question'],
                'hint': question['Hint'],
                'correct_answer': question['Answer']
            }
            documents.append(doc)
    return documents

# Get user input
prof_number = 1
item_number  = int(itemNumber)
# Convert the JSON to a list of documents
documents = convert_json_to_documents(question_json, prof_number, item_number)

# %%
result = db.question_collection.insert_many(documents)
print(f"Inserted {len(result.inserted_ids)} documents into the collection.")
# Out:
# Inserted 10 documents into the collection.

# %% [markdown]
# #Get questions from MongoDB

# %%
def filter_questions_mongo(prof_number, item_number, topic_name, num_questions=10):
    query = {
        'prof': prof_number,
        'item': item_number,
        'topic': topic_name
    }

    results_cursor = question_collection.find(query).limit(num_questions)

    # Convert cursor to a list of dictionaries
    results = list(results_cursor)

    return results

# %%
# Get user input
prof_number = int(input("Enter Prof number (e.g: 1): "))
item_number = int(input("Enter Item number (e.g: 1): "))
print(', '.join(topics[item_number]))
topicNumber = int(input("Enter the topic number(e.g: 1):"))
topic_name = topics[item_number][topicNumber]
# Get and show the questions
questions = filter_questions_mongo(prof_number, item_number, topic_name, num_questions=3)
# Out:
# Enter Prof number (e.g: 1): 1
# Enter Item number (e.g: 1): 1
# Parts of Upper Limb, Parts of Ulna
# Enter the topic number(e.g: 1):0

# %%
questions
# Out:
# [{'_id': ObjectId('66838d8dfeae1d4cdc97c0a5'),
#   'prof': 1,
#   'item': 1,
#   'topic': 'Parts of Upper Limb',
#   'question': 'What are the components of the pectoral girdle?',
#   'hint': 'What bones make up the shoulder girdle?',
#   'correct_answer': 'The pectoral girdle consists of two bones - the scapula and the clavicle.'},
#  {'_id': ObjectId('66838d8dfeae1d4cdc97c0a6'),
#   'prof': 1,
#   'item': 1,
#   'topic': 'Parts of Upper Limb',
#   'question': 'Name the bone of the upper arm and the bones of the forearm.',
#   'hint': 'What is the single bone of the arm?',
#   'correct_answer': 'The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna.'},
#  {'_id': ObjectId('66838d8dfeae1d4cdc97c0a7'),
#   'prof': 1,
#   'item': 1,
#   'topic': 'Parts of Upper Limb',
#   'question': 'How many carpal bones are there and how are they arranged?',
#   'hint': 'What is the composition of the wrist?',
#   'correct_answer': 'The wrist consists of eight carpal bones arranged in two rows, each consisting of four bones.'}]

# %% [markdown]
# #Setting Up SQLite

# %%
import sqlite3
conn = sqlite3.connect('questions.db')

# %% [markdown]
# ### Cursor **creation**

# %%
c = conn.cursor()

# %%
c.execute("""DROP TABLE IF EXISTS questions""")

# %% [markdown]
# ##Create Table

# %%
#DataTypes:REAL INTEGER TEXT NULL BLOB
c.execute("""
    CREATE TABLE IF NOT EXISTS questions(
        prof INTEGER,
        item INTEGER,
        topic TEXT,
        question TEXT,
        hint TEXT,
        correct_answer TEXT
    )
""")

# %% [markdown]
# ## Insert to Sqlite Database

# %%
# Insert the documents into the 'questions' table
c.executemany('INSERT INTO questions VALUES (:prof, :item, :topic, :question, :hint, :correct_answer)', documents)

# %% [markdown]
# ##Get Question from SQLite

# %%
c.execute("SELECT * from questions")
c.fetchall()
# Out:
# [(1,
#   1,
#   'Parts of Upper Limb',
#   'What are the components of the pectoral girdle?',
#   'What bones make up the shoulder girdle?',
#   'The pectoral girdle consists of two bones - the scapula and the clavicle.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'Name the bone of the upper arm and the bones of the forearm.',
#   'What is the single bone of the arm?',
#   'The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'How many carpal bones are there and how are they arranged?',
#   'What is the composition of the wrist?',
#   'The wrist consists of eight carpal bones arranged in two rows, each consisting of four bones.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'Name the three main regions of the shoulder region and the bones involved in each.',
#   'What are the different parts of the shoulder?',
#   'The shoulder region includes: (a) axilla or armpit, (b) scapular region or parts around the scapula (shoulder blade), and (c) pectoral or breast region on the front of the chest. The bones of the shoulder region are the clavicle (collar bone) and the scapula (shoulder blade).'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'What is the function of the pectoral girdle?',
#   'What is the purpose of the bones that connect the arm to the body?',
#   'The primary function of the pectoral girdle is to provide attachment to numerous muscles, which move the arm and forearm.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'Where is the ulnar nerve palpable in the elbow region?',
#   'Which nerve can be felt behind the medial epicondyle of the humerus?',
#   'The ulnar nerve can be rolled by the middle finger in the groove behind the medial epicondyle of the humerus.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'Describe the orientation of the preaxial and postaxial borders of the upper limb.',
#   'How are the preaxial and postaxial borders oriented in relation to the head?',
#   'Each has dorsal and ventral surfaces, and preaxial and postaxial borders. The preaxial border faces towards the head.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'What is the deltoid tuberosity and what muscle attaches to it?',
#   'Where does the deltoid muscle insert?',
#   'The deltoid tuberosity is a characteristic V-shaped tuberosity on the anterolateral surface of the humerus. The deltoid muscle inserts into the deltoid tuberosity.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'Name the two fascial septa that divide the arm into compartments.',
#   'What structures separate the anterior and posterior compartments of the arm?',
#   'Two fascial septa, one on the medial side and one on the lateral side, extend inwards from the fascial sleeve and get attached to the medial and lateral supracondylar ridges of the humerus, respectively.'),
#  (1,
#   1,
#   'Parts of Upper Limb',
#   'What is the significance of the greater tubercle of the humerus and which muscles attach to it?',
#   'What is the importance of the greater tubercle?',
#   'The greater tubercle of the humerus is important because it forms the most lateral bony point of the shoulder region and provides attachment to supraspinatus, infraspinatus, and teres minor muscles.')]

# %%
def filter_questions(prof_number, item_number, topic_name, num_questions=3):
    c.execute('''
        SELECT question
        FROM questions
        WHERE prof = ? AND item = ? AND topic = ?
        LIMIT ?
    ''', (prof_number, item_number, topic_name, num_questions))
    questions = c.fetchall()

    return questions

# %%
prof_number = int(input("Enter Prof number (e.g: 1): "))
item_number = int(input("Enter Item number (e.g: 1): "))
itemNumber = item_number
print(', '.join(topics[itemNumber]))

topicNumber = int(input("Enter the topic number(e.g: 1): "))
topic_name = topics[itemNumber][topicNumber - 1]
questions = filter_questions(prof_number, item_number, topic_name, num_questions=3)

for i, question in enumerate(questions):
    print(f'{i+1}: {question}')
# Out:
# Enter Prof number (e.g: 1): 1
# Enter Item number (e.g: 1): 1
# Parts of Upper Limb, Parts of Ulna
# Enter the topic number(e.g: 1): 1
# 1: ('What are the components of the pectoral girdle?',)
# 2: ('Name the bone of the upper arm and the bones of the forearm.',)
# 3: ('How many carpal bones are there and how are they arranged?',)

# %%
conn.close()

# %% [markdown]
# #Answer Evaluation store in MongoDB

# %%
prof_number = 1
item_number =  1
topic_name  = topics[item_number][1]
questions = filter_questions_mongo(prof_number, item_number, topic_name, num_questions=5)

# %% [markdown]
# ##Schema

# %%
from pymongo import MongoClient
from pymongo.errors import CollectionInvalid
from collections import OrderedDict

# Access the database
db = client['RAG_application']

# Define the collection name
student_collection_name = 'student_collection_updated'

# Define the schema and validator
student_schema = {
    'name': {
        'type': 'string',
        'required': True,
    },
    'answer_evaluation': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'question_id': {
                    'type': 'string',
                    'required': True
                },
                'question': {
                    'type': 'string',
                    'minlength': 7,
                    'required': True,
                },
                'correct_answer': {
                    'type': 'string',
                    'required': True
                },
                'student_answer': {
                    'type': 'string',
                    'required': True
                },
                'model_evaluation': {
                    'type': 'string',
                    'required': True
                },
                'points': {
                    'type': 'int',
                    'max': 10,
                    'required': True
                }
            }
        }
    }
}

validator = {
    '$jsonSchema': {
        'bsonType': 'object',
        'properties': {}
    }
}

required = []

def process_field(field_key, field, parent_required, parent_properties):
    properties = {'bsonType': field['type']}

    if field['type'] == 'list':
        properties['bsonType'] = 'array'
        properties['items'] = {'bsonType': 'object', 'properties': {}}
        nested_required = []
        for nested_key, nested_field in field['schema']['schema'].items():
            process_field(nested_key, nested_field, nested_required, properties['items']['properties'])
        if nested_required:
            properties['items']['required'] = nested_required

    elif field['type'] == 'dict':
        properties['bsonType'] = 'object'
        nested_required = []
        for nested_key, nested_field in field['schema'].items():
            process_field(nested_key, nested_field, nested_required, properties['properties'])
        if nested_required:
            properties['required'] = nested_required
    else:
        minimum = field.get('minlength')
        if isinstance(minimum, int):
            properties['minimum'] = minimum
        maximum = field.get('max')
        if isinstance(maximum, int):
            properties['maximum'] = maximum

    if field.get('required') is True:
        parent_required.append(field_key)

    parent_properties[field_key] = properties

for field_key, field in student_schema.items():
    process_field(field_key, field, required, validator['$jsonSchema']['properties'])

if required:
    validator['$jsonSchema']['required'] = required

# Create the collection with the validator
try:
    db.create_collection(student_collection_name, validator=validator)
    print(f"Collection '{student_collection_name}' created with validator.")
except CollectionInvalid:
    print(f"Collection '{student_collection_name}' already exists or validation failed.")

print(validator)
# Out:
# Collection 'student_collection_updated' created with validator.
# {'$jsonSchema': {'bsonType': 'object', 'properties': {'name': {'bsonType': 'string'}, 'answer_evaluation': {'bsonType': 'array', 'items': {'bsonType': 'object', 'properties': {'question_id': {'bsonType': 'string'}, 'question': {'bsonType': 'string', 'minimum': 7}, 'correct_answer': {'bsonType': 'string'}, 'student_answer': {'bsonType': 'string'}, 'model_evaluation': {'bsonType': 'string'}, 'points': {'bsonType': 'int', 'maximum': 10}}, 'required': ['question_id', 'question', 'correct_answer', 'student_answer', 'model_evaluation', 'points']}}}, 'required': ['name']}}

# %%
for q in questions:
  print(q)

# %%
for question in questions:
  print(question['question'])
  hint  = input("Want a hint (y/n):")
  if(hint =='y'):
    print(question['hint'])
  answer = input("Answer:")
  actual_answer = question['correct_answer']
  prompt = get_answer_prompt(actual_answer, question['question'], answer)
  model_evaluation = model.generate_content(prompt).text
  print(model_evaluation)
# Out:
# What are the components of the pectoral girdle?
# Want a hint (y/n):y
# What bones make up the shoulder girdle?
# Answer:No idea
# {
#   "Model Feedback": "The answer provided is incorrect. The student has failed to demonstrate any knowledge or understanding of the components of the pectoral girdle. To improve, the student should review the relevant anatomical structures and their functions.",
#   "Points": 1
# }
# Name the bone of the upper arm and the bones of the forearm.
# Want a hint (y/n):y
# What is the single bone of the arm?
# Answer:Hictorial
# {
# "Model Feedback": "The answer is incorrect. The student has not provided a valid response. The correct answer is 'The bone of the upper arm is the humerus. The bones of the forearm are the radius and ulna.'",
# "Points": 1
# }
# How many carpal bones are there and how are they arranged?
# Want a hint (y/n):y
# What is the composition of the wrist?
# Answer:No idea
# {
#     "Model Feedback": "I was rather disappointed with your answer. I was expecting you to know that the wrist consists of eight carpal bones arranged in two rows, each consisting of four bones. Your answer 'No idea' suggests that you have not prepared well for the exam.",
#     "Points": 1
# }

# %%
for question in questions:
  print(question['question'])
  hint  = input("Want a hint (y/n):")
  if(hint =='y'):
    print(question['hint'])
  answer = input("Answer:")
  actual_answer = question['correct_answer']
  prompt = get_answer_prompt(actual_answer, question['question'], answer)
  model_evaluation = model.generate_content(prompt).text
  print(model_evaluation)
  #Store it into MongoDB
  document = {
        'question': question['question'],
        'correct_answer': actual_answer,
        'student_answer': answer,
        'model_evaluation': model_evaluation
    }

  print("---------------------------")
  print(document)
  # Insert document into MongoDB collection
  result = student_collection_name.insert_one(document)
  print(f"Inserted document with id: {result.inserted_id}")

# %% [markdown]
# #Store Answer Evaluation in SQLite

# %%
import sqlite3
conn = sqlite3.connect('student_evaluation.db')

# %%
c = conn.cursor()

# %%
c.execute("""
    CREATE TABLE IF NOT EXISTS student_evaluation(
        question TEXT,
        correct_answer TEXT,
        student_answer TEXT,
        model_evaluation TEXT
    )
""")

# %%
for question in questions:
  print(question['question'])
  hint  = input("Want a hint (y/n):")
  if(hint =='y'):
    print(question['hint'])
  answer = input("Answer:")
  actual_answer = question['correct_answer']
  prompt = get_answer_prompt(actual_answer, question['question'], answer)
  model_evaluation = model.generate_content(prompt).text
  print(model_evaluation)
  #Store it into MongoDB
  document = {
        'question': question['question'],
        'correct_answer': actual_answer,
        'student_answer': answer,
        'model_evaluation': model_evaluation
    }

  print("---------------------------")
  print(document)
  # Insert document into MongoDB collection
  c.execute('INSERT INTO student_evaluation VALUES (?, ?, ?, ?)',
                      (document['question'], document['correct_answer'], document['student_answer'], document['model_evaluation']))
  conn.commit()

# %%
conn.close()
